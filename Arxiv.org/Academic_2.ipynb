# %%
# A small programme to
import requests
import networkx as nx
import itertools
import xmltodict
# %pylab inline 
r = requests.get('http://export.arxiv.org/api/query?search_query=all:electron')
r.text
# Out:
# Populating the interactive namespace from numpy and matplotlib
# u'<?xml version="1.0" encoding="UTF-8"?>\n<feed xmlns="http://www.w3.org/2005/Atom">\n  <link href="http://arxiv.org/api/query?search_query%3Dall%3Aelectron%26id_list%3D%26start%3D0%26max_results%3D10" rel="self" type="application/atom+xml"/>\n  <title type="html">ArXiv Query: search_query=all:electron&amp;id_list=&amp;start=0&amp;max_results=10</title>\n  <id>http://arxiv.org/api/WyBPOs+pRgzCTXTMWhtnbcOmk6g</id>\n  <updated>2017-01-25T00:00:00-05:00</updated>\n  <opensearch:totalResults xmlns:opensearch="http://a9.com/-/spec/opensearch/1.1/">119632</opensearch:totalResults>\n  <opensearch:startIndex xmlns:opensearch="http://a9.com/-/spec/opensearch/1.1/">0</opensearch:startIndex>\n  <opensearch:itemsPerPage xmlns:opensearch="http://a9.com/-/spec/opensearch/1.1/">10</opensearch:itemsPerPage>\n  <entry>\n    <id>http://arxiv.org/abs/cond-mat/0102536v1</id>\n    <updated>2001-02-28T20:12:09Z</updated>\n    <published>2001-02-28T20:12:09Z</published>\n    <title>Impact of Electron-Electron Cusp on Configuration Interaction Energies</title>\n    <summary>  The effect of the electron-electron cusp on the convergence of configuration\ninteraction (CI) wave functions is examined. By analogy with the\npseudopotential approach for electron-ion interactions, an effective\nelectron-electron interaction is developed which closely reproduces the\nscattering of the Coulomb interaction but is smooth and finite at zero\nelectron-electron separation. The exact many-electron wave function for this\nsmooth effective interaction has no cusp at zero electron-electron separation.\nWe perform CI and quantum Monte Carlo calculations for He and Be atoms, both\nwith the Coulomb electron-electron interaction and with the smooth effective\nelectron-electron interaction. We find that convergence of the CI expansion of\nthe wave function for the smooth electron-electron interaction is not\nsignificantly improved compared with that for the divergent Coulomb interaction\nfor energy differences on the order of 1 mHartree. This shows that, contrary to\npopular belief, description of the electron-electron cusp is not a limiting\nfactor, to within chemical accuracy, for CI calculations.\n</summary>\n    <author>\n      <name>David Prendergast</name>\n      <arxiv:affiliation xmlns:arxiv="http://arxiv.org/schemas/atom">Department of Physics</arxiv:affiliation>\n    </author>\n    <author>\n      <name>M. Nolan</name>\n      <arxiv:affiliation xmlns:arxiv="http://arxiv.org/schemas/atom">NMRC, University College, Cork, Ireland</arxiv:affiliation>\n    </author>\n    <author>\n      <name>Claudia Filippi</name>\n      <arxiv:affiliation xmlns:arxiv="http://arxiv.org/schemas/atom">Department of Physics</arxiv:affiliation>\n    </author>\n    <author>\n      <name>Stephen Fahy</name>\n      <arxiv:affiliation xmlns:arxiv="http://arxiv.org/schemas/atom">Department of Physics</arxiv:affiliation>\n    </author>\n    <author>\n      <name>J. C. Greer</name>\n      <arxiv:affiliation xmlns:arxiv="http://arxiv.org/schemas/atom">NMRC, University College, Cork, Ireland</arxiv:affiliation>\n    </author>\n    <arxiv:doi xmlns:arxiv="http://arxiv.org/schemas/atom">10.1063/1.1383585</arxiv:doi>\n    <link title="doi" href="http://dx.doi.org/10.1063/1.1383585" rel="related"/>\n    <arxiv:comment xmlns:arxiv="http://arxiv.org/schemas/atom">11 pages, 6 figures, 3 tables, LaTeX209, submitted to The Journal of\n  Chemical Physics</arxiv:comment>\n    <arxiv:journal_ref xmlns:arxiv="http://arxiv.org/schemas/atom">J. Chem. Phys. 115, 1626 (2001)</arxiv:journal_ref>\n    <link href="http://arxiv.org/abs/cond-mat/0102536v1" rel="alternate" type="text/html"/>\n    <link title="pdf" href="http://arxiv.org/pdf/cond-mat/0102536v1" rel="related" type="application/pdf"/>\n    <arxiv:primary_category xmlns:arxiv="http://arxiv.org/schemas/atom" term="cond-mat.str-el" scheme="http://arxiv.org/schemas/atom"/>\n    <category term="cond-mat.str-el" scheme="http://arxiv.org/schemas/atom"/>\n  </entry ...

# %%
def search_all(term,start,stop):
    r = requests.get('http://export.arxiv.org/api/query?search_query=all:{}&start={}&max_results={}'.format(term,start,stop))
    return xmltodict.parse(r.text)

# %%
def search_author(author,start,stop):
    r = requests.get('http://export.arxiv.org/api/query?search_query=au:{}&start={}&max_results={}'.format(author,start,stop))
    return xmltodict.parse(r.text)

# %%
def get_author_list(temp):
    list_of_authors_grouped = []
    list_of_authors = []
    for entry in temp['feed']['entry']:
        temp2 = []
        for author in entry['author']:
            if type(author) is not unicode:
                temp2.append(author['name'])
                list_of_authors.append(author['name'])
        list_of_authors_grouped.append(temp2)
    return [list_of_authors,list_of_authors_grouped]

# %%
def network_generation(list_of_authors):
    for element in list_of_authors:
        if len(element) > 0:
            #print(element)
            for i in element:
                G.add_node(i)
            a = list(itertools.combinations(element,2))
            for i in a:
                G.add_edge(*i)

# %%
#Initial seed
a = search_all('Graphene',0,100)

author_list = get_author_list(a)
#loop

for i in author_list[0]:
    b = search_author(i,'0','100')
    b = get_author_list(b)
    network_generation(b[1])
    


#b = get_author_list(a)

#network_generation(b[1])
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-160-06938e450155> in <module>()
#       6
#       7 for i in author_list[0]:
# ----> 8     b = search_author(i,'0','100')
#       9     b = get_author_list(b)
#      10     network_generation(b[1])
#
# <ipython-input-87-70243025bf07> in search_author(author, start, stop)
#       1 def search_author(author,start,stop):
# ----> 2     r = requests.get('http://export.arxiv.org/api/query?search_query=au:{}&start={}&max_results={}'.format(author,start,stop))
#       3     return xmltodict.parse(r.text)
#
# UnicodeEncodeError: 'ascii' codec can't encode character u'\xf6' in position 5: ordinal not in range(128)

# %%
b
# Out:
# OrderedDict([(u'feed',
#               OrderedDict([(u'@xmlns', u'http://www.w3.org/2005/Atom'),
#                            (u'link',
#                             OrderedDict([(u'@href',
#                                           u'http://arxiv.org/api/query?search_query%3Dau%3AZhao%20Zhang%26id_list%3D%26start%3D0%26max_results%3D100'),
#                                          (u'@rel', u'self'),
#                                          (u'@type',
#                                           u'application/atom+xml')])),
#                            (u'title',
#                             OrderedDict([(u'@type', u'html'),
#                                          ('#text',
#                                           u'ArXiv Query: search_query=au:Zhao Zhang&id_list=&start=0&max_results=100')])),
#                            (u'id',
#                             u'http://arxiv.org/api/E5cITAStOeyMJoxBi46sxea//tA'),
#                            (u'updated', u'2017-01-25T00:00:00-05:00'),
#                            (u'opensearch:totalResults',
#                             OrderedDict([(u'@xmlns:opensearch',
#                                           u'http://a9.com/-/spec/opensearch/1.1/'),
#                                          ('#text', u'29837')])),
#                            (u'opensearch:startIndex',
#                             OrderedDict([(u'@xmlns:opensearch',
#                                           u'http://a9.com/-/spec/opensearch/1.1/'),
#                                          ('#text', u'0')])),
#                            (u'opensearch:itemsPerPage',
#                             OrderedDict([(u'@xmlns:opensearch',
#                                           u'http://a9.com/-/spec/opensearch/1.1/'),
#                                          ('#text', u'100')])),
#                            (u'entry',
#                             [OrderedDict([(u'id',
#                                            u'http://arxiv.org/abs/math/0612093v3'),
#                                           (u'updated',
#                                            u'2007-05-26T15:03:03Z'),
#                                           (u'published',
#                                            u'2006-12-04T14:55:06Z'),
#                                           (u'title',
#                                            u'Renormalization of Multiple $q$-Zeta Values'),
#                                           (u'summary',
#                                            u'In this paper we shall define the renormalization of the multiple $q$-zeta\nvalues (M$q$ZV) which are special values of multiple $q$-zeta functions\n$\\zeta_q(s_1,...,s_d)$ when the arguments are all positive integers or all\nnon-positive integers. This generalizes the work of Guo and Zhang\n(math.NT/0606076v3) on the renormalization of Euler-Zagier multiple zeta\nvalues. We show that our renormalization process produces the same values if\nthe M$q$ZVs are well-defined originally and that these renormalizations of\nM$q$ZV satisfy the $q$-stuffle relations if we use shifted-renormalizations for\nall divergent $\\zeta_q(s_1,...,s_d)$ (i.e., $s_1\\le 1$). Moreover, when $\\qup$\nour renormalizations agree with those of Guo and Zhang.'),
#                                           (u'author',
#                                            OrderedDict([(u'name',
#                                                          u'Jianqiang Zhao')])),
#                                           (u'arxiv:doi',
#                                            OrderedDict([(u'@xmlns:arxiv',
#                                                          u'http://arxiv.org/schemas/atom'),
#                                                         ('#text',
#                                                          u'10.1007/s10114-008-6646-x')])),
#                                           (u'link',
#                                            [OrderedDict([(u'@title', u'doi'),
#                                                          (u'@href',
#                                                           u'http://dx.doi.org/10.1007/s10114-008-6646-x'),
#                                                          (u'@rel',
#                                                           u'related')]),
#                                             OrderedDict([(u'@href',
#                                                           u'http://arxiv.org/abs/math/0612093v3'),
#                                                          (u'@rel',
#                                                           u'alternate'),
#                                                          (u'@type',
#                                                           u'text/html')]),
#                                             OrderedDict([(u'@title', u'pdf'),
#                                                          (u'@href',
#                                                           u'http://arxiv.org/pdf/math/0612093v3'),
#                                                          (u'@rel', u'related'),
#                                                          (u'@type',
#                                                           u'application/pdf')])]),
#                                           (u'arxiv:comment',
#                                            OrderedDict([(u'@xmlns:arxiv',
#                                                          u'http://arxiv.org/schemas/atom'),
#                                                         ('#text',
#                                                          u'22 pages. This is a substantial revision of the first version. I\n  provide a new and complete proof of the fact that our renormalizations\n  satisfy the q-stuffle relations using the shifting principle of MqZVs')])),
#                                           (u'arxiv:journal_ref',
#                                            OrderedDict([(u'@xmlns:arxiv',
#                                                          u'http://arxiv.org/schemas/atom'),
#                                                         ('#text',
#                                                          u'Acta Mathematica Sinica, English Series, 24 (2008), pp. 1593-1616.')])),
#                                           (u'arxiv:primary_category',
#                                            OrderedDict([(u'@xmlns:arxiv',
#                                                          u'http://arxiv.org/schemas/atom'),
#                                                         (u'@term', u'math.NT'),
#                                                         (u'@scheme',
#                                                          u'http://arxiv.org/schemas/atom')])),
#                                           (u'category',
#                                            [OrderedDict([(u'@term',
#                                                           u'math.NT'),
#                                                          (u'@scheme',
#                                                           u'http://arxiv.org/schemas/atom')]),
#                                             OrderedDict([(u'@term', u'11M41'),
#                                                          (u'@scheme',
#                                                           u'http://arxiv.org/schemas/atom')])])]),
#                              OrderedDict([(u'id',
#                                            u'http://arxiv.org/abs/1201.0422v3'),
#                                           (u'updated',
#                                            u'2012-05-28T16:08:44Z'),
#                                           (u'published',
#                                            u'2012-01-02T05:22:29Z'),
#                                           (u'title',
#                                            u'Correction to the Chiral Magnetic Effect from axial-vector interaction'),
#                                           (u'summary',
#                                            u"The recent lattice calculation at finite axial chemical potential suggests\nthat the induced current density of the chiral magnetic effect (CME) is somehow\nsuppressed comparing with the standard analytical formula. We show in a\nNJL-type model of QCD that such a suppression is a natural result when\nconsidering the influence of the attractive axial-vector interaction. We point\nout that the lattice result doesn't need to be quantitatively consistent with\nthe analytical formula due to the chirality density-density correlation. We\nalso investigate the nonperturbative effect of instanton molecules on the CME.\nSince an unconventional repulsive axial-vector interaction is induced, the CME\nwill be enhanced significantly by the instanton-anti-instanton pairings. Such a\nprediction needs to be tested by more improved lattice simulations. We further\ndemonstrate that the axial-vector interaction plays an important role on the\n$T-\\mu_A$ phase diagram."),
#                                           (u'author',
#                                            OrderedDict([(u'name',
#                                                          u'Zhao Zhang')])),
#                                           (u'arxiv:doi',
#                                            OrderedDict([(u'@xmlns:arxiv',
#                                                          u'http://arxiv.org/schemas/atom'),
#                                                         ('#text',
#                                                          u'10.1103/PhysRevD.85.114028')])),
#                                           (u'link',
#                                            [OrderedDict([(u'@title', u'doi'),
#                                                          (u'@href',
#                                                           u'http://dx.doi.org/10.1103/PhysRevD.85.114028'),
#                                                          (u'@rel',
#                                                           u'related')]),
#                                             OrderedDict([(u'@href',
#                                                           u'http://arxiv.org/abs/1201.0422v3'),
#                                                          (u'@rel',
#                                                           u'alternate'),
#                                                          (u'@type',
#                                                           u'text/html')]),
#                                             OrderedDict([(u'@title', u'pdf'),
#                                                          (u'@href',
#                                                           u'http://arxiv.org/pdf/1201.0422v3'),
#                                                          (u'@rel', u'related'),
#                                                          (u'@type',
#                                                           u'application/pdf')])]),
#                                           (u'arxiv:comment',
#                                            OrderedDict([(u'@xmlns:arxiv',
#                                                          u'http://arxiv.org/schemas/atom'),
#                                                         ('#text',
#                                                          u'9 pages,5 figures, references added, some comments modified. Final\n  version for PRD')])),
#                                           (u'arxiv:journal_ref',
#                                            OrderedDict([(u'@xmlns:arxiv',
#                                                          u'http://arxiv.org/schemas/atom'),
#                                                         ('#text',
#                                                          u'Phys. Rev. D 85, 114028 (2012)')])),
#                                           (u'arxiv:primary_category',
#                                            OrderedDict([(u'@xmlns:arxiv',
#                                                          u'http://arxiv.org/schemas/atom'),
#                                                         (u'@term', u'hep-ph'),
#                                                         (u'@scheme',
#                                                          u'http://arxiv.org/schemas/atom')])),
#                                           (u'category',
#                                            [OrderedDict([(u'@term', u'hep-ph'),
#                                                          (u'@scheme',
#                                                           u'http://arxiv.org/schemas/atom')]),
#                                             OrderedDict([(u'@term',
#                                                           u'hep-lat'),
#                                                          (u'@scheme',
#                                                           u'http://arxiv.org/schemas/atom')]),
#                                             OrderedDict([(u'@term',
#                                                           u'nucl-th'),
#                                                          (u'@scheme',
#                                                           u'http://arxiv.org/schemas/atom')])])]),
#                              OrderedDict([(u'id',
#                                            u'http://arxiv.org/abs/1504.03759v1'),
#                                           (u'updated',
#                                            u'2015-04-15T01:33:18Z'),
#                                           (u'published',
#                                            u'2015-04-15T01:33:18Z'),
#                                           (u'title',
#                                            u'Stain-Induced Band Inversion and Topological Nontriviality in Antimonene'),
#                                           (u'summary',
#                                            u'Antimonene is a novel two-dimensional (2D) semiconducting material of group V\nelements proposed in a recent literature [Zhang et al., Angew. Chem. Int. Ed.\n54, 1-5 (2015)]. Using first-principles calculations, we demonstrated that the\nbuckled configuration of antimonene enables it sustain large tensile strain up\nto 20%. Band inversion takes place in the vicinity of the Gamma point as the\ntensile strain is larger than 14.5%, leading to six tilted Dirac cones in the\nBrillouin zone. Spin-orbital coupling (SOC) effect opens up a topologically\nnontrivial bulk band gap at the Dirac points, exhibiting the features of 2D\ntopological insulators characterized by a nonzero Z2 topological invariant. The\ntunable bulk band gap, 101-560 meV, make the antimonene a promising candidate\nmaterial for achieving quantum spin Hall effect (QSH) at high temperatures\nwhich meet the requirement of future electronic devices with low power\nconsumption.'),
#                                           (u'author',
#                                            OrderedDict([(u'name',
#                                                          u'Mingwen Zhao')])),
#                                           (u'arxiv:comment',
#                                            OrderedDict([(u'@xmlns:arxiv',
#                                                          u'http://arxiv.org/schemas/atom'),
#                                                         ('#text',
#                                                          u'11 pages, 3 figures')])),
#                                           (u'link',
#                                            [OrderedDict([(u'@href',
#                                                           u'http://arxiv.org/abs/1504.03759v1'),
#                                                          (u'@rel',
#                                                           u'alternate'),
#                                                          (u'@type',
#                                                           u'text/html')]),
#                                             OrderedDict([(u'@title', u'pdf'),
#                                                          (u'@href',
#                                                           u'http://arxiv.org/pdf/1504.03759v1'),
#                                                          (u'@rel', u'related'),
#                                                          (u'@type',
#                                                           u'application/pdf')])]),
#                                           (u'arxiv:primary_category',
#                                            OrderedDict([(u'@xmlns:arxiv',
#                                                          u'http://arxiv.org/schemas/atom'),
#                                                         (u'@term',
#                                                          u'cond-mat.mtrl-sci'),
#                                                         (u'@scheme',
#                                                          u'http://arxiv.org/schemas/atom')])),
#                                           (u'category',
#                                            OrderedDict([(u'@term',
#                                                          u'cond-mat.mtrl-sci'),
#                                                         (u'@scheme',
#                                                          u'http://arxiv.org/schemas/atom')]))]),
#                              OrderedDict([(u'id',
#                                            u'http://arxiv.org/abs/astro-ph/0612727v1'),
#                                           (u'updated',
#                                            u'2006-12-26T06:17:02Z'),
#                                           (u'published',
#                                            u'2006-12-26T06:17:02Z'),
#                                           (u'title',
#                                            u'BBN, ADTree and MLP Comparison in Separating Quasars from Large Survey\n  Catalogues'),
#                                           (u'summary',
#                                            u'We compare the performance of Bayesian Belief Networks (BBN), Multilayer\nPerceptron (MLP) networks and Alternating Decision Trees (ADtree) on separating\nquasars from stars with the database from the 2MASS and FIRST survey catalogs.\nHaving a training sample of sources of known object types, the classifiers are\ntrained to separate quasars from stars. By the statistical properties of the\nsample, the features important for classification are selected. We compare the\nclassification results with and without feature selection. Experiments show\nthat the results with feature selection are better than those without feature\nselection. From the high accuracy, it is concluded that these automated methods\nare robust and effective to classify point sources, moreover they all may be\napplied for large survey projects (e.g. selecting input catalogs) and for other\nastronomical issues, such as the parameter measurement of stars and the\nredshift estimation of galaxies and quasars.'),
#                                           (u'author',
#                                            [OrderedDict([(u'name',
#                                                           u'Y. Zhang')]),
#                                             OrderedDict([(u'name',
#                                                           u'Y. Zhao')])]),
#                                           (u'arxiv:comment',
#                                            OrderedDict([(u'@xmlns:arxiv',
#                                                          u'http://arxiv.org/schemas/atom'),
#                                                         ('#text',
#                                                          u'12 pages, 6 tables, 1 figure')])),
#                                           (u'link',
#                                            [OrderedDict([(u'@href',
#                                                           u'http://arxiv.org/abs/astro-ph/0612727v1'),
#                                                          (u'@rel',
#                                                           u'alternate'),
#                                                          (u'@type',
#                                                           u'text/html')]),
#                                             OrderedDict([(u'@title', u'pdf'),
#                                                          (u'@href',
#                                                           u'http://arxiv.org/pdf/astro-ph/0612727v1'),
#                                                          (u'@rel', u'related'),
#                                                          (u'@type',
#                                                           u'application/pdf')])]),
#                                           (u'arxiv:primary_category',
#                                            OrderedDict([(u'@xmlns:arxiv',
#                                                          u'http://arxiv.org/schemas/atom'),
#                                                         (u'@term',
#                                                          u'astro-ph'),
#                                                         (u'@scheme',
#                                                          u'http://arxiv.org/schemas/atom')])),
#                                           (u'category',
#                                            OrderedDict([(u'@term',
#                                                          u'astro-ph'),
#                                                         (u'@scheme',
#                                                          u'http://arxiv.org/schemas/atom')]))]),
#                              OrderedDict([(u'id',
#                                            u'http://arxiv.org/abs/0708.4274v1'),
#                                           (u'updated',
#                                            u'2007-08-31T06:30:49Z'),
#                                           (u'published',
#                                            u'2007-08-31T06:30:49Z'),
#                                           (u'title',
#                                            u'Comparison of decision tree methods for finding active objects'),
#                                           (u'summary',
#                                            u'The automated classification of objects from large catalogues or survey\nprojects is an important task in many astronomical surveys. Faced with various\nclassification algorithms, astronomers should select the method according to\ntheir requirements. Here we describe several kinds of decision trees for\nfinding active objects by multi-wavelength data, such as REPTree, Random Tree,\nDecision Stump, Random Forest, J48, NBTree, AdTree. All decision tree\napproaches investigated are in the WEKA package. The classification performance\nof the methods is presented. In the process of classification by decision tree\nmethods, the classification rules are easily obtained, moreover these rules are\nclear and easy to understand for astronomers. As a result, astronomers are\ninclined to prefer and apply them, thus know which attributes are important to\ndiscriminate celestial objects. The experimental results show that when various\ndecision trees are applied in discriminating active objects (quasars, BL Lac\nobjects and active galaxies) from non-active objects (stars and galaxies),\nADTree is the best only in terms of accuracy, Decision Stump is the best only\nconsidering speed, J48 is the optimal choice considering both accuracy and\nspeed.'),
#                                           (u'author',
#                                            [OrderedDict([(u'name',
#                                                           u'Y. Zhao')]),
#                                             OrderedDict([(u'name',
#                                                           u'Y. Zhang')])]),
#                                           (u'arxiv:doi',
#                                            OrderedDict([(u'@xmlns:arxiv',
#                                                          u'http://arxiv.org/schemas/atom'),
#                                                         ('#text',
#                                                          u'10.1016/j.asr.2007.07.020')])),
#                                           (u'link',
#                                            [OrderedDict([(u'@title', u'doi'),
#                                                          (u'@href',
#                                                           u'http://dx.doi.org/10.1016/j.asr.2007.07.020'),
#                                                          (u'@rel',
#                                                           u'related')]),
#                                             OrderedDict([(u'@href',
#                                                           u'http://arxiv.org/abs/0708.4274v1'),
#                                                          (u'@rel',
#                                                           u'alternate'),
#                                                          (u'@type',
#                                                           u'text/html')]),
#                                             OrderedDict([(u'@title', u'pdf'),
#                                                          (u'@href',
#                                                           u'http://arxiv.org/pdf/0708.4274v1'),
#                                                          (u'@rel', u'related'),
#                                                          (u'@type',
#                                                           u'application/pdf')])]),
#                                           (u'arxiv:comment',
#                                            OrderedDict([(u'@xmlns:arxiv',
#                                                          u'http://arxiv.org/schemas/atom'),
#                                                         ('#text',
#                                                          u'10 pages. accepted by Advances in Space Research')])),
#                                           (u'arxiv:journal_ref',
#                                            OrderedDict([(u'@xmlns:arxiv',
#                                                          u'http://arxiv.org/schemas/atom'),
#                                                         ('#text',
#                                                          u'Adv.Space Res.41:1955-1959,2008')])),
#                                           (u'arxiv:primary_category',
#                                            OrderedDict([(u'@xmlns:arxiv',
#                                                          u'http://arxiv.org/schemas/atom'),
#                                                         (u'@term',
#                                                          u'astro-ph'),
#                                                         (u'@scheme',
#                                                          u'http://arxiv.org/schemas/atom')])),
#                                           (u'category',
#                                            OrderedDict([(u'@term',
#                                                          u'astro-ph'),
#                                                         (u'@scheme',
#                                                          u'http://arxiv.org/schemas/atom')]))]),
#                              OrderedDict([(u'id',
#                                            u'http://arxiv.org/abs/hep-ph/0603183v1'),
#                                           (u'updated',
#                                            u'2006-03-23T04:13:42Z'),
#                                           (u'published',
#                                            u'2006-03-23T04:13:42Z'),
#                                           (u'title',
#                                            u'Landau gauge condensates from global color model'),
#                                           (u'summary',
#                                            u'We compute the dimension-2 gluon pair condensate $g^2<{AA}>$ and the\ndimension-4 mixed quark-gluon condensate $<\\bar{q}gA\\cdot\\gamma{q}>$ in Landau\ngauge within the framework of global color model. The result for the dynamical\ngluon mass is within the range given by other independent determinations. The\nobtained mixed Landau gauge condensate $<\\bar{q}gA\\cdot\\gamma{q}>$ is clearly\ndependent on the definitions of the condensates. We show that the consistent\nresult may be obtained when the same definitions are used.'),
#                                           (u'author',
#                                            [OrderedDict([(u'name',
#                                                           u'Zhao Zhang')]),
#                                             OrderedDict([(u'name',
#                                                           u'Wei-qin Zhao')])]),
#                                           (u'arxiv:doi',
#                                            OrderedDict([(u'@xmlns:arxiv',
#                                                          u'http://arxiv.org/schemas/atom'),
#                                                         ('#text',
#                                                          u'10.1016/j.physletb.2005.05.005')])),
#                                           (u'link',
#                                            [OrderedDict([(u'@title', u'doi'),
#                                                          (u'@href',
#                                                           u'http://dx.doi.org/10.1016/j.physletb.2005.05.005'),
#                                                          (u'@rel',
#                                                           u'related')]),
#                                             OrderedDict([(u'@href',
#                                                           u'http://arxiv.org/abs/hep-ph/0603183v1'),
#                                                          (u'@rel',
#                                                           u'alternate'),
#                                                          (u'@type',
#                                                           u'text/html')]),
#                                             OrderedDict([(u'@title', u'pdf'),
#                                                          (u'@href',
#                                                           u'http://arxiv.org/pdf/hep-ph/0603183v1'),
#                                                          (u'@rel', u'related'),
#                                                          (u'@type',
#                                                           u'application/pdf')])]),
#                                           (u'arxiv:journal_ref',
#                                            OrderedDict([(u'@xmlns:arxiv',
#                                                          u'http://arxiv.org/schemas/atom'),
#                                                         ('#text',
#                                                          u'Phys.Lett. B617 (2005) 157')])),
#                                           (u'arxiv:primary_category',
#                                            OrderedDict([(u'@xmlns:arxiv',
#                                                          u'http://arxiv.org/schemas/atom'),
#                                                         (u'@term', u'hep-ph'),
#                                                         (u'@scheme',
#                                                          u'http://arxiv.org/schemas/atom')])),
#                                           (u'category',
#                                            OrderedDict([(u'@term', u'hep-ph'),
#                                                         (u'@scheme',
#                                                          u'http://arxiv.org/schemas/atom')]))]),
#                              OrderedDict([(u'id',
#                                            u'http://arxiv.org/abs/0907.1453v1'),
#                                           (u'updated',
#                                            u'2009-07-09T08:43:59Z'),
#                                           (u'published',
#                                            u'2009-07-09T08:43:59Z'),
#                                           (u'title',
#                                            u'Detecting Relic Gravitational Waves in the CMB: Comparison of Planck and\n  Ground-based Experiments'),
#                                           (u'summary',
#                                            u'We compare the detection abilities for the relic gravitational waves by two\nkinds of forthcoming cosmic microwave background radiation (CMB) experiments,\nspace-based Planck satellite and the various ground-based experiments.\nComparing with the ground-based experiments, Planck satellite can observe all\nthe CMB power spectra in all the multipole range, but having much larger\ninstrumental noises. We find that, for the uncertainty of the tensor-to-scalar\nratio $\\Delta r$, PolarBear (II) as a typical ground-based experiment can give\nmuch smaller value than Planck satellite. However, for the uncertainty of the\nspectral index $\\Delta n_t$, Planck can give the similar result with PolarBear\n(II). If combining these two experiments, the value of $\\Delta n_t$ can be\nreduced by a factor 2. For the model with $r=0.1$, the constraint $\\Delta\nn_t=0.10$ is expected to be achieved, which provides an excellent opportunity\nto study the physics in the very early universe. We also find the observation\nin the largest scale ($\\ell<20$) is very important for constraining the\nspectral index $n_t$. So it is necessary to combine the observations of the\nfuture space-based and ground-based CMB experiments to determine the relic\ngravitational waves.'),
#                                           (u'author',
#                                            [OrderedDict([(u'name',
#                                                           u'W. Zhao')]),
#                                             OrderedDict([(u'name',
#                                                           u'W. Zhang')])]),
#                                           (u'arxiv:doi',
#                                            OrderedDict([(u'@xmlns:arxiv',
#                                                          u'http://arxiv.org/schemas/atom'),
#                                                         ('#text',
#                                                          u'10.1016/j.physletb.2009.05.015')])),
#                                           (u'link',
#                                            [OrderedDict([(u'@title', u'doi'),
#                                                          (u'@href',
#                                                           u'http://dx.doi.org/10.1016/j.physletb.2009.05.015'),
#                                                          (u'@rel',
#                                                           u'related')]),
#                                             OrderedDict([(u'@href',
#                                                           u'http://arxiv.org/abs/0907.1453v1'),
#                                                          (u'@rel',
#                                                           u'alternate'),
#                                                          (u'@type',
#                                                           u'text/html')]),
#                                             OrderedDict([(u'@title', u'pdf'),
#                                                          (u'@href',
#                                                           u'http://arxiv.org/pdf/0907.1453v1'),
#                                                          (u'@rel', u'related'),
#                                                          (u'@type',
#                                                           u'application/pdf')])]),
#                                           (u'arxiv:comment',
#                                            OrderedDict([(u'@xmlns:arxiv',
#                                                          u'http://arxiv.org/schemas/atom'),
#                                                         ('#text',
#                                                          u'8 pages, 9 figures, 6 tables')])),
#                                           (u'arxiv:journal_ref',
#                                            OrderedDict([(u'@xmlns:arxiv',
#                                                          u'http://arxiv.org/schemas/atom'),
#                                                         ('#text',
#                                                          u'Phys.Lett.B677:16-23, 2009')])),
#                                           (u'arxiv:primary_category',
#                                            OrderedDict([(u'@xmlns:arxiv',
#                                                          u'http://arxiv.org/schemas/atom'),
#                                                         (u'@term',
#                                                          u'astro-ph.CO'),
#                                                         (u'@scheme',
#                                                          u'http://arxiv.org/schemas/atom')])),
#                                           (u'category',
#                                            OrderedDict([(u'@term',
#                                                          u'astro-ph.CO'),
#                                                         (u'@scheme',
#                                                          u'http://arxiv.org/schemas/atom')]))]),
#                              OrderedDict([(u'id',
#                                            u'http://arxiv.org/abs/hep-ph/0409100v1'),
#                                           (u'updated',
#                                            u'2004-09-09T02:54:01Z'),
#                                           (u'published',
#                                            u'2004-09-09T02:54:01Z'),
#                                           (u'title',
#                                            u'Mixed tensor susceptibility of the QCD vacuum from effective quark-quark\n  interactions'),
#                                           (u'summary',
#                                            u'We calculate the mixed tensor susceptibility of QCD vacuum in the framework\nof the global color symmetry model. In our calculation, the functional\nintegration over gluon fields can be performed and the gluonic vacuum\nobservable can be expressed in terms of the quark operators and the gluon\npropagator. The mixed tensor susceptibility was obtained with the subtraction\nof the perturbative contribution which is evaluated by the Wigner solution of\nthe quark gap equation. Using several different effective quark-quark\ninteraction models, we find the values of the mixed tensor susceptibility are\nvery small.'),
#                                           (u'author',
#                                            [OrderedDict([(u'name',
#                                                           u'Zhao Zhang')]),
#                                             OrderedDict([(u'name',
#                                                           u'Wei-qin Zhao')])]),
#                                           (u'arxiv:doi',
#                                            OrderedDict([(u'@xmlns:arxiv',
#                                                          u'http://arxiv.org/schemas/atom'),
#                                                         ('#text',
#                                                          u'10.1016/j.physletb.2005.03.012')])),
#                                           (u'link',
#                                            [OrderedDict([(u'@title', u'doi'),
#                                                          (u'@href',
#                                                           u'http://dx.doi.org/10.1016/j.physletb.2005.03.012'),
#                                                          (u'@rel',
#                                                           u'related')]),
#                                             OrderedDict([(u'@href',
#                                                           u'http://arxiv.org/abs/hep-ph/0409100v1'),
#                                                          (u'@rel',
#                                                           u'alternate'),
#                                                          (u'@type',
#                                                           u'text/html')]),
#                                             OrderedDict([(u'@title', u'pdf'),
#                                                          (u'@href',
#                                                           u'http://arxiv.org/pdf/hep-ph/0409100v1'),
#                                                          (u'@rel', u'related'),
#                                                          (u'@type',
#                                                           u'application/pdf')])]),
#                                           (u'arxiv:comment',
#                                            OrderedDict([(u'@xmlns:arxiv',
#                                                          u'http://arxiv.org/schemas/atom'),
#                                                         ('#text',
#                                                          u'12 pages')])),
#                                           (u'arxiv:journal_ref',
#                                            OrderedDict([(u'@xmlns:arxiv',
#                                                          u'http://arxiv.org/schemas/atom'),
#                                                         ('#text',
#                                                          u'Phys.Lett. B612 (2005) 207-214')])),
#                                           (u'arxiv:primary_category',
#                                            OrderedDict([(u'@xmlns:arxiv',
#                                                          u'http://arxiv.org/schemas/atom'),
#                                                         (u'@term', u'hep-ph'),
#                                                         (u'@scheme',
#                                                          u'http://arxiv.org/schemas/atom')])),
#                                           (u'category',
#                                            OrderedDict([(u'@term', u'hep-ph'),
#                                                         (u'@scheme',
#                                                          u'http://arxiv.org/schemas/atom')]))]),
#                              OrderedDict([(u'id',
#                                            u'http://arxiv.org/abs/1404.7566v1'),
#                                           (u'updated',
#                                            u'2014-04-30T00:56:40Z'),
#                                           (u'published',
#                                            u'2014-04-30T00:56:40Z'),
#                                           (u'title',
#                                            u'Image Compressive Sensing Recovery Using Adaptively Learned Sparsifying\n  Basis via L0 Minimization'),
#                                           (u'summary',
#                                            u'From many fewer acquired measurements than suggested by the Nyquist sampling\ntheory, compressive sensing (CS) theory demonstrates that, a signal can be\nreconstructed with high probability when it exhibits sparsity in some domain.\nMost of the conventional CS recovery approaches, however, exploited a set of\nfixed bases (e.g. DCT, wavelet and gradient domain) for the entirety of a\nsignal, which are irrespective of the non-stationarity of natural signals and\ncannot achieve high enough degree of sparsity, thus resulting in poor CS\nrecovery performance. In this paper, we propose a new framework for image\ncompressive sensing recovery using adaptively learned sparsifying basis via L0\nminimization. The intrinsic sparsity of natural images is enforced\nsubstantially by sparsely representing overlapped image patches using the\nadaptively learned sparsifying basis in the form of L0 norm, greatly reducing\nblocking artifacts and confining the CS solution space. To make our proposed\nscheme tractable and robust, a split Bregman iteration based technique is\ndeveloped to solve the non-convex L0 minimization problem efficiently.\nExperimental results on a wide range of natural images for CS recovery have\nshown that our proposed algorithm achieves significant performance improvements\nover many current state-of-the-art schemes and exhibits good convergence\nproperty.'),
#                                           (u'author',
#                                            [OrderedDict([(u'name',
#                                                           u'Jian Zhang')]),
#                                             OrderedDict([(u'name',
#                                                           u'Chen Zhao')]),
#                                             OrderedDict([(u'name',
#                                                           u'Debin Zhao')]),
#                                             OrderedDict([(u'name',
#                                                           u'Wen Gao')])]),
#                                           (u'arxiv:doi',
#                                            OrderedDict([(u'@xmlns:arxiv',
#                                                          u'http://arxiv.org/schemas/atom'),
#                                                         ('#text',
#                                                          u'10.1016/j.sigpro.2013.09.025')])),
#                                           (u'link',
#                                            [OrderedDict([(u'@title', u'doi'),
#                                                          (u'@href',
#                                                           u'http://dx.doi.org/10.1016/j.sigpro.2013.09.025'),
#                                                          (u'@rel',
#                                                           u'related')]),
#                                             OrderedDict([(u'@href',
#                                                           u'http://arxiv.org/abs/1404.7566v1'),
#                                                          (u'@rel',
#                                                           u'alternate'),
#                                                          (u'@type',
#                                                           u'text/html')]),
#                                             OrderedDict([(u'@title', u'pdf'),
#                                                          (u'@href',
#                                                           u'http://arxiv.org/pdf/1404.7566v1'),
#                                                          (u'@rel', u'related'),
#                                                          (u'@type',
#                                                           u'application/pdf')])]),
#                                           (u'arxiv:comment',
#                                            OrderedDict([(u'@xmlns:arxiv',
#                                                          u'http://arxiv.org/schemas/atom'),
#                                                         ('#text',
#                                                          u'31 pages, 4 tables, 12 figures, to be published at Signal Processing,\n  Code available: http://idm.pku.edu.cn/staff/zhangjian/ALSB/')])),
#                                           (u'arxiv:primary_category',
#                                            OrderedDict([(u'@xmlns:arxiv',
#                                                          u'http://arxiv.org/schemas/atom'),
#                                                         (u'@term', u'cs.CV'),
#                                                         (u'@scheme',
#                                                          u'http://arxiv.org/schemas/atom')])),
#                                           (u'category',
#                                            OrderedDict([(u'@term', u'cs.CV'),
#                                                         (u'@scheme',
#                                                          u'http://arxiv.org/schemas/atom')]))]),
#                              OrderedDict([(u'id',
# ...
#                                             OrderedDict([(u'name',
#                                                           u'Zengxiu Zhao')])]),
#                                           (u'arxiv:doi',
#                                            OrderedDict([(u'@xmlns:arxiv',
#                                                          u'http://arxiv.org/schemas/atom'),
#                                                         ('#text',
#                                                          u'10.1103/PhysRevA.90.035402')])),
#                                           (u'link',
#                                            [OrderedDict([(u'@title', u'doi'),
#                                                          (u'@href',
#                                                           u'http://dx.doi.org/10.1103/PhysRevA.90.035402'),
#                                                          (u'@rel',
#                                                           u'related')]),
#                                             OrderedDict([(u'@href',
#                                                           u'http://arxiv.org/abs/1406.3135v1'),
#                                                          (u'@rel',
#                                                           u'alternate'),
#                                                          (u'@type',
#                                                           u'text/html')]),
#                                             OrderedDict([(u'@title', u'pdf'),
#                                                          (u'@href',
#                                                           u'http://arxiv.org/pdf/1406.3135v1'),
#                                                          (u'@rel', u'related'),
#                                                          (u'@type',
#                                                           u'application/pdf')])]),
#                                           (u'arxiv:comment',
#                                            OrderedDict([(u'@xmlns:arxiv',
#                                                          u'http://arxiv.org/schemas/atom'),
#                                                         ('#text',
#                                                          u'5 pages, 4 figures')])),
#                                           (u'arxiv:primary_category',
#                                            OrderedDict([(u'@xmlns:arxiv',
#                                                          u'http://arxiv.org/schemas/atom'),
#                                                         (u'@term',
#                                                          u'physics.atom-ph'),
#                                                         (u'@scheme',
#                                                          u'http://arxiv.org/schemas/atom')])),
#                                           (u'category',
#                                            OrderedDict([(u'@term',
#                                                          u'physics.atom-ph'),
#                                                         (u'@scheme',
#                                                          u'http://arxiv.org/schemas/atom')]))]),
#                              OrderedDict([(u'id',
#                                            u'http://arxiv.org/abs/1406.5389v1'),
#                                           (u'updated',
#                                            u'2014-06-20T13:57:51Z'),
#                                           (u'published',
#                                            u'2014-06-20T13:57:51Z'),
#                                           (u'title',
#                                            u'Rydberg states generation of Hydrogen atoms with intense laser pulses:\n  the roles of Coulomb force and initial lateral momentum'),
#                                           (u'summary',
#                                            u'We investigate the Rydberg states generation of Hydrogen atoms with intense\nlaser pulses, by solving the time-dependent Schr\\"odinger equation and by means\nof classical trajectory monte-carlo simulations. Both linearly polarized\nmulti-cycle pulses and pairs of optical half cycle pulses are used. Comparisons\nbetween these methods show that both the Coulomb force and initial lateral\nmomentum, which have effects on the $n$-distribution and $l$-distribution of\nthe population of excited states, are important in the generation of Rydberg\nstates.'),
#                                           (u'author',
#                                            [OrderedDict([(u'name',
#                                                           u'Bin Zhang')]),
#                                             OrderedDict([(u'name',
#                                                           u'Wenbo Chen')]),
#                                             OrderedDict([(u'name',
#                                                           u'Zengxiu Zhao')])]),
#                                           (u'arxiv:doi',
#                                            OrderedDict([(u'@xmlns:arxiv',
#                                                          u'http://arxiv.org/schemas/atom'),
#                                                         ('#text',
#                                                          u'10.1103/PhysRevA.90.023409')])),
#                                           (u'link',
#                                            [OrderedDict([(u'@title', u'doi'),
#                                                          (u'@href',
#                                                           u'http://dx.doi.org/10.1103/PhysRevA.90.023409'),
#                                                          (u'@rel',
#                                                           u'related')]),
#                                             OrderedDict([(u'@href',
#                                                           u'http://arxiv.org/abs/1406.5389v1'),
#                                                          (u'@rel',
#                                                           u'alternate'),
#                                                          (u'@type',
#                                                           u'text/html')]),
#                                             OrderedDict([(u'@title', u'pdf'),
#                                                          (u'@href',
#                                                           u'http://arxiv.org/pdf/1406.5389v1'),
#                                                          (u'@rel', u'related'),
#                                                          (u'@type',
#                                                           u'application/pdf')])]),
#                                           (u'arxiv:comment',
#                                            OrderedDict([(u'@xmlns:arxiv',
#                                                          u'http://arxiv.org/schemas/atom'),
#                                                         ('#text',
#                                                          u'7 pages, 8 figures')])),
#                                           (u'arxiv:primary_category',
#                                            OrderedDict([(u'@xmlns:arxiv',
#                                                          u'http://arxiv.org/schemas/atom'),
#                                                         (u'@term',
#                                                          u'physics.atom-ph'),
#                                                         (u'@scheme',
#                                                          u'http://arxiv.org/schemas/atom')])),
#                                           (u'category',
#                                            OrderedDict([(u'@term',
#                                                          u'physics.atom-ph'),
#                                                         (u'@scheme',
#                                                          u'http://arxiv.org/schemas/atom')]))]),
#                              OrderedDict([(u'id',
#                                            u'http://arxiv.org/abs/1506.08514v2'),
#                                           (u'updated',
#                                            u'2016-03-30T09:25:50Z'),
#                                           (u'published',
#                                            u'2015-06-29T06:08:59Z'),
#                                           (u'title',
#                                            u'Exponential Convergence for 3D Stochastic Primitive Equations of the\n  Large Scale Ocean'),
#                                           (u'summary',
#                                            u'This paper reports weak solutions of 3D stochastic primitive equations of the\nlarge scale ocean converge exponentially fast to the equilibrium, if the noise\nis at the same time sufficiently smooth and non-degenerate. Furthermore, thanks\nto global well-posedness of the strong solution, weak solutions which are\nlimits of Galerkin approximations share the same invariant measure. In\nparticular, the invariant measure for the strong solution is unique.'),
#                                           (u'author',
#                                            [OrderedDict([(u'name',
#                                                           u'Zhao Dong')]),
#                                             OrderedDict([(u'name',
#                                                           u'Jianliang Zhai')]),
#                                             OrderedDict([(u'name',
#                                                           u'Rangrang Zhang')])]),
#                                           (u'arxiv:comment',
#                                            OrderedDict([(u'@xmlns:arxiv',
#                                                          u'http://arxiv.org/schemas/atom'),
#                                                         ('#text',
#                                                          u'arXiv admin note: substantial text overlap with arXiv:math/0512056 by\n  other authors; text overlap with arXiv:math/0503028 by other authors')])),
#                                           (u'link',
#                                            [OrderedDict([(u'@href',
#                                                           u'http://arxiv.org/abs/1506.08514v2'),
#                                                          (u'@rel',
#                                                           u'alternate'),
#                                                          (u'@type',
#                                                           u'text/html')]),
#                                             OrderedDict([(u'@title', u'pdf'),
#                                                          (u'@href',
#                                                           u'http://arxiv.org/pdf/1506.08514v2'),
#                                                          (u'@rel', u'related'),
#                                                          (u'@type',
#                                                           u'application/pdf')])]),
#                                           (u'arxiv:primary_category',
#                                            OrderedDict([(u'@xmlns:arxiv',
#                                                          u'http://arxiv.org/schemas/atom'),
#                                                         (u'@term', u'math.PR'),
#                                                         (u'@scheme',
#                                                          u'http://arxiv.org/schemas/atom')])),
#                                           (u'category',
#                                            OrderedDict([(u'@term', u'math.PR'),
#                                                         (u'@scheme',
#                                                          u'http://arxiv.org/schemas/atom')]))]),
#                              OrderedDict([(u'id',
#                                            u'http://arxiv.org/abs/1509.08171v1'),
#                                           (u'updated',
#                                            u'2015-09-28T01:31:30Z'),
#                                           (u'published',
#                                            u'2015-09-28T01:31:30Z'),
#                                           (u'title',
#                                            u'Enhancement of two-photon transition rate by selectively removing\n  certain frequency comb teeth'),
#                                           (u'summary',
#                                            u'We present experiments demonstrating an enhancement of resonant two-photon\ntransition rate in 87Rb utilizing spectral phase manipulation of the excitation\nfrequency comb. By selectively removing certain comb teeth, the resonant\ntwo-photon transition rate can be improved, and reach a factor of more than\n1.8. The femtosecond pulse-train excitation of two-photon transition is\ninvestigated theoretically based on general multiphoton transitions and the\nresults are compared with the experiments. The theory presented here gives a\nclear insight of physical mechanism of this quantum coherent control and\nindicates that it is simple, effective and universal for nonlinear interactions\nbetween frequency combs and matters.'),
#                                           (u'author',
#                                            [OrderedDict([(u'name',
#                                                           u'Shuangyou Zhang')]),
#                                             OrderedDict([(u'name',
#                                                           u'Wanpeng Yang')]),
#                                             OrderedDict([(u'name',
#                                                           u'Jianye Zhao')])]),
#                                           (u'link',
#                                            [OrderedDict([(u'@href',
#                                                           u'http://arxiv.org/abs/1509.08171v1'),
#                                                          (u'@rel',
#                                                           u'alternate'),
#                                                          (u'@type',
#                                                           u'text/html')]),
#                                             OrderedDict([(u'@title', u'pdf'),
#                                                          (u'@href',
#                                                           u'http://arxiv.org/pdf/1509.08171v1'),
#                                                          (u'@rel', u'related'),
#                                                          (u'@type',
#                                                           u'application/pdf')])]),
#                                           (u'arxiv:primary_category',
#                                            OrderedDict([(u'@xmlns:arxiv',
#                                                          u'http://arxiv.org/schemas/atom'),
#                                                         (u'@term',
#                                                          u'physics.optics'),
#                                                         (u'@scheme',
#                                                          u'http://arxiv.org/schemas/atom')])),
#                                           (u'category',
#                                            [OrderedDict([(u'@term',
#                                                           u'physics.optics'),
#                                                          (u'@scheme',
#                                                           u'http://arxiv.org/schemas/atom')]),
#                                             OrderedDict([(u'@term',
#                                                           u'physics.atom-ph'),
#                                                          (u'@scheme',
#                                                           u'http://arxiv.org/schemas/atom')])])])])]))])

# %%
G = nx.Graph()
G.nodes()
network_generation(b)

# %%
G.nodes()
# Out:
# [u'Michihisa Yamamoto',
#  u'Roy Shiloh',
#  u'Chao Feng',
#  u'J. C. Greer',
#  u'Michele Cini',
#  u'Yossi Lereah',
#  u'A. Rubio',
#  u'Yigal Lilach',
#  u'I. Hagymasi',
#  u'Kenji Kamide',
#  u'Patrick Irvin',
#  u'A. H. Castro Neto',
#  u'Natalia Del Fatti',
#  u'John C. Brown',
#  u'H. Predel',
#  u'Roland Bouffanais',
#  u'C. Vocks',
#  u'I. Karakurt',
#  u'Seigo Tarucha',
#  u'Jamal Berakdar',
#  u'Gerhard Fasol',
#  u'R. N. Gurzhi',
#  u'Reza Asgari',
#  u'P. Youplao',
#  u'I. V. Tokatly',
#  u'Jeremy Levy',
#  u'Vadim Galenchik',
#  u'Ignacio Franco',
#  u'M. Hruska',
#  u'Emile B\xe9villon',
#  u'A. Saxena',
#  u'Michelle Tomczyk',
#  u'F Flores',
#  u'Ryota Niikura',
#  u'E. Dzifcakova',
#  u'Z. Khas',
#  u'Michele Piana',
#  u'Arnab Kar',
#  u'R. C. Monreal',
#  u'S. Kaprzyk',
#  u'P. S. Shternin',
#  u'M. Saitoh',
#  u'K. W. West',
#  u'J. Lorenzana',
#  u'Marco Polini',
#  u"Roberto D'Agosta",
#  u'Tristan Meunier',
#  u'Tong Zhang',
#  u'M. Grilli',
#  u'Andrew Das Arulsamy',
#  u'Shintaro Takada',
#  u'K. Kral',
#  u'X. Liu',
#  u'M. Yu. Reizer',
#  u'Ming-Su Si',
#  u'Christos Flytzanis',
#  u'Wang-Kong Tse',
#  u'J. Ali',
#  u'G. De Filippis',
#  u'M. Korkusinski',
#  u'Guanglei Cheng',
#  u'Laurent Saminadayar',
#  u'Jeffrey M. Wrighton',
#  u'Yuan Li',
#  u'David Pekker',
#  u'Pavel Lougovski',
#  u'Andrea Bertoni',
#  u'Guido Goldoni',
#  u'Stephen Fahy',
#  u'Teresa del Rio Gaztelurrutia',
#  u'Elisa Molinari',
#  u'Gaetano Senatore',
#  u'Jozef Strecka',
#  u'You-Quan Li',
#  u'Rok Zitko',
#  u'Eduard P. Kontar',
#  u'L. K. Saini',
#  u'Fabrice Vall\xe9e',
#  u'Konstantin A. Kouzakov',
#  u'L. N. Pfeiffer',
#  u'David Prendergast',
#  u'Janez Bonca',
#  u'Xuezhong Ruan',
#  u'Sylvain Hermelin',
#  u'Ilya V. Pogorelov',
#  u'Vanina Recoules',
#  u'J. Tobola',
#  u'Zhentang Zhao',
#  u'John R. Tolsma',
#  u'John M. Vail',
#  u'D Ihle',
#  u'I. Campillo',
#  u'B. Wiendlocha',
#  u'D. Ninno',
#  u'E. H. Hwang',
#  u'Mengchen Huang',
#  u'S. Das Sarma',
#  u'G. Mann',
#  u'V. O. Krasnov',
#  u'J. H. Lloyd-Williams',
#  u'M. Brodsky',
#  u'Roser Valenti',
#  u'C. Broggini',
#  u'A. I. Kopeliovich',
#  u'Hirofumi Yanagisawa',
#  u'P. Aebi',
#  u'Marco Fronzi',
#  u'G. Seibold',
#  u'I. V. Gornyi',
#  u'Enrico Perfetto',
#  u'Alessandro Principi',
#  u'Andreas D. Wieck',
#  u'F. Marsiglio',
#  u'Hideo Aoki',
#  u'I. V. Stasyuk',
#  u'A. Martin-Rodero',
#  u'Alexandre B. Tacla',
#  u'Sangwoo Ryu',
#  u'Herman Batelaan',
#  u'R. C. Ashoori',
#  u'R. J. Needs',
#  u'M. Nolan',
#  u'M. Dimitrova-Ivanovich',
#  u'Toma Yorisaki',
#  u'B Zenker',
#  u'A. N. Kalinenko',
#  u'Manuel A. Gonzalez',
#  u'V. P. Garistov',
#  u'Na Sai',
#  u'Shicheng Lu',
#  u'Emmanuelle Dufour',
#  u'N. Pornsuwancharoen',
#  u'S. -W. Tsai',
#  u'Matthew D. Mower',
#  u'Razvan Stoian',
#  u'D. G. Yakovlev',
#  u'Yasuchika Ishida',
#  u'P. P. Raychev',
#  u'F. M. Peeters',
#  u'N. B. Zhitenev',
#  u'A. Gordon Emslie',
#  u'Pascal Simon',
#  u'Harald O. Jeschke',
#  u'Ryotaro Arita',
#  u'D. K. Campbell',
#  u'B. Hildebrand',
#  u'Zhoufei Wang',
#  u'Yoshihiro Aiura',
#  u'I. Masina',
#  u'Chuhei Oshima',
#  u'Hyungwoo Lee',
#  u'E. V. Chulkov',
#  u'Yang Ji',
#  u'O. Legeza',
#  u'Andrew Daley',
#  u'U. C. Mendes',
#  u'G. J. Conduit',
#  u'Juan I. Climente',
#  u'A. Di Ciolo',
#  u'R. Fok',
#  u'Ka-Ming Tam',
#  u'P. Yupapin',
#  u'Jie liu',
#  u'Xuan Qian',
#  u'V. Cataudella',
#  u'I. S. Amiri',
#  u'Shuhei Kato',
#  u'Marco Prato',
#  u'H Fehske',
#  u'V. Mitin',
#  u'Marco A. Gigosos',
#  u'V. Marigliano Ramaglia',
#  u'G. -Q. Hai',
#  u'D. B. Melrose',
#  u'D. F. Ye',
#  u'Claudia Filippi',
#  u'V. M. Silkin',
#  u'Francesc Salvat-Pujol',
#  u'Oscar J. Hernandez',
#  u'C. Monney',
#  u'Massimo Rontani',
#  u'F X Bronold',
#  u'H. Buhmann',
#  u'L. W. Molenkamp',
#  u'L. K. Castelano',
#  u'P. M. Echenique',
#  u'Anna Maria Massone',
#  u'G. Vignale',
#  u'Josh P. Veazey',
#  u'Masaki Tezuka',
#  u'Jana Cisarova',
#  u'J. Maruani',
#  u'N. M. Chtchelkatchev',
#  u'Chang-Beom Eom',
#  u'Haihui Luo',
#  u'K. H. Ahn',
#  u'Dmitry Pozdnyakov',
#  u'A. Sergeev',
#  u'I. S. Burmistrov',
#  u'M. Moretti',
#  u'M. W. Wu',
#  u'Jean-Philippe Colombier',
#  u'G. Iadonisi',
#  u'G. Monney',
#  u'A. V. Yanovsky',
#  u'J. M. Pitarke',
#  u'Kirk T. McDonald',
#  u'A. R. Bishop',
#  u'Allan H. MacDonald',
#  u'Antimo Angelucci',
#  u'P. Hawrylak',
#  u'J. Solyom',
#  u'K. S. Tikhonov',
#  u'Arturo Tagliacozzo',
#  u'Hiroyuki Sakaki',
#  u'D. P. Menezes',
#  u'A. J. Dahm',
#  u'A. N. Petrov',
#  u'Konstantine Shmakov',
#  u'Annette Calisti',
#  u'R. L. Pavlov',
#  u'R. K. Moudgil',
#  u'A. Levy Yeyati',
#  u'Daniel Loss',
#  u'Massimiliano Di Ventra',
#  u'Haixiao Deng',
#  u'C. A. Perroni',
#  u'Shigeru Koikegami',
#  u'W. S. Stacey',
#  u'A. H. Trojnar',
#  u'A. I. Panin',
#  u'James W. Dufty',
#  u'T. Lookman',
#  u'Van An Dinh',
#  u'Ady Arie',
#  u'F. Ventriglia',
#  u'Liping Chen',
#  u'Christopher B\xe4uerle',
#  u'Bernard Talin',
#  u'B. Spivak',
#  u'Y. Zhou',
#  u'H. Beck']

# %%
a = search_all('electron','0','100')

# %%
b = get_author_list(a)

# %%
b
# Out:
# [[u'David Prendergast',
#   u'M. Nolan',
#   u'Claudia Filippi',
#   u'Stephen Fahy',
#   u'J. C. Greer'],
#  [u'P. S. Shternin', u'D. G. Yakovlev'],
#  [u'G. -Q. Hai', u'F. M. Peeters'],
#  [u'Eduard P. Kontar',
#   u'A. Gordon Emslie',
#   u'Anna Maria Massone',
#   u'Michele Piana',
#   u'John C. Brown',
#   u'Marco Prato'],
#  [],
#  [],
#  [u'I. Karakurt', u'A. J. Dahm'],
#  [u'Emile B\xe9villon',
#   u'Jean-Philippe Colombier',
#   u'Vanina Recoules',
#   u'Razvan Stoian'],
#  [u'I. Campillo',
#   u'V. M. Silkin',
#   u'J. M. Pitarke',
#   u'E. V. Chulkov',
#   u'A. Rubio',
#   u'P. M. Echenique'],
#  [u'Matthew D. Mower', u'G. Vignale', u'I. V. Tokatly'],
#  [u'Emile B\xe9villon',
#   u'Jean-Philippe Colombier',
#   u'Vanina Recoules',
#   u'Razvan Stoian'],
#  [],
#  [u'N. M. Chtchelkatchev', u'I. S. Burmistrov'],
#  [],
#  [u'Konstantin A. Kouzakov', u'Jamal Berakdar'],
#  [],
#  [u'Dmitry Pozdnyakov', u'Vadim Galenchik'],
#  [],
#  [],
#  [u'James W. Dufty',
#   u'Ilya V. Pogorelov',
#   u'Bernard Talin',
#   u'Annette Calisti'],
#  [u'Hirofumi Yanagisawa',
#   u'Toma Yorisaki',
#   u'Ryota Niikura',
#   u'Shuhei Kato',
#   u'Yasuchika Ishida',
#   u'Kenji Kamide',
#   u'Chuhei Oshima'],
#  [u'Sylvain Hermelin',
#   u'Shintaro Takada',
#   u'Michihisa Yamamoto',
#   u'Seigo Tarucha',
#   u'Andreas D. Wieck',
#   u'Laurent Saminadayar',
#   u'Christopher B\xe4uerle',
#   u'Tristan Meunier'],
#  [u'Gerhard Fasol', u'Hiroyuki Sakaki'],
#  [],
#  [u'N. B. Zhitenev', u'R. C. Ashoori', u'L. N. Pfeiffer', u'K. W. West'],
#  [],
#  [u'G. De Filippis',
#   u'V. Cataudella',
#   u'G. Iadonisi',
#   u'V. Marigliano Ramaglia',
#   u'C. A. Perroni',
#   u'F. Ventriglia'],
#  [u'Rok Zitko', u'Janez Bonca'],
#  [u'Enrico Perfetto', u'Michele Cini'],
#  [],
#  [],
#  [u'Kirk T. McDonald', u'Konstantine Shmakov'],
#  [u'Shigeru Koikegami', u'Yoshihiro Aiura'],
#  [],
#  [u'Wang-Kong Tse', u'E. H. Hwang', u'S. Das Sarma'],
#  [u'Haihui Luo', u'Xuan Qian', u'Xuezhong Ruan', u'Yang Ji'],
#  [u'Pavel Lougovski', u'Herman Batelaan'],
#  [u'G. -Q. Hai', u'L. K. Castelano'],
#  [],
#  [u'John R. Tolsma',
#   u'Alessandro Principi',
#   u'Reza Asgari',
#   u'Marco Polini',
#   u'Allan H. MacDonald'],
#  [u'H. Predel',
#   u'H. Buhmann',
#   u'L. W. Molenkamp',
#   u'R. N. Gurzhi',
#   u'A. N. Kalinenko',
#   u'A. I. Kopeliovich',
#   u'A. V. Yanovsky'],
#  [u'A. Sergeev', u'M. Yu. Reizer', u'V. Mitin'],
#  [],
#  [u'Masaki Tezuka', u'Ryotaro Arita', u'Hideo Aoki'],
#  [u'Guanglei Cheng',
#   u'Michelle Tomczyk',
#   u'Alexandre B. Tacla',
#   u'Hyungwoo Lee',
#   u'Shicheng Lu',
#   u'Josh P. Veazey',
#   u'Mengchen Huang',
#   u'Patrick Irvin',
#   u'Sangwoo Ryu',
#   u'Chang-Beom Eom',
#   u'Andrew Daley',
#   u'David Pekker',
#   u'Jeremy Levy'],
#  [u'C. Vocks', u'E. Dzifcakova', u'G. Mann'],
#  [],
#  [u'Y. Zhou', u'M. W. Wu'],
#  [u'Antimo Angelucci', u'Arturo Tagliacozzo'],
#  [u'M. Hruska', u'B. Spivak'],
#  [u'K. H. Ahn', u'T. Lookman', u'A. Saxena', u'A. R. Bishop'],
#  [u'A. I. Panin', u'A. N. Petrov'],
#  [u'B. Wiendlocha', u'J. Tobola', u'S. Kaprzyk'],
#  [],
#  [u'Andrew Das Arulsamy', u'Marco Fronzi'],
#  [],
#  [],
#  [u'Roy Shiloh', u'Yossi Lereah', u'Yigal Lilach', u'Ady Arie'],
#  [u'U. C. Mendes', u'M. Korkusinski', u'A. H. Trojnar', u'P. Hawrylak'],
#  [u'D. B. Melrose', u'R. Fok', u'D. P. Menezes'],
#  [],
#  [u'R. K. Moudgil', u'L. K. Saini', u'Gaetano Senatore'],
#  [u'Juan I. Climente',
#   u'Andrea Bertoni',
#   u'Massimo Rontani',
#   u'Guido Goldoni',
#   u'Elisa Molinari'],
#  [u'Emmanuelle Dufour',
#   u'Annette Calisti',
#   u'Bernard Talin',
#   u'Marco A. Gigosos',
#   u'Manuel A. Gonzalez',
#   u'Teresa del Rio Gaztelurrutia',
#   u'James W. Dufty'],
#  [u'Jeffrey M. Wrighton', u'James W. Dufty'],
#  [u'A. Martin-Rodero', u'A. Levy Yeyati', u'F Flores', u'R. C. Monreal'],
#  [u'C. A. Perroni', u'D. Ninno', u'V. Cataudella'],
#  [u'Francesc Salvat-Pujol', u'Harald O. Jeschke', u'Roser Valenti'],
#  [u'John M. Vail', u'Oscar J. Hernandez', u'Ming-Su Si', u'Zhoufei Wang'],
#  [u'N. Pornsuwancharoen',
#   u'P. Youplao',
#   u'I. S. Amiri',
#   u'J. Ali',
#   u'P. Yupapin'],
#  [],
#  [u'N. B. Zhitenev',
#   u'M. Brodsky',
#   u'R. C. Ashoori',
#   u'L. N. Pfeiffer',
#   u'K. W. West'],
#  [u'K. Kral', u'Z. Khas'],
#  [],
#  [u'Van An Dinh', u'M. Saitoh'],
#  [u'Ka-Ming Tam', u'S. -W. Tsai', u'D. K. Campbell', u'A. H. Castro Neto'],
#  [u"Roberto D'Agosta", u'Na Sai', u'Massimiliano Di Ventra'],
#  [],
#  [u'Pascal Simon', u'Daniel Loss'],
#  [u'C. Broggini', u'I. Masina', u'M. Moretti'],
#  [u'R. L. Pavlov',
#   u'P. P. Raychev',
#   u'V. P. Garistov',
#   u'M. Dimitrova-Ivanovich',
#   u'J. Maruani'],
#  [u'Natalia Del Fatti',
#   u'Roland Bouffanais',
#   u'Fabrice Vall\xe9e',
#   u'Christos Flytzanis'],
#  [u'Yuan Li', u'You-Quan Li'],
#  [u'D. F. Ye', u'X. Liu', u'Jie liu'],
#  [u'A. Di Ciolo', u'J. Lorenzana', u'M. Grilli', u'G. Seibold'],
#  [u'I. S. Burmistrov', u'I. V. Gornyi', u'K. S. Tikhonov'],
#  [],
#  [u'I. V. Stasyuk', u'V. O. Krasnov'],
#  [],
#  [u'B Zenker', u'D Ihle', u'F X Bronold', u'H Fehske'],
#  [],
#  [u'W. S. Stacey', u'F. Marsiglio'],
#  [u'Chao Feng', u'Tong Zhang', u'Haixiao Deng', u'Zhentang Zhao'],
#  [u'G. Monney', u'C. Monney', u'B. Hildebrand', u'P. Aebi', u'H. Beck'],
#  [u'I. Hagymasi', u'J. Solyom', u'O. Legeza'],
#  [],
#  [u'Arnab Kar', u'Liping Chen', u'Ignacio Franco'],
#  [u'J. H. Lloyd-Williams', u'R. J. Needs', u'G. J. Conduit'],
#  [],
#  [u'Jozef Strecka', u'Jana Cisarova']]

# %%
b = search_author('J. H. Lloyd-Williams','0','100')

# %%
b['feed']['entry'][0]
# Out:
# OrderedDict([(u'id', u'http://arxiv.org/abs/1204.0097v1'),
#              (u'updated', u'2012-03-31T12:51:27Z'),
#              (u'published', u'2012-03-31T12:51:27Z'),
#              (u'title',
#               u'Kinetic Monte Carlo simulations inspired by epitaxial graphene growth'),
#              (u'summary',
#               u'Graphene, a flat monolayer of carbon atoms packed tightly into a two\ndimensional hexagonal lattice, has unusual electronic properties which have\nmany promising nanoelectronic applications. Recent Low Energy Electron\nMicroscopy (LEEM) experiments show that the step edge velocity of epitaxially\ngrown 2D graphene islands on Ru(0001) varies with the fifth power of the\nsupersaturation of carbon adatoms. This suggests that graphene islands grow by\nthe addition of clusters of five atoms rather than by the usual mechanism of\nsingle adatom attachment.\n  We have carried out Kinetic Monte Carlo (KMC) simulations in order to further\ninvestigate the general scenario of epitaxial growth by the attachment of\nmobile clusters of atoms. We did not seek to directly replicate the Gr/Ru(0001)\nsystem but instead considered a model involving mobile tetramers of atoms on a\nsquare lattice. Our results show that the energy barrier for tetramer break up\nand the number of tetramers that must collide in order to nucleate an immobile\nisland are the important parameters for determining whether, as in the\nGr/Ru(0001) system, the adatom density at the onset of island nucleation is an\nincreasing function of temperature. A relatively large energy barrier for\nadatom attachment to islands is required in order for our model to produce an\nequilibrium adatom density that is a large fraction of the nucleation density.\nA large energy barrier for tetramer attachment to islands is also needed for\nthe island density to dramatically decrease with increasing temperature. We\nshow that islands grow with a velocity that varies with the fourth power of the\nsupersaturation of adatoms when tetramer attachment is the dominant process for\nisland growth.'),
#              (u'author', OrderedDict([(u'name', u'J H Lloyd-Williams')])),
#              (u'arxiv:doi',
#               OrderedDict([(u'@xmlns:arxiv', u'http://arxiv.org/schemas/atom'),
#                            ('#text', u'10.1103/PhysRevB.85.161402')])),
#              (u'link',
#               [OrderedDict([(u'@title', u'doi'),
#                             (u'@href',
#                              u'http://dx.doi.org/10.1103/PhysRevB.85.161402'),
#                             (u'@rel', u'related')]),
#                OrderedDict([(u'@href', u'http://arxiv.org/abs/1204.0097v1'),
#                             (u'@rel', u'alternate'),
#                             (u'@type', u'text/html')]),
#                OrderedDict([(u'@title', u'pdf'),
#                             (u'@href', u'http://arxiv.org/pdf/1204.0097v1'),
#                             (u'@rel', u'related'),
#                             (u'@type', u'application/pdf')])]),
#              (u'arxiv:journal_ref',
#               OrderedDict([(u'@xmlns:arxiv', u'http://arxiv.org/schemas/atom'),
#                            ('#text', u'Phys. Rev. B 85, 161402(R) (2012)')])),
#              (u'arxiv:primary_category',
#               OrderedDict([(u'@xmlns:arxiv', u'http://arxiv.org/schemas/atom'),
#                            (u'@term', u'cond-mat.mtrl-sci'),
#                            (u'@scheme', u'http://arxiv.org/schemas/atom')])),
#              (u'category',
#               OrderedDict([(u'@term', u'cond-mat.mtrl-sci'),
#                            (u'@scheme', u'http://arxiv.org/schemas/atom')]))])

# %%
import xmltodict

# %%
temp = xmltodict.parse(r.text)

# %%
temp['feed'].keys()
# Out:
# [u'@xmlns',
#  u'link',
#  u'title',
#  u'id',
#  u'updated',
#  u'opensearch:totalResults',
#  u'opensearch:startIndex',
#  u'opensearch:itemsPerPage',
#  u'entry']

# %%
temp['feed']['entry'][1].keys()
# Out:
# [u'id',
#  u'updated',
#  u'published',
#  u'title',
#  u'summary',
#  u'author',
#  u'arxiv:doi',
#  u'link',
#  u'arxiv:comment',
#  u'arxiv:journal_ref',
#  u'arxiv:primary_category',
#  u'category']

# %%
temp['feed']['entry'][1]['author'][1]['name']
# Out:
# u'D. G. Yakovlev'

# %%
list_of_authors = []
temp2 = []

# %%
for entry in temp['feed']['entry']:
#    print(entry)
    temp2 = []
    for author in entry['author']:
        #print(len(author))
        #print(type(author))
        #print(author)
        if type(author) is not unicode:
            #print('success')
            temp2.append(author['name'])
    list_of_authors.append(temp2)

# %%
list_of_authors
# Out:
# [[u'David Prendergast',
#   u'M. Nolan',
#   u'Claudia Filippi',
#   u'Stephen Fahy',
#   u'J. C. Greer'],
#  [u'P. S. Shternin', u'D. G. Yakovlev'],
#  [u'G. -Q. Hai', u'F. M. Peeters'],
#  [u'Eduard P. Kontar',
#   u'A. Gordon Emslie',
#   u'Anna Maria Massone',
#   u'Michele Piana',
#   u'John C. Brown',
#   u'Marco Prato'],
#  [],
#  [],
#  [u'I. Karakurt', u'A. J. Dahm'],
#  [u'Emile B\xe9villon',
#   u'Jean-Philippe Colombier',
#   u'Vanina Recoules',
#   u'Razvan Stoian'],
#  [u'I. Campillo',
#   u'V. M. Silkin',
#   u'J. M. Pitarke',
#   u'E. V. Chulkov',
#   u'A. Rubio',
#   u'P. M. Echenique'],
#  [u'Matthew D. Mower', u'G. Vignale', u'I. V. Tokatly']]

# %%
for i in list_of_authors:
    print(i,type(i))
# Out:
# ([u'David Prendergast', u'M. Nolan', u'Claudia Filippi', u'Stephen Fahy', u'J. C. Greer'], <type 'list'>)
# ([u'P. S. Shternin', u'D. G. Yakovlev'], <type 'list'>)
# ([u'G. -Q. Hai', u'F. M. Peeters'], <type 'list'>)
# ([u'Eduard P. Kontar', u'A. Gordon Emslie', u'Anna Maria Massone', u'Michele Piana', u'John C. Brown', u'Marco Prato'], <type 'list'>)
# ([], <type 'list'>)
# ([], <type 'list'>)
# ([u'I. Karakurt', u'A. J. Dahm'], <type 'list'>)
# ([u'Emile B\xe9villon', u'Jean-Philippe Colombier', u'Vanina Recoules', u'Razvan Stoian'], <type 'list'>)
# ([u'I. Campillo', u'V. M. Silkin', u'J. M. Pitarke', u'E. V. Chulkov', u'A. Rubio', u'P. M. Echenique'], <type 'list'>)
# ([u'Matthew D. Mower', u'G. Vignale', u'I. V. Tokatly'], <type 'list'>)

# %%
list_of_authors[0]
# Out:
# [u'David Prendergast',
#  u'M. Nolan',
#  u'Claudia Filippi',
#  u'Stephen Fahy',
#  u'J. C. Greer']

# %%
type(list_of_authors[4]) is not unicode
# Out:
# True

# %%
G = nx.Graph()

# %%
for element in list_of_authors:
    if len(element) > 0:
        #print(element)
        for i in element:
            G.add_node(i)
        a = list(itertools.combinations(element,2))
        for i in a:
            G.add_edge(*i)

# %%
G.edges()
# Out:
# [(u'J. C. Greer', u'Claudia Filippi'),
#  (u'J. C. Greer', u'M. Nolan'),
#  (u'J. C. Greer', u'David Prendergast'),
#  (u'J. C. Greer', u'Stephen Fahy'),
#  (u'Anna Maria Massone', u'Michele Piana'),
#  (u'Anna Maria Massone', u'Marco Prato'),
#  (u'Anna Maria Massone', u'Eduard P. Kontar'),
#  (u'Anna Maria Massone', u'A. Gordon Emslie'),
#  (u'Anna Maria Massone', u'John C. Brown'),
#  (u'A. Rubio', u'E. V. Chulkov'),
#  (u'A. Rubio', u'J. M. Pitarke'),
#  (u'A. Rubio', u'I. Campillo'),
#  (u'A. Rubio', u'V. M. Silkin'),
#  (u'A. Rubio', u'P. M. Echenique'),
#  (u'Stephen Fahy', u'Claudia Filippi'),
#  (u'Stephen Fahy', u'M. Nolan'),
#  (u'Stephen Fahy', u'David Prendergast'),
#  (u'John C. Brown', u'Michele Piana'),
#  (u'John C. Brown', u'Eduard P. Kontar'),
#  (u'John C. Brown', u'A. Gordon Emslie'),
#  (u'John C. Brown', u'Marco Prato'),
#  (u'P. M. Echenique', u'E. V. Chulkov'),
#  (u'P. M. Echenique', u'J. M. Pitarke'),
#  (u'P. M. Echenique', u'I. Campillo'),
#  (u'P. M. Echenique', u'V. M. Silkin'),
#  (u'Jean-Philippe Colombier', u'Vanina Recoules'),
#  (u'Jean-Philippe Colombier', u'Razvan Stoian'),
#  (u'Jean-Philippe Colombier', u'Emile B\xe9villon'),
#  (u'Matthew D. Mower', u'G. Vignale'),
#  (u'Matthew D. Mower', u'I. V. Tokatly'),
#  (u'Razvan Stoian', u'Vanina Recoules'),
#  (u'Razvan Stoian', u'Emile B\xe9villon'),
#  (u'Eduard P. Kontar', u'Michele Piana'),
#  (u'Eduard P. Kontar', u'Marco Prato'),
#  (u'Eduard P. Kontar', u'A. Gordon Emslie'),
#  (u'I. Karakurt', u'A. J. Dahm'),
#  (u'F. M. Peeters', u'G. -Q. Hai'),
#  (u'M. Nolan', u'Claudia Filippi'),
#  (u'M. Nolan', u'David Prendergast'),
#  (u'A. Gordon Emslie', u'Michele Piana'),
#  (u'A. Gordon Emslie', u'Marco Prato'),
#  (u'David Prendergast', u'Claudia Filippi'),
#  (u'I. V. Tokatly', u'G. Vignale'),
#  (u'Emile B\xe9villon', u'Vanina Recoules'),
#  (u'E. V. Chulkov', u'J. M. Pitarke'),
#  (u'E. V. Chulkov', u'I. Campillo'),
#  (u'E. V. Chulkov', u'V. M. Silkin'),
#  (u'Michele Piana', u'Marco Prato'),
#  (u'I. Campillo', u'J. M. Pitarke'),
#  (u'I. Campillo', u'V. M. Silkin'),
#  (u'P. S. Shternin', u'D. G. Yakovlev'),
#  (u'V. M. Silkin', u'J. M. Pitarke')]

# %%
nx.draw(G,pos=nx.nx.circular_layout(G))

# %%
for i in list_of_authors:
    print(type(i) == list)
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True

# %%
fir
# Out:
# [(u'David Prendergast',),
#  (u'M. Nolan',),
#  (u'Claudia Filippi',),
#  (u'Stephen Fahy',),
#  (u'J. C. Greer',)]

# %%
for i,k in pairwise(list_of_authors[0]):
    print(i,k)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-850cae58499b> in <module>()
# ----> 1 for i,k in pairwise(list_of_authors[0]):
#       2     print(i,k)
#
# NameError: name 'pairwise' is not defined

# %%
import itertools

# %%
a = list(itertools.combinations(list_of_authors[0],2))

# %%
a
# Out:
# [(u'David Prendergast', u'M. Nolan'),
#  (u'David Prendergast', u'Claudia Filippi'),
#  (u'David Prendergast', u'Stephen Fahy'),
#  (u'David Prendergast', u'J. C. Greer'),
#  (u'M. Nolan', u'Claudia Filippi'),
#  (u'M. Nolan', u'Stephen Fahy'),
#  (u'M. Nolan', u'J. C. Greer'),
#  (u'Claudia Filippi', u'Stephen Fahy'),
#  (u'Claudia Filippi', u'J. C. Greer'),
#  (u'Stephen Fahy', u'J. C. Greer')]

# %%
G.add_node(a[0])

# %%
G.nodes()
# Out:
# [(u'David Prendergast', u'M. Nolan')]

# %%
iterable = range(10)
for s in xrange(len(iterable)+1):
    for comb in itertools.combinations(iterable, s):
        yield comb
# Out:
#   File "<ipython-input-44-75b84ff704de>", line 4
#     yield comb
# SyntaxError: 'yield' outside function

# %%
a = '{} is a {}'.format('This','test')

# %%
a
# Out:
# 'This is a test'

# %%
G = nx.Graph()

print(G.nodes())
def add_to_a():
    G.add_node(1)
    
add_to_a()    
print(G.nodes())
# Out:
# []
# [1]

# %%
G.add_node(1)

# %%
G.nodes()
# Out:
# []

# %%
# !pwd
