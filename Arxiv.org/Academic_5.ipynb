# %%
# A small programme to
import requests
import networkx as nx
import itertools
import xmltodict
import pandas as pd
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def search_all(term,start,stop):
    r = requests.get('http://export.arxiv.org/api/query?search_query=all:{}&start={}&max_results={}'.format(term,start,stop))
    return xmltodict.parse(r.text)

# %%
def search_author(author,start,stop):
    r = requests.get('http://export.arxiv.org/api/query?search_query=au:{}&start={}&max_results={}'.format(author,start,stop))
    return xmltodict.parse(r.text)

# %%
def get_author_list(temp):
    list_of_authors_grouped = []
    list_of_authors = []
    for entry in temp['feed']['entry']:
        temp2 = []
        for author in entry['author']:
            if type(author) is not unicode:
                temp2.append(author['name'])
                list_of_authors.append(author['name'])
        list_of_authors_grouped.append(temp2)
    return [list_of_authors,list_of_authors_grouped]

# %%
def get_author_list(temp):
    list_of_authors_grouped = []
    list_of_authors = []
    if 'entry' not in temp['feed'].keys():
        return
    if type(temp['feed']['entry']) == list:
        for entry in temp['feed']['entry']:
            temp2 = []
            for author in entry['author']:
                if type(author) is not unicode:
                    temp2.append(author['name'])
                    list_of_authors.append(author['name'])
            list_of_authors_grouped.append(temp2)
    else:
        list_of_authors_grouped.extend(temp['feed']['entry']['author'])
        list_of_authors.append(temp['feed']['entry']['author'])
    return [list_of_authors,list_of_authors_grouped]

# %%
def get_author_list(temp):
    list_of_authors_grouped = []
    list_of_authors = []
    if 'entry' not in temp['feed'].keys():
        return
    if type(temp['feed']['entry']) == list:
        for entry in temp['feed']['entry']:
            temp2 = []
            for author in entry['author']:
                if type(author) is not unicode:
                    temp2.append(author['name'])
                    list_of_authors.append(author['name'])
                else:
                    temp2.append(temp['feed']['entry']['author'])
                    #list_of_authors_grouped.extend(temp['feed']['entry']['author'])
                    list_of_authors.append(temp['feed']['entry']['author'])    
                    
            list_of_authors_grouped.append({'authors':temp2,'title':entry['title']})
               
    return [list_of_authors,list_of_authors_grouped]

# %%
def get_author_list(temp):
    list_of_authors_grouped = []
    list_of_authors = []
    if 'entry' not in temp['feed'].keys():
        return
    if type(temp['feed']['entry']) == list:
        for entry in temp['feed']['entry']:
            temp2 = []
            for author in entry['author']:
                if type(author) is not unicode:
                    temp2.append(author['name'])
                    list_of_authors.append(author['name'])
            list_of_authors_grouped.append({'authors':temp2,'title':entry['title']})
    else:
        list_of_authors_grouped.extend(temp['feed']['entry']['author'])
        list_of_authors.append(temp['feed']['entry']['author'])
    return [list_of_authors,list_of_authors_grouped]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-109-49efa9caabb8> in <module>()
# ----> 1 temp2
#
# NameError: name 'temp2' is not defined

# %%
def network_generation(list_of_authors):
    for element in list_of_authors:
        if len(element) > 0:
            #print(element)
            for i in element:
                G.add_node(i)
            a = list(itertools.combinations(element,2))
            for i in a:
                G.add_edge(*i)

# %%
def network_generation(list_of_authors):
    for element in list_of_authors:
        if len(element) > 0:
            #print(element)
            for i in element:
                G.add_node(i)
            a = list(itertools.combinations(element,2))
            for i in a:
                G.add_edge(*i)

# %%
#Initial seed
G = nx.Graph()
a = search_all('Graphene',0,10)

author_list = get_author_list(a)
#loop

for i in author_list[0]:
    b = search_author(i,'0','10')
    b = get_author_list(b)
    if type(b) != type(None):
        network_generation(b[1])
    


#b = get_author_list(a)

#network_generation(b[1])

# %%
#Initial seed
G = nx.Graph()
a = search_all('Graphene',0,10)

author_list = get_author_list(a)
#loop

for i in author_list[0]:
    b = search_author(i,'0','10')
    b = authors_and_titles(b)
    if type(b) != type(None):
        network_generation(b[1])
    


#b = get_author_list(a)

#network_generation(b[1])

# %%
def network_generation(c):
    for element in c:
        for author in element['author']:
            G.add_node(author,title = element['title'])

        a = list(itertools.combinations(element['author'],2))
        for i in a:
            G.add_edge(*i)

# %%
network_generation(b[0])

# %%
G = nx.Graph()
G.nodes()
# Out:
# []

# %%
G.edges()
G.node['S. J. Welz'].keys()
# Out:
# dict_keys(['title'])

# %%
H = nx.Graph()


for author in b[0][0]['author']:
    H.add_node(author,title = b[0][0]['title'])

a = list(itertools.combinations(element,2))
for i in a:
    G.add_edge(*i)


    print(author)

    
b[0][0]['title']
# Out:
# Ajmala Shireen
# Rana Saha
# A. Sundaresan
# C. N. R. Rao
# 'Large magnetoelectric effect in the Al1-xGaxFeO3 family of multiferroic\n  Oxides'

# %%
H.node['Ajmala Shireen']
# Out:
# {'title': 'Large magnetoelectric effect in the Al1-xGaxFeO3 family of multiferroic\n  Oxides'}

# %%
b[0][0]['title']
# Out:
# 'Large magnetoelectric effect in the Al1-xGaxFeO3 family of multiferroic\n  Oxides'

# %%
b = search_author(i,'0','10')
c = get_author_list(b)

# %%
b['feed']['entry'][0]['author']
# Out:
# OrderedDict([('name', 'M. I. Katsnelson')])

# %%
temp1 = []
temp2 = []
temp5 = []
for entry in b['feed']['entry']:
    if type(entry['author']) == list:
        temp3 = []
        for author in entry['author']:
            temp3.append(author['name'])
        temp1.append(temp3)
        temp5.append({'author':temp3,'title':entry['title']})
    else: 
        temp1.append(entry['author']['name'])
        temp5.append({'author':entry['author']['name'],'title':entry['title']})
    #temp1.append(entry['author'])
    #temp1.append(entry['author'])
    temp2.append(entry['title'])
# Out:
# 'Zitterbewegung, chirality, and minimal conductivity in graphene'

# %%
def authors_and_titles(b):
    temp1 = []
    temp2 = []
    temp5 = []
    for entry in b['feed']['entry']:
        if type(entry['author']) == list:
            temp3 = []
            for author in entry['author']:
                temp3.append(author['name'])
            temp1.append(temp3)
            temp5.append({'author':temp3,'title':entry['title']})
        else: 
            temp1.append(entry['author']['name'])
            temp5.append({'author':entry['author']['name'],'title':entry['title']})
        #temp1.append(entry['author'])
        #temp1.append(entry['author'])
        temp2.append(entry['title'])
    return [temp5,temp1]

# %%
temp = authors_and_titles(b)
temp[1]
# Out:
# ['M. I. Katsnelson',
#  'M. I. Katsnelson',
#  'M. Ahsan Zeb',
#  ['M. Feldbacher', 'R. Arita', 'K. Held', 'F. F. Assaad'],
#  'M. I. Katsnelson',
#  'M. I. Katsnelson',
#  'M. I. Katsnelson',
#  'M. I. Katsnelson',
#  'M. I. Katsnelson',
#  'M. I. Katsnelson']

# %%
temp4 = []
for author in b['feed']['entry'][3]['author']:
    temp4.append(author['name'])
    print(author['name'])
# Out:
# M. Feldbacher
# R. Arita
# K. Held
# F. F. Assaad

# %%
temp1
# Out:
# ['M. I. Katsnelson',
#  'M. I. Katsnelson',
#  'M. Ahsan Zeb',
#  ['M. Feldbacher', 'R. Arita', 'K. Held', 'F. F. Assaad'],
#  'M. I. Katsnelson',
#  'M. I. Katsnelson',
#  'M. I. Katsnelson',
#  'M. I. Katsnelson',
#  'M. I. Katsnelson',
#  'M. I. Katsnelson']

# %%
temp5
# Out:
# [{'author': 'M. I. Katsnelson',
#   'title': 'Comment on "Projective Quantum Monte Carlo Method for the Anderson\n  Impurity Model and its Application to Dynamical Mean Field Theory"'},
#  {'author': 'M. I. Katsnelson',
#   'title': 'Aharonov-Bohm effect in undoped graphene: Magnetotransport via\n  evanescent waves'},
#  {'author': 'M. Ahsan Zeb',
#   'title': 'Comment on "Chiral tunnelling and the Klein paradox in graphene"'},
#  {'author': ['M. Feldbacher', 'R. Arita', 'K. Held', 'F. F. Assaad'],
#   'title': 'Some clarifications on cond-mat/0508763 by M. I. Katsnelson'},
#  {'author': 'M. I. Katsnelson',
#   'title': 'Zitterbewegung, chirality, and minimal conductivity in graphene'},
#  {'author': 'M. I. Katsnelson',
#   'title': 'Minimal conductivity in bilayer graphene'},
#  {'author': 'M. I. Katsnelson',
#   'title': 'Nonlinear screening of charge impurities in graphene'},
#  {'author': 'M. I. Katsnelson',
#   'title': 'Conductance quantization in graphene nanoribbons: Adiabatic\n  approximation'},
#  {'author': 'M. I. Katsnelson',
#   'title': 'Scattering of charge carriers by point defects in bilayer graphene'},
#  {'author': 'M. I. Katsnelson',
#   'title': 'Optical properties of graphene: the Fermi liquid approach'}]

# %%
temp1
temp2
# Out:
# ['Comment on "Projective Quantum Monte Carlo Method for the Anderson\n  Impurity Model and its Application to Dynamical Mean Field Theory"',
#  'Aharonov-Bohm effect in undoped graphene: Magnetotransport via\n  evanescent waves',
#  'Comment on "Chiral tunnelling and the Klein paradox in graphene"',
#  'Some clarifications on cond-mat/0508763 by M. I. Katsnelson',
#  'Zitterbewegung, chirality, and minimal conductivity in graphene',
#  'Minimal conductivity in bilayer graphene',
#  'Nonlinear screening of charge impurities in graphene',
#  'Conductance quantization in graphene nanoribbons: Adiabatic\n  approximation',
#  'Scattering of charge carriers by point defects in bilayer graphene',
#  'Optical properties of graphene: the Fermi liquid approach']

# %%
temp1[2]['name']
# Out:
# 'M. Ahsan Zeb'

# %%
collections.OrderedDict
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-140-c6c606d20764> in <module>()
# ----> 1 collections.OrderedDict
#
# NameError: name 'collections' is not defined

# %%
c
# Out:
# [['M. Feldbacher', 'R. Arita', 'K. Held', 'F. F. Assaad'],
#  [{'authors': [],
#    'title': 'Comment on "Projective Quantum Monte Carlo Method for the Anderson\n  Impurity Model and its Application to Dynamical Mean Field Theory"'},
#   {'authors': [],
#    'title': 'Aharonov-Bohm effect in undoped graphene: Magnetotransport via\n  evanescent waves'},
#   {'authors': [],
#    'title': 'Comment on "Chiral tunnelling and the Klein paradox in graphene"'},
#   {'authors': ['M. Feldbacher', 'R. Arita', 'K. Held', 'F. F. Assaad'],
#    'title': 'Some clarifications on cond-mat/0508763 by M. I. Katsnelson'},
#   {'authors': [],
#    'title': 'Zitterbewegung, chirality, and minimal conductivity in graphene'},
#   {'authors': [], 'title': 'Minimal conductivity in bilayer graphene'},
#   {'authors': [],
#    'title': 'Nonlinear screening of charge impurities in graphene'},
#   {'authors': [],
#    'title': 'Conductance quantization in graphene nanoribbons: Adiabatic\n  approximation'},
#   {'authors': [],
#    'title': 'Scattering of charge carriers by point defects in bilayer graphene'},
#   {'authors': [],
#    'title': 'Optical properties of graphene: the Fermi liquid approach'}]]

# %%
b['feed']['entry'][0]['author']
# Out:
# OrderedDict([('name', 'M. I. Katsnelson')])

# %%
author_list[1]
# Out:
# [['Zhao Zhang', 'Teng Li'],
#  ['U. Stöberl', 'U. Wurstbauer', 'W. Wegscheider', 'D. Weiss', 'J. Eroms'],
#  ['E. N. Voloshina', 'Yu. S. Dedkov'],
#  ['J. L. Qi', 'K. Nagashio', 'T. Nishimura', 'A. Toriumi'],
#  ['Cem Ozdogan', 'Jens Kunstmann', 'Alexander Quandt'],
#  ['W. Jung',
#   'D. -H. Oh',
#   'I. Song',
#   'H. -C. Shin',
#   'S. J. Ahn',
#   'Y. Moon',
#   'C. -Y. Park',
#   'J. R. Ahn'],
#  ['Guilhermino J. M. Fechine',
#   'Inigo Martin-Fernandez',
#   'George Yiapanis',
#   'Ricardo V. Bof de Oliveira',
#   'Xiao Hu',
#   'Irene Yarovsky',
#   'Antonio H. Castro Neto',
#   'Barbaros Ozyilmaz'],
#  ['Sanshui Xiao', 'Xiaolong Zhu', 'Bo-Hong Li', 'N. Asger Mortensen'],
#  ['Xinran Wang', 'Scott Tabakman', 'Hongjie Dai'],
#  ['D. W. Boukhvalov', 'M. I. Katsnelson']]

# %%
G.nodes()
# Out:
# ['authors', 'title']

# %%
author_list[1]
# Out:
# [{'authors': ['Zhao Zhang', 'Teng Li'],
#   'title': 'Determining Graphene Adhesion via Substrate-regulated Morphology of\n  Graphene'},
#  {'authors': ['U. Stöberl',
#    'U. Wurstbauer',
#    'W. Wegscheider',
#    'D. Weiss',
#    'J. Eroms'],
#   'title': 'Morphology and flexibility of graphene and few-layer graphene on various\n  substrates'},
#  {'authors': ['E. N. Voloshina', 'Yu. S. Dedkov'],
#   'title': 'Electronic and magnetic properties of the graphene/Eu/Ni(111) hybrid\n  system'},
#  {'authors': ['J. L. Qi', 'K. Nagashio', 'T. Nishimura', 'A. Toriumi'],
#   'title': 'Crystal orientation relation and macroscopic surface roughness in\n  hetero-epitaxially grown graphene on Cu/mica'},
#  {'authors': ['Cem Ozdogan', 'Jens Kunstmann', 'Alexander Quandt'],
#   'title': 'Localization of metallicity and magnetic properties of graphene and of\n  graphene nanoribbons doped with boron clusters'},
#  {'authors': ['W. Jung',
#    'D. -H. Oh',
#    'I. Song',
#    'H. -C. Shin',
#    'S. J. Ahn',
#    'Y. Moon',
#    'C. -Y. Park',
#    'J. R. Ahn'],
#   'title': 'Influence of graphene-substrate interactions on configurations of\n  organic molecules on graphene: pentacene/epitaxial graphene/SiC'},
#  {'authors': ['Guilhermino J. M. Fechine',
#    'Inigo Martin-Fernandez',
#    'George Yiapanis',
#    'Ricardo V. Bof de Oliveira',
#    'Xiao Hu',
#    'Irene Yarovsky',
#    'Antonio H. Castro Neto',
#    'Barbaros Ozyilmaz'],
#   'title': 'Direct dry transfer of chemical vapor deposition graphene to polymeric\n  substrates'},
#  {'authors': ['Sanshui Xiao',
#    'Xiaolong Zhu',
#    'Bo-Hong Li',
#    'N. Asger Mortensen'],
#   'title': 'Graphene-plasmon polaritons: From fundamental properties to potential\n  applications'},
#  {'authors': ['Xinran Wang', 'Scott Tabakman', 'Hongjie Dai'],
#   'title': 'Atomic Layer Deposition of Metal Oxides on Pristine and Functionalized\n  Graphene'},
#  {'authors': ['D. W. Boukhvalov', 'M. I. Katsnelson'],
#   'title': 'Chemical functionalization of graphene'}]

# %%
author_list[1]
# Out:
# [['Zhao Zhang', 'Teng Li'],
#  ['U. Stöberl', 'U. Wurstbauer', 'W. Wegscheider', 'D. Weiss', 'J. Eroms'],
#  ['E. N. Voloshina', 'Yu. S. Dedkov'],
#  ['J. L. Qi', 'K. Nagashio', 'T. Nishimura', 'A. Toriumi'],
#  ['Cem Ozdogan', 'Jens Kunstmann', 'Alexander Quandt'],
#  ['W. Jung',
#   'D. -H. Oh',
#   'I. Song',
#   'H. -C. Shin',
#   'S. J. Ahn',
#   'Y. Moon',
#   'C. -Y. Park',
#   'J. R. Ahn'],
#  ['Guilhermino J. M. Fechine',
#   'Inigo Martin-Fernandez',
#   'George Yiapanis',
#   'Ricardo V. Bof de Oliveira',
#   'Xiao Hu',
#   'Irene Yarovsky',
#   'Antonio H. Castro Neto',
#   'Barbaros Ozyilmaz'],
#  ['Sanshui Xiao', 'Xiaolong Zhu', 'Bo-Hong Li', 'N. Asger Mortensen'],
#  ['Xinran Wang', 'Scott Tabakman', 'Hongjie Dai'],
#  ['D. W. Boukhvalov', 'M. I. Katsnelson']]

# %%
G.edges()
# Out:
# [('E. Orru', 'G. Mann'),
#  ('E. Orru', 'O. Wucknitz'),
#  ('E. Orru', 'A. Corstanje'),
#  ('E. Orru', 'G. Heald'),
#  ('E. Orru', 'M. A. Garrett'),
#  ('E. Orru', 'J. W. Broderick'),
#  ('E. Orru', 'J. E. Enriquez'),
#  ('E. Orru', 'W. Reich'),
#  ('E. Orru', 'C. Tasse'),
#  ('E. Orru', 'M. W. Wise'),
#  ('E. Orru', 'S. Duscha'),
#  ('E. Orru', 'M. Kuniyoshi'),
#  ('E. Orru', 'I. M. Avruch'),
#  ('E. Orru', 'U. Ebert'),
#  ('E. Orru', 'R. J. van Weeren'),
#  ('E. Orru', 'O. Scholten'),
#  ('E. Orru', 'A. G. Polatidis'),
#  ('E. Orru', 'M. J. Norden'),
#  ('E. Orru', 'S. Thoudam'),
#  ('E. Orru', 'M. Pandey-Pommier'),
#  ('E. Orru', 'T. N. G. Trinh'),
#  ('E. Orru', 'G. Bernardi'),
#  ('E. Orru', 'R. Vermeulen'),
#  ('E. Orru', 'P. Schellart'),
#  ('E. Orru', 'C. Koehn'),
#  ('E. Orru', 'W. Frieswijk'),
#  ('E. Orru', 'S. ter Veen'),
#  ('E. Orru', 'J. Moldon'),
#  ('E. Orru', 'P. Zarka'),
#  ('E. Orru', 'R. A. Fallows'),
#  ('E. Orru', 'B. Ciardi'),
#  ('E. Orru', 'M. Hoeft'),
#  ('E. Orru', 'M. de Vos'),
#  ('E. Orru', 'O. Smirnov'),
#  ('E. Orru', 'D. McKay-Bukowski'),
#  ('E. Orru', 'E. de Geus'),
#  ('E. Orru', 'A. Alexov'),
#  ('E. Orru', 'M. Mevius'),
#  ('E. Orru', 'A. M. M. Scaife'),
#  ('E. Orru', 'V. I. Kondratiev'),
#  ('E. Orru', 'J. Swinbank'),
#  ('E. Orru', 'J. W. T. Hessels'),
#  ('E. Orru', 'J. Grießmeier'),
#  ('E. Orru', 'R. McFadden'),
#  ('E. Orru', 'D. J. Schwarz'),
#  ('E. Orru', 'A. Bonafede'),
#  ('E. Orru', 'C. Vocks'),
#  ('E. Orru', 'H. Falcke'),
#  ('E. Orru', 'J. P. Rachen'),
#  ('E. Orru', 'M. Brüggen'),
#  ('E. Orru', 'J. P. McKean'),
#  ('E. Orru', 'M. Serylak'),
#  ('E. Orru', 'G. Kuper'),
#  ('E. Orru', 'M. Tagger'),
#  ('E. Orru', 'L. Rossetto'),
#  ('E. Orru', 'M. Steinmetz'),
#  ('E. Orru', 'M. C. Toribio'),
#  ('E. Orru', 'S. Buitink'),
#  ('E. Orru', 'H. Paas'),
#  ('E. Orru', 'F. Breitling'),
#  ('E. Orru', 'R. Pizzo'),
#  ('E. Orru', 'H. R. Butcher'),
#  ('E. Orru', 'J. R. Hörandel'),
#  ('E. Orru', 'J. Eislöffel'),
#  ('E. Orru', 'C. Rutjes'),
#  ('E. Orru', 'J. M. Anderson'),
#  ('E. Orru', 'A. Nelles'),
#  ('E. Orru', 'E. Juette'),
#  ('E. Orru', 'A. W. Gunst'),
#  ('E. Orru', 'P. Best'),
#  ('E. Orru', 'M. J. Bentum'),
#  ('E. Orru', 'H. Röttgering'),
#  ('E. Orru', 'H. A. Holties'),
#  ('D. Qi', 'J. K. Schoelz'),
#  ('D. Qi', 'L. Dong'),
#  ('D. Qi', 'P. Xu'),
#  ('D. Qi', 'M. L. Ackerman'),
#  ('D. Qi', 'J. Hansen'),
#  ('D. Qi', 'P. M. Thibado'),
#  ('D. Qi', 'S. D. Barber'),
#  ('C. Gerl', 'C. Mitzkus'),
#  ('C. Gerl', 'U. Wurstbauer'),
#  ('C. Gerl', 'V. Umansky'),
#  ('C. Gerl', 'R. G. Mani'),
#  ('C. Gerl', 'W. Wegscheider'),
#  ('C. Gerl', 'S. Schmult'),
#  ('M. Rongen', 'A. Taketa'),
#  ('M. Rongen', 'J. Gallagher'),
#  ('M. Rongen', 'H. -G. Sander'),
#  ('M. Rongen', 'F. Huang'),
#  ('M. Rongen', 'R. Koirala'),
#  ('M. Rongen', 'M. Voge'),
#  ('M. Rongen', 'U. Naumann'),
#  ('M. Rongen', 'M. Stahlberg'),
#  ('M. Rongen', 'M. Medici'),
#  ('M. Rongen', 'T. Ehrhardt'),
#  ('M. Rongen', 'M. Schmitz'),
#  ('M. Rongen', 'G. T. Przybylski'),
#  ('M. Rongen', 'N. Wandkowsky'),
#  ('M. Rongen', 'E. Cheung'),
#  ('M. Rongen', 'S. Kopper'),
#  ('M. Rongen', 'S. Marka'),
#  ('M. Rongen', 'A. Goldschmidt'),
#  ('M. Rongen', 'K. Ghorbani'),
#  ('M. Rongen', 'L. Gerhardt'),
#  ('M. Rongen', 'M. Day'),
#  ('M. Rongen', 'D. Heereman'),
#  ('M. Rongen', 'J. A. Pepper'),
#  ('M. Rongen', 'J. L. Kelley'),
#  ('M. Rongen', 'D. Góra'),
#  ('M. Rongen', 'R. Bay'),
#  ('M. Rongen', 'K. Hoshina'),
#  ('M. Rongen', 'S. De Ridder'),
#  ('M. Rongen', 'K. D. de Vries'),
#  ('M. Rongen', 'A. Hallgren'),
#  ('M. Rongen', 'K. Krings'),
#  ('M. Rongen', 'R. Gaior'),
#  ('M. Rongen', 'A. Meli'),
#  ('M. Rongen', 'A. Turcati'),
#  ('M. Rongen', 'F. Scheriau'),
#  ('M. Rongen', 'E. Blaufuss'),
#  ('M. Rongen', 'A. Sandrock'),
#  ('M. Rongen', 'B. J. Whelan'),
#  ('M. Rongen', 'A. Bernhard'),
#  ('M. Rongen', 'S. Westerhoff'),
#  ('M. Rongen', 'M. Tselengidou'),
#  ('M. Rongen', 'C. Pérez de los Heros'),
#  ('M. Rongen', 'P. Sandstrom'),
#  ('M. Rongen', 'A. Terliuk'),
#  ('M. Rongen', 'L. Paul'),
#  ('M. Rongen', 'A. Wallace'),
#  ('M. Rongen', 'T. DeYoung'),
#  ('M. Rongen', 'D. Gier'),
#  ('M. Rongen', 'T. Schmidt'),
#  ('M. Rongen', 'A. Olivas'),
#  ('M. Rongen', 'T. Glüsenkamp'),
#  ('M. Rongen', 'J. Lünemann'),
#  ('M. Rongen', 'The IceCube-Gen2 Collaboration'),
#  ('M. Rongen', 'J. P. Yanez'),
#  ('M. Rongen', 'C. Arguelles'),
#  ('M. Rongen', 'J. Kläs'),
#  ('M. Rongen', 'E. Pinat'),
#  ('M. Rongen', 'M. Wolf'),
#  ('M. Rongen', 'G. Kohnen'),
#  ('M. Rongen', 'C. Walck'),
#  ('M. Rongen', 'O. Kalekin'),
#  ('M. Rongen', 'S. Robertson'),
#  ('M. Rongen', 'H. K. M. Tanaka'),
#  ('M. Rongen', 'C. Pfendner'),
#  ('M. Rongen', 'C. -C. Fösig'),
#  ('M. Rongen', 'K. Clark'),
#  ('M. Rongen', 'D. R. Williams'),
#  ('M. Rongen', 'C. Kopper'),
#  ('M. Rongen', 'S. Toscano'),
#  ('M. Rongen', 'C. Spiering'),
#  ('M. Rongen', 'M. Kauer'),
#  ('M. Rongen', 'K. Rawlins'),
#  ('M. Rongen', 'C. Finley'),
#  ('M. Rongen', 'A. Christov'),
#  ('M. Rongen', 'D. J. Koskinen'),
#  ('M. Rongen', 'L. Gladstone'),
#  ('M. Rongen', 'S. In'),
#  ('M. Rongen', 'M. J. Larson'),
#  ('M. Rongen', 'J. Feintzeig'),
#  ('M. Rongen', 'T. Ruhe'),
#  ('M. Rongen', 'V. di Lorenzo'),
#  ('M. Rongen', 'M. Zoll'),
#  ('M. Rongen', 'G. Binder'),
#  ('M. Rongen', 'C. Wichary'),
#  ('M. Rongen', 'A. Keivani'),
#  ('M. Rongen', 'D. Seckel'),
#  ('M. Rongen', 'M. Leuermann'),
#  ('M. Rongen', 'M. Labare'),
#  ('M. Rongen', 'K. Schatto'),
#  ('M. Rongen', 'A. Obertacke'),
#  ('M. Rongen', 'M. Huber'),
#  ('M. Rongen', 'M. Richman'),
#  ('M. Rongen', 'M. H. Shaevitz'),
#  ('M. Rongen', 'M. Relich'),
#  ('M. Rongen', 'K. Hultqvist'),
#  ('M. Rongen', 'M. Sutherland'),
#  ('M. Rongen', 'B. Hansmann'),
#  ('M. Rongen', 'T. Katori'),
#  ('M. Rongen', 'T. Anderson'),
#  ('M. Rongen', 'G. M. Spiczak'),
#  ('M. Rongen', 'T. Fischer-Wasels'),
#  ('M. Rongen', 'S. Vanheule'),
#  ('M. Rongen', 'J. Haugen'),
#  ('M. Rongen', 'W. Rhode'),
#  ('M. Rongen', 'P. A. Toale'),
#  ('M. Rongen', 'D. Bose'),
#  ('M. Rongen', 'G. W. Sullivan'),
#  ('M. Rongen', 'E. del Pino Rosendo'),
#  ('M. Rongen', 'P. A. Evenson'),
#  ('M. Rongen', 'L. Lu'),
#  ('M. Rongen', 'B. Eichmann'),
#  ('M. Rongen', 'T. Montaruli'),
#  ('M. Rongen', 'Z. Marka'),
#  ('M. Rongen', 'J. L. Pinfold'),
#  ('M. Rongen', 'J. Felde'),
#  ('M. Rongen', 'C. H. Wiebusch'),
#  ('M. Rongen', 'M. Wallraff'),
#  ('M. Rongen', 'A. Ishihara'),
#  ('M. Rongen', 'G. Golup'),
#  ('M. Rongen', 'T. C. Petersen'),
#  ('M. Rongen', 'J. Braun'),
#  ('M. Rongen', 'M. Börner'),
#  ('M. Rongen', 'A. Groß'),
#  ('M. Rongen', "A. O'Murchadha"),
#  ('M. Rongen', 'A. Stasik'),
#  ('M. Rongen', 'J. Kiryluk'),
#  ('M. Rongen', 'P. O. Hulth'),
#  ('M. Rongen', 'J. Madsen'),
#  ('M. Rongen', 'N. Buzinsky'),
#  ('M. Rongen', 'N. A. Stanisha'),
#  ('M. Rongen', 'R. Maruyama'),
#  ('M. Rongen', 'D. Soldin'),
#  ('M. Rongen', 'M. Lesiak-Bzdak'),
#  ('M. Rongen', 'D. Tosi'),
#  ('M. Rongen', 'G. de Wasseige'),
#  ('M. Rongen', 'J. J. Evans'),
#  ('M. Rongen', 'U. Katz'),
#  ('M. Rongen', 'J. G. Gonzalez'),
#  ('M. Rongen', 'S. Euler'),
#  ('M. Rongen', 'D. L. Xu'),
#  ('M. Rongen', 'D. Hellwig'),
#  ('M. Rongen', 'S. Ter-Antonyan'),
#  ('M. Rongen', 'E. Jacobi'),
#  ('M. Rongen', 'S. Axani'),
#  ('M. Rongen', 'M. Rameez'),
#  ('M. Rongen', 'J. P. A. M. de André'),
#  ('M. Rongen', 'H. Wissing'),
#  ('M. Rongen', 'A. R. Fazely'),
#  ('M. Rongen', 'A. Fedynitch'),
#  ('M. Rongen', 'A. Karle'),
#  ('M. Rongen', 'M. Kroll'),
#  ('M. Rongen', 'R. Nahnhauer'),
#  ('M. Rongen', 'F. McNally'),
#  ('M. Rongen', 'K. Helbing'),
#  ('M. Rongen', 'G. Tešić'),
#  ('M. Rongen', 'J. Pütz'),
#  ('M. Rongen', 'E. Middell'),
#  ('M. Rongen', 'B. Eberhardt'),
#  ('M. Rongen', 'K. Wiebe'),
#  ('M. Rongen', 'E. Beiser'),
#  ('M. Rongen', 'K. Hanson'),
#  ('M. Rongen', 'C. Haack'),
#  ('M. Rongen', 'H. Kolanoski'),
#  ('M. Rongen', 'M. G. Aartsen'),
#  ('M. Rongen', 'K. D. Hoffman'),
#  ('M. Rongen', 'A. H. Cruz Silva'),
#  ('M. Rongen', 'L. Rädel'),
#  ('M. Rongen', 'A. Schönwald'),
#  ('M. Rongen', 'K. Jero'),
#  ('M. Rongen', 'H. -P. Bretz'),
#  ('M. Rongen', 'M. Ahlers'),
#  ('M. Rongen', 'M. Song'),
#  ('M. Rongen', 'A. Kheirandish'),
#  ('M. Rongen', 'J. A. Aguilar'),
#  ('M. Rongen', 'J. van Santen'),
#  ('M. Rongen', 'R. G. Stokstad'),
#  ('M. Rongen', 'J. Becker Tjus'),
#  ('M. Rongen', 'M. Kowalski'),
#  ('M. Rongen', 'K. Abraham'),
#  ('M. Rongen', 'D. Altmann'),
#  ('M. Rongen', 'T. C. Arlen'),
#  ('M. Rongen', 'G. C. Hill'),
#  ('M. Rongen', 'D. F. Cowen'),
#  ('M. Rongen', 'C. Wendt'),
#  ('M. Rongen', 'A. Koob'),
#  ('M. Rongen', 'E. Resconi'),
#  ('M. Rongen', 'S. Schoenen'),
#  ('M. Rongen', 'V. Baum'),
#  ('M. Rongen', 'H. Taavola'),
#  ('M. Rongen', 'A. Palazzo'),
#  ('M. Rongen', 'G. Anton'),
#  ('M. Rongen', 'R. Eagan'),
#  ('M. Rongen', 'J. Casey'),
#  ('M. Rongen', 'D. Z. Besson'),
#  ('M. Rongen', 'E. Bernardini'),
#  ('M. Rongen', 'R. Reimann'),
#  ('M. Rongen', 'D. Pieloth'),
#  ('M. Rongen', 'L. Sabbatini'),
#  ('M. Rongen', 'I. Bartos'),
#  ('M. Rongen', 'R. Konietz'),
#  ('M. Rongen', 'G. Merino'),
#  ('M. Rongen', 'J. Leuner'),
#  ('M. Rongen', 'D. R. Nygren'),
#  ('M. Rongen', 'J. J. Beatty'),
#  ('M. Rongen', 'P. Berghaus'),
#  ('M. Rongen', 'M. Stamatikos'),
#  ('M. Rongen', 'K. Holzapfel'),
#  ('M. Rongen', 'T. Stanev'),
#  ('M. Rongen', 'T. R. Wood'),
#  ('M. Rongen', 'J. M. Conrad'),
#  ('M. Rongen', 'R. Ström'),
#  ('M. Rongen', 'P. Desiati'),
#  ('M. Rongen', 'J. Kemp'),
#  ('M. Rongen', 'T. Menne'),
#  ('M. Rongen', 'J. Blumenthal'),
#  ('M. Rongen', 'T. Palczewski'),
#  ('M. Rongen', 'H. Dembinski'),
#  ('M. Rongen', 'C. Bohm'),
#  ('M. Rongen', 'J. C. Diaz-Vélez'),
#  ('M. Rongen', 'S. Flis'),
#  ('M. Rongen', 'M. Casier'),
#  ('M. Rongen', 'G. Maggi'),
#  ('M. Rongen', 'T. Stezelberger'),
#  ('M. Rongen', 'S. BenZvi'),
#  ('M. Rongen', 'M. Ackermann'),
#  ('M. Rongen', 'J. C. Davis'),
#  ('M. Rongen', ':'),
#  ('M. Rongen', 'M. N. Tobin'),
#  ('M. Rongen', 'K. B. M. Mahn'),
#  ('M. Rongen', 'S. M. Saba'),
#  ('M. Rongen', 'M. Archinger'),
#  ('M. Rongen', 'L. Wille'),
#  ('M. Rongen', 'S. C. Nowicki'),
#  ('M. Rongen', 'M. Ahrens'),
#  ('M. Rongen', 'L. Mohrmann'),
#  ('M. Rongen', 'H. Pandya'),
#  ('M. Rongen', 'M. Bissok'),
#  ('M. Rongen', 'X. W. Xu'),
#  ('M. Rongen', 'G. Kroll'),
#  ('M. Rongen', 'T. Fuchs'),
#  ('M. Rongen', 'W. Huelsnitz'),
#  ('M. Rongen', 'H. Niederhausen'),
#  ('M. Rongen', 'S. Vallecorsa'),
#  ('M. Rongen', 'A. Haj Ismail'),
#  ('M. Rongen', 'Ch. Weaver'),
#  ('M. Rongen', 'S. Hickford'),
#  ('M. Rongen', 'O. Fadiran'),
#  ('M. Rongen', 'I. Ansseau'),
#  ('M. Rongen', 'S. Yoshida'),
#  ('M. Rongen', 'A. Homeier'),
#  ('M. Rongen', 'J. Veenkamp'),
#  ('M. Rongen', 'S. Richter'),
#  ('M. Rongen', 'T. Meures'),
#  ('M. Rongen', 'G. Neer'),
#  ('M. Rongen', 'B. Riedel'),
#  ('M. Rongen', 'D. Hebecker'),
#  ('M. Rongen', 'J. LoSecco'),
#  ('M. Rongen', 'M. W. E. Smith'),
#  ('M. Rongen', 'S. R. Klein'),
#  ('M. Rongen', 'R. Morse'),
#  ('M. Rongen', 'L. Schulte'),
#  ('M. Rongen', 'K. -H. Becker'),
#  ('M. Rongen', 'K. Mase'),
#  ('M. Rongen', 'S. Miarecki'),
#  ('M. Rongen', 'J. Daughhetee'),
#  ('M. Rongen', 'A. Stößl'),
#  ('M. Rongen', 'M. Vehring'),
#  ('M. Rongen', 'N. van Eijndhoven'),
#  ('M. Rongen', 'O. Botner'),
#  ('M. Rongen', 'J. Vandenbroucke'),
#  ('M. Rongen', 'M. de With'),
#  ('M. Rongen', 'R. Shanidze'),
#  ('M. Rongen', 'Y. Xu'),
#  ('M. Rongen', 'C. Rott'),
#  ('M. Rongen', 'A. Omairat'),
#  ('M. Rongen', 'E. Middlemas'),
#  ('M. Rongen', 'T. K. Gaisser'),
#  ('M. Rongen', 'J. P. Dumm'),
#  ('M. Rongen', 'S. Seunarine'),
#  ('M. Rongen', 'R. Hoffmann'),
#  ('M. Rongen', 'J. Hignight'),
#  ('M. Rongen', 'D. Ryckbosch'),
#  ('M. Rongen', 'S. Böser'),
#  ('M. Rongen', 'X. Bai'),
#  ('M. Rongen', 'M. Schimp'),
#  ('M. Rongen', 'J. Adams'),
#  ('M. Rongen', 'C. Ha'),
#  ('M. Rongen', 'M. Dunkman'),
#  ('M. Rongen', 'D. Grant'),
#  ('M. Rongen', 'J. Posselt'),
#  ('M. Rongen', 'F. Bos'),
#  ('M. Rongen', 'M. Glagla'),
#  ('M. Rongen', 'S. Söldner-Rembold'),
#  ('M. Rongen', 'N. Whitehorn'),
#  ('M. Rongen', 'J. C. Groh'),
#  ('M. Rongen', 'T. Karg'),
#  ('M. Rongen', 'D. Bindig'),
#  ('M. Rongen', 'G. H. Collin'),
#  ('M. Rongen', 'F. Halzen'),
#  ('M. Rongen', 'L. Classen'),
#  ('M. Rongen', 'S. Schöneberg'),
#  ('M. Rongen', 'C. De Clercq'),
#  ('M. Rongen', 'M. Usner'),
#  ('M. Rongen', 'G. S. Japaridze'),
#  ('M. Rongen', 'K. Meagher'),
#  ('M. Rongen', 'N. Kurahashi'),
#  ('M. Rongen', 'K. Woschnagg'),
#  ('M. Rongen', 'K. Filimonov'),
#  ('M. Rongen', 'S. W. Barwick'),
#  ('M. Rongen', 'S. Wren'),
#  ('M. Rongen', 'B. Kaminsky'),
#  ('M. Rongen', 'T. Kuwabara'),
#  ('M. Rongen', 'C. B. Krauss'),
#  ('M. Rongen', 'J. L. Lanfranchi'),
#  ('M. Rongen', 'B. J. P. Jones'),
#  ('M. Rongen', 'J. Auffenberg'),
#  ('M. Rongen', 'H. S. Matis'),
#  ('M. Rongen', 'R. Hellauer'),
#  ('M. Rongen', 'P. B. Price'),
#  ('M. Rongen', 'A. Kappes'),
#  ('M. Rongen', 'J. Sandroos'),
#  ('M. Rongen', 'D. Chirkin'),
#  ('M. Rongen', 'M. Quinnan'),
#  ('M. Rongen', 'E. Unger'),
#  ('M. Rongen', 'I. Taboada'),
#  ('M. Rongen', 'M. Jurkovic'),
#  ('M. Rongen', 'D. J. Boersma'),
#  ('M. Rongen', 'L. Köpke'),
#  ('M. Rongen', 'R. Maunu'),
#  ('M. Rongen', 'N. L. Strotjohann'),
#  ('M. Rongen', 'S. Sarkar'),
#  ('M. Rongen', 'R. W. Moore'),
#  ('M. Rongen', 'L. Brayeur'),
#  ('M. Rongen', 'S. Tilav'),
#  ('M. Rongen', 'C. Raab'),
#  ('M. Rongen', 'S. Fahey'),
#  ('M. Rongen', 'S. Coenders'),
#  ('M. Rongen', 'D. Berley'),
#  ('M. Rongen', 'M. Vraeghe'),
#  ('M. Rongen', 'G. Yodh'),
#  ('M. Rongen', 'J. Kunnen'),
#  ('M. Usner', 'A. Taketa'),
#  ('M. Usner', 'J. Gallagher'),
#  ('M. Usner', 'H. -G. Sander'),
#  ('M. Usner', 'F. Huang'),
#  ('M. Usner', 'R. Koirala'),
#  ('M. Usner', 'M. Voge'),
#  ('M. Usner', 'U. Naumann'),
#  ('M. Usner', 'M. Stahlberg'),
#  ('M. Usner', 'M. Medici'),
#  ('M. Usner', 'T. Ehrhardt'),
#  ('M. Usner', 'M. Schmitz'),
#  ('M. Usner', 'G. T. Przybylski'),
#  ('M. Usner', 'N. Wandkowsky'),
#  ('M. Usner', 'E. Cheung'),
#  ('M. Usner', 'S. Kopper'),
#  ('M. Usner', 'S. Marka'),
#  ('M. Usner', 'A. Goldschmidt'),
#  ('M. Usner', 'K. Ghorbani'),
#  ('M. Usner', 'L. Gerhardt'),
#  ('M. Usner', 'M. Day'),
#  ('M. Usner', 'D. Heereman'),
#  ('M. Usner', 'J. A. Pepper'),
#  ('M. Usner', 'J. L. Kelley'),
#  ('M. Usner', 'D. Góra'),
#  ('M. Usner', 'R. Bay'),
#  ('M. Usner', 'K. Hoshina'),
#  ('M. Usner', 'S. De Ridder'),
#  ('M. Usner', 'K. D. de Vries'),
#  ('M. Usner', 'A. Hallgren'),
#  ('M. Usner', 'K. Krings'),
#  ('M. Usner', 'R. Gaior'),
#  ('M. Usner', 'A. Meli'),
#  ('M. Usner', 'A. Turcati'),
#  ('M. Usner', 'F. Scheriau'),
#  ('M. Usner', 'E. Blaufuss'),
#  ('M. Usner', 'A. Sandrock'),
#  ('M. Usner', 'B. J. Whelan'),
#  ('M. Usner', 'A. Bernhard'),
#  ('M. Usner', 'S. Westerhoff'),
#  ('M. Usner', 'M. Tselengidou'),
#  ('M. Usner', 'C. Pérez de los Heros'),
#  ('M. Usner', 'P. Sandstrom'),
#  ('M. Usner', 'A. Terliuk'),
#  ('M. Usner', 'L. Paul'),
#  ('M. Usner', 'A. Wallace'),
#  ('M. Usner', 'T. DeYoung'),
#  ('M. Usner', 'D. Gier'),
#  ('M. Usner', 'T. Schmidt'),
#  ('M. Usner', 'A. Olivas'),
#  ('M. Usner', 'T. Glüsenkamp'),
#  ('M. Usner', 'J. Lünemann'),
#  ('M. Usner', 'The IceCube-Gen2 Collaboration'),
#  ('M. Usner', 'J. P. Yanez'),
#  ('M. Usner', 'C. Arguelles'),
#  ('M. Usner', 'J. Kläs'),
#  ('M. Usner', 'E. Pinat'),
#  ('M. Usner', 'M. Wolf'),
#  ('M. Usner', 'G. Kohnen'),
#  ('M. Usner', 'C. Walck'),
#  ('M. Usner', 'O. Kalekin'),
#  ('M. Usner', 'S. Robertson'),
#  ('M. Usner', 'H. K. M. Tanaka'),
#  ('M. Usner', 'C. Pfendner'),
#  ('M. Usner', 'C. -C. Fösig'),
#  ('M. Usner', 'K. Clark'),
#  ('M. Usner', 'D. R. Williams'),
#  ('M. Usner', 'C. Kopper'),
#  ('M. Usner', 'S. Toscano'),
#  ('M. Usner', 'C. Spiering'),
#  ('M. Usner', 'M. Kauer'),
#  ('M. Usner', 'K. Rawlins'),
#  ('M. Usner', 'C. Finley'),
#  ('M. Usner', 'A. Christov'),
#  ('M. Usner', 'D. J. Koskinen'),
#  ('M. Usner', 'L. Gladstone'),
#  ('M. Usner', 'S. In'),
#  ('M. Usner', 'M. J. Larson'),
#  ('M. Usner', 'J. Feintzeig'),
#  ('M. Usner', 'T. Ruhe'),
#  ('M. Usner', 'V. di Lorenzo'),
#  ('M. Usner', 'M. Zoll'),
#  ('M. Usner', 'G. Binder'),
#  ('M. Usner', 'C. Wichary'),
#  ('M. Usner', 'A. Keivani'),
#  ('M. Usner', 'D. Seckel'),
#  ('M. Usner', 'M. Leuermann'),
#  ('M. Usner', 'M. Labare'),
#  ('M. Usner', 'K. Schatto'),
#  ('M. Usner', 'A. Obertacke'),
#  ('M. Usner', 'M. Huber'),
#  ('M. Usner', 'M. Richman'),
#  ('M. Usner', 'M. H. Shaevitz'),
#  ('M. Usner', 'M. Relich'),
#  ('M. Usner', 'K. Hultqvist'),
#  ('M. Usner', 'M. Sutherland'),
#  ('M. Usner', 'B. Hansmann'),
#  ('M. Usner', 'T. Katori'),
#  ('M. Usner', 'T. Anderson'),
#  ('M. Usner', 'G. M. Spiczak'),
#  ('M. Usner', 'T. Fischer-Wasels'),
#  ('M. Usner', 'S. Vanheule'),
#  ('M. Usner', 'J. Haugen'),
#  ('M. Usner', 'W. Rhode'),
#  ('M. Usner', 'P. A. Toale'),
#  ('M. Usner', 'D. Bose'),
#  ('M. Usner', 'G. W. Sullivan'),
#  ('M. Usner', 'E. del Pino Rosendo'),
#  ('M. Usner', 'P. A. Evenson'),
#  ('M. Usner', 'L. Lu'),
#  ('M. Usner', 'B. Eichmann'),
#  ('M. Usner', 'T. Montaruli'),
#  ('M. Usner', 'Z. Marka'),
#  ('M. Usner', 'J. L. Pinfold'),
#  ('M. Usner', 'J. Felde'),
#  ('M. Usner', 'C. H. Wiebusch'),
#  ('M. Usner', 'M. Wallraff'),
#  ('M. Usner', 'A. Ishihara'),
#  ('M. Usner', 'G. Golup'),
#  ('M. Usner', 'T. C. Petersen'),
#  ('M. Usner', 'J. Braun'),
#  ('M. Usner', 'M. Börner'),
#  ('M. Usner', 'A. Groß'),
#  ('M. Usner', "A. O'Murchadha"),
#  ('M. Usner', 'A. Stasik'),
#  ('M. Usner', 'J. Kiryluk'),
#  ('M. Usner', 'P. O. Hulth'),
#  ('M. Usner', 'J. Madsen'),
#  ('M. Usner', 'N. Buzinsky'),
#  ('M. Usner', 'N. A. Stanisha'),
#  ('M. Usner', 'R. Maruyama'),
#  ('M. Usner', 'D. Soldin'),
#  ('M. Usner', 'M. Lesiak-Bzdak'),
#  ('M. Usner', 'D. Tosi'),
#  ('M. Usner', 'G. de Wasseige'),
#  ('M. Usner', 'J. J. Evans'),
#  ('M. Usner', 'U. Katz'),
#  ('M. Usner', 'J. G. Gonzalez'),
#  ('M. Usner', 'S. Euler'),
#  ('M. Usner', 'D. L. Xu'),
#  ('M. Usner', 'D. Hellwig'),
#  ('M. Usner', 'S. Ter-Antonyan'),
#  ('M. Usner', 'E. Jacobi'),
#  ('M. Usner', 'S. Axani'),
#  ('M. Usner', 'M. Rameez'),
#  ('M. Usner', 'J. P. A. M. de André'),
#  ('M. Usner', 'H. Wissing'),
#  ('M. Usner', 'A. R. Fazely'),
#  ('M. Usner', 'A. Fedynitch'),
#  ('M. Usner', 'A. Karle'),
#  ('M. Usner', 'M. Kroll'),
#  ('M. Usner', 'R. Nahnhauer'),
#  ('M. Usner', 'F. McNally'),
#  ('M. Usner', 'K. Helbing'),
#  ('M. Usner', 'G. Tešić'),
#  ('M. Usner', 'J. Pütz'),
#  ('M. Usner', 'E. Middell'),
#  ('M. Usner', 'B. Eberhardt'),
#  ('M. Usner', 'K. Wiebe'),
#  ('M. Usner', 'E. Beiser'),
#  ('M. Usner', 'K. Hanson'),
#  ('M. Usner', 'C. Haack'),
#  ('M. Usner', 'H. Kolanoski'),
#  ('M. Usner', 'M. G. Aartsen'),
#  ('M. Usner', 'K. D. Hoffman'),
#  ('M. Usner', 'A. H. Cruz Silva'),
#  ('M. Usner', 'L. Rädel'),
#  ('M. Usner', 'A. Schönwald'),
#  ('M. Usner', 'K. Jero'),
#  ('M. Usner', 'H. -P. Bretz'),
#  ('M. Usner', 'M. Ahlers'),
#  ('M. Usner', 'M. Song'),
#  ('M. Usner', 'A. Kheirandish'),
#  ('M. Usner', 'J. A. Aguilar'),
#  ('M. Usner', 'J. van Santen'),
#  ('M. Usner', 'R. G. Stokstad'),
#  ('M. Usner', 'J. Becker Tjus'),
#  ('M. Usner', 'M. Kowalski'),
#  ('M. Usner', 'K. Abraham'),
#  ('M. Usner', 'D. Altmann'),
#  ('M. Usner', 'T. C. Arlen'),
#  ('M. Usner', 'G. C. Hill'),
#  ('M. Usner', 'D. F. Cowen'),
#  ('M. Usner', 'C. Wendt'),
#  ('M. Usner', 'A. Koob'),
#  ('M. Usner', 'E. Resconi'),
#  ('M. Usner', 'S. Schoenen'),
#  ('M. Usner', 'V. Baum'),
#  ('M. Usner', 'H. Taavola'),
#  ('M. Usner', 'A. Palazzo'),
#  ('M. Usner', 'G. Anton'),
#  ('M. Usner', 'R. Eagan'),
#  ('M. Usner', 'J. Casey'),
#  ('M. Usner', 'D. Z. Besson'),
#  ('M. Usner', 'E. Bernardini'),
#  ('M. Usner', 'R. Reimann'),
#  ('M. Usner', 'D. Pieloth'),
#  ('M. Usner', 'L. Sabbatini'),
#  ('M. Usner', 'I. Bartos'),
#  ('M. Usner', 'R. Konietz'),
#  ('M. Usner', 'G. Merino'),
#  ('M. Usner', 'J. Leuner'),
#  ('M. Usner', 'D. R. Nygren'),
#  ('M. Usner', 'J. J. Beatty'),
#  ('M. Usner', 'P. Berghaus'),
#  ('M. Usner', 'M. Stamatikos'),
#  ('M. Usner', 'K. Holzapfel'),
#  ('M. Usner', 'T. Stanev'),
#  ('M. Usner', 'T. R. Wood'),
#  ('M. Usner', 'J. M. Conrad'),
#  ('M. Usner', 'R. Ström'),
#  ('M. Usner', 'P. Desiati'),
#  ('M. Usner', 'J. Kemp'),
#  ('M. Usner', 'T. Menne'),
#  ('M. Usner', 'J. Blumenthal'),
#  ('M. Usner', 'T. Palczewski'),
#  ('M. Usner', 'H. Dembinski'),
#  ('M. Usner', 'C. Bohm'),
#  ('M. Usner', 'J. C. Diaz-Vélez'),
#  ('M. Usner', 'S. Flis'),
#  ('M. Usner', 'M. Casier'),
#  ('M. Usner', 'G. Maggi'),
#  ('M. Usner', 'T. Stezelberger'),
#  ('M. Usner', 'S. BenZvi'),
#  ('M. Usner', 'M. Ackermann'),
#  ('M. Usner', 'J. C. Davis'),
#  ('M. Usner', ':'),
#  ('M. Usner', 'M. N. Tobin'),
#  ('M. Usner', 'K. B. M. Mahn'),
#  ('M. Usner', 'S. M. Saba'),
#  ('M. Usner', 'M. Archinger'),
#  ('M. Usner', 'L. Wille'),
#  ('M. Usner', 'S. C. Nowicki'),
#  ('M. Usner', 'M. Ahrens'),
#  ('M. Usner', 'L. Mohrmann'),
#  ('M. Usner', 'H. Pandya'),
#  ('M. Usner', 'M. Bissok'),
#  ('M. Usner', 'X. W. Xu'),
#  ('M. Usner', 'G. Kroll'),
#  ('M. Usner', 'T. Fuchs'),
#  ('M. Usner', 'W. Huelsnitz'),
#  ('M. Usner', 'H. Niederhausen'),
#  ('M. Usner', 'S. Vallecorsa'),
#  ('M. Usner', 'A. Haj Ismail'),
#  ('M. Usner', 'Ch. Weaver'),
#  ('M. Usner', 'S. Hickford'),
#  ('M. Usner', 'O. Fadiran'),
#  ('M. Usner', 'I. Ansseau'),
#  ('M. Usner', 'S. Yoshida'),
#  ('M. Usner', 'A. Homeier'),
#  ('M. Usner', 'J. Veenkamp'),
#  ('M. Usner', 'S. Richter'),
#  ('M. Usner', 'T. Meures'),
#  ('M. Usner', 'G. Neer'),
#  ('M. Usner', 'B. Riedel'),
#  ('M. Usner', 'D. Hebecker'),
#  ('M. Usner', 'J. LoSecco'),
#  ('M. Usner', 'M. W. E. Smith'),
#  ('M. Usner', 'S. R. Klein'),
#  ('M. Usner', 'R. Morse'),
#  ('M. Usner', 'L. Schulte'),
#  ('M. Usner', 'K. -H. Becker'),
#  ('M. Usner', 'K. Mase'),
#  ('M. Usner', 'S. Miarecki'),
#  ('M. Usner', 'J. Daughhetee'),
#  ('M. Usner', 'A. Stößl'),
#  ('M. Usner', 'M. Vehring'),
#  ('M. Usner', 'N. van Eijndhoven'),
#  ('M. Usner', 'O. Botner'),
#  ('M. Usner', 'J. Vandenbroucke'),
#  ('M. Usner', 'M. de With'),
#  ('M. Usner', 'R. Shanidze'),
#  ('M. Usner', 'Y. Xu'),
#  ('M. Usner', 'C. Rott'),
#  ('M. Usner', 'A. Omairat'),
#  ('M. Usner', 'E. Middlemas'),
#  ('M. Usner', 'T. K. Gaisser'),
#  ('M. Usner', 'J. P. Dumm'),
#  ('M. Usner', 'S. Seunarine'),
#  ('M. Usner', 'R. Hoffmann'),
#  ('M. Usner', 'J. Hignight'),
#  ('M. Usner', 'D. Ryckbosch'),
#  ('M. Usner', 'S. Böser'),
#  ('M. Usner', 'X. Bai'),
#  ('M. Usner', 'M. Schimp'),
#  ('M. Usner', 'J. Adams'),
#  ('M. Usner', 'C. Ha'),
#  ('M. Usner', 'M. Dunkman'),
#  ('M. Usner', 'D. Grant'),
#  ('M. Usner', 'J. Posselt'),
#  ('M. Usner', 'F. Bos'),
#  ('M. Usner', 'M. Glagla'),
#  ('M. Usner', 'S. Söldner-Rembold'),
#  ('M. Usner', 'N. Whitehorn'),
#  ('M. Usner', 'J. C. Groh'),
#  ('M. Usner', 'T. Karg'),
#  ('M. Usner', 'D. Bindig'),
#  ('M. Usner', 'G. H. Collin'),
#  ('M. Usner', 'F. Halzen'),
#  ('M. Usner', 'L. Classen'),
#  ('M. Usner', 'S. Schöneberg'),
#  ('M. Usner', 'C. De Clercq'),
#  ('M. Usner', 'G. S. Japaridze'),
#  ('M. Usner', 'K. Meagher'),
#  ('M. Usner', 'N. Kurahashi'),
#  ('M. Usner', 'K. Woschnagg'),
#  ('M. Usner', 'K. Filimonov'),
#  ('M. Usner', 'S. W. Barwick'),
#  ('M. Usner', 'S. Wren'),
#  ('M. Usner', 'B. Kaminsky'),
#  ('M. Usner', 'T. Kuwabara'),
#  ('M. Usner', 'C. B. Krauss'),
#  ('M. Usner', 'J. L. Lanfranchi'),
#  ('M. Usner', 'B. J. P. Jones'),
#  ('M. Usner', 'J. Auffenberg'),
#  ('M. Usner', 'H. S. Matis'),
#  ('M. Usner', 'R. Hellauer'),
#  ('M. Usner', 'P. B. Price'),
#  ('M. Usner', 'A. Kappes'),
#  ('M. Usner', 'J. Sandroos'),
#  ('M. Usner', 'D. Chirkin'),
#  ('M. Usner', 'M. Quinnan'),
#  ('M. Usner', 'E. Unger'),
#  ('M. Usner', 'I. Taboada'),
#  ('M. Usner', 'M. Jurkovic'),
#  ('M. Usner', 'D. J. Boersma'),
#  ('M. Usner', 'L. Köpke'),
#  ('M. Usner', 'R. Maunu'),
#  ('M. Usner', 'N. L. Strotjohann'),
#  ('M. Usner', 'S. Sarkar'),
#  ('M. Usner', 'R. W. Moore'),
#  ('M. Usner', 'L. Brayeur'),
#  ('M. Usner', 'S. Tilav'),
#  ('M. Usner', 'C. Raab'),
#  ('M. Usner', 'S. Fahey'),
#  ('M. Usner', 'S. Coenders'),
#  ('M. Usner', 'D. Berley'),
#  ('M. Usner', 'M. Vraeghe'),
#  ('M. Usner', 'G. Yodh'),
#  ('M. Usner', 'J. Kunnen'),
#  ('J. K. Ahn', 'S. Yamashita'),
#  ('J. K. Ahn', 'S. Weibe'),
#  ('J. K. Ahn', 'T. Yoshida'),
#  ('J. K. Ahn', 'I. S. Park'),
#  ('J. K. Ahn', 'M. Sekimoto'),
#  ('J. K. Ahn', 'R. Susukita'),
#  ('J. K. Ahn', 'A. Masaike'),
#  ('J. K. Ahn', 'A. Higashi'),
#  ('J. K. Ahn', 'K. Yoshida'),
#  ('J. K. Ahn', 'M. Iinuma'),
#  ('J. K. Ahn', 'F. Takeutchi'),
#  ('J. K. Ahn', 'S. Aoki'),
#  ('J. K. Ahn', 'R. Takashima'),
#  ('J. K. Ahn', 'Y. Matsuyama'),
#  ('J. K. Ahn', 'S. Yakkaichi'),
#  ('J. K. Ahn', 'Y. Itow'),
#  ('J. K. Ahn', 'Y. Goto'),
#  ('J. K. Ahn', 'Y. Matsuda'),
#  ('J. K. Ahn', 'K. Imai'),
#  ('J. K. Ahn', 'H. Enyo'),
#  ('J. K. Ahn', 'T. Iijima'),
#  ('J. K. Ahn', 'K. S. Chung'),
#  ('J. K. Ahn', 'M. Yoshida'),
#  ('J. K. Ahn', 'I. Nomura'),
#  ('J. K. Ahn', 'N. Saito'),
#  ('J. K. Ahn', 'C. Nagoshi'),
#  ('J. K. Ahn', 'Y. M. Shin'),
#  ('J. K. Ahn', 'J. M. Lee'),
#  ('J. K. Ahn', 'M. Ieiri'),
#  ('J. K. Ahn', 'S. Makino'),
#  ('J. K. Ahn', 'M. S. Chung'),
#  ('J. K. Ahn', 'P. Tlusty'),
#  ('J. K. Ahn', 'T. Fukuda'),
#  ('J. K. Ahn', 'K. S. Sim'),
#  ('J. K. Ahn', 'H. Funahashi'),
#  ('J. K. Ahn', 'S. Mihara'),
#  ('T. T. Yamamoto', 'Y. Iida'),
#  ('T. T. Yamamoto', 'Y. Bamba'),
#  ('T. T. Yamamoto', 'S. Toriumi'),
#  ('T. T. Yamamoto', 'A. Asai'),
#  ('T. T. Yamamoto', 'K. Kusano'),
#  ('M. Schmitz', 'A. Taketa'),
#  ('M. Schmitz', 'J. Gallagher'),
#  ('M. Schmitz', 'H. -G. Sander'),
#  ('M. Schmitz', 'F. Huang'),
#  ('M. Schmitz', 'R. Koirala'),
#  ('M. Schmitz', 'M. Voge'),
#  ('M. Schmitz', 'U. Naumann'),
#  ('M. Schmitz', 'M. Stahlberg'),
#  ('M. Schmitz', 'M. Medici'),
#  ('M. Schmitz', 'T. Ehrhardt'),
#  ('M. Schmitz', 'A. Stasik'),
#  ('M. Schmitz', 'G. T. Przybylski'),
#  ('M. Schmitz', 'N. Wandkowsky'),
#  ('M. Schmitz', 'E. Cheung'),
#  ('M. Schmitz', 'S. Kopper'),
#  ('M. Schmitz', 'S. Marka'),
#  ('M. Schmitz', 'A. Goldschmidt'),
#  ('M. Schmitz', 'K. Ghorbani'),
#  ('M. Schmitz', 'L. Gerhardt'),
#  ('M. Schmitz', 'M. Day'),
#  ('M. Schmitz', 'D. Heereman'),
#  ('M. Schmitz', 'J. A. Pepper'),
#  ('M. Schmitz', 'J. L. Kelley'),
#  ('M. Schmitz', 'D. Góra'),
#  ('M. Schmitz', 'R. Bay'),
#  ('M. Schmitz', 'K. Hoshina'),
#  ('M. Schmitz', 'S. De Ridder'),
#  ('M. Schmitz', 'K. D. de Vries'),
#  ('M. Schmitz', 'A. Hallgren'),
#  ('M. Schmitz', 'K. Krings'),
#  ('M. Schmitz', 'R. Gaior'),
#  ('M. Schmitz', 'A. Meli'),
#  ('M. Schmitz', 'A. Turcati'),
#  ('M. Schmitz', 'F. Scheriau'),
#  ('M. Schmitz', 'E. Blaufuss'),
#  ('M. Schmitz', 'A. Sandrock'),
#  ('M. Schmitz', 'B. J. Whelan'),
#  ('M. Schmitz', 'A. Bernhard'),
#  ('M. Schmitz', 'S. Westerhoff'),
#  ('M. Schmitz', 'M. Tselengidou'),
#  ('M. Schmitz', 'C. Pérez de los Heros'),
#  ('M. Schmitz', 'P. Sandstrom'),
#  ('M. Schmitz', 'A. Terliuk'),
#  ('M. Schmitz', 'L. Paul'),
#  ('M. Schmitz', 'A. Wallace'),
#  ('M. Schmitz', 'T. DeYoung'),
#  ('M. Schmitz', 'D. Gier'),
#  ('M. Schmitz', 'T. Schmidt'),
#  ('M. Schmitz', 'A. Olivas'),
#  ('M. Schmitz', 'T. Glüsenkamp'),
#  ('M. Schmitz', 'J. Lünemann'),
#  ('M. Schmitz', 'The IceCube-Gen2 Collaboration'),
#  ('M. Schmitz', 'J. P. Yanez'),
#  ('M. Schmitz', 'C. Arguelles'),
#  ('M. Schmitz', 'J. Kläs'),
#  ('M. Schmitz', 'E. Pinat'),
#  ('M. Schmitz', 'M. Wolf'),
#  ('M. Schmitz', 'G. Kohnen'),
#  ('M. Schmitz', 'C. Walck'),
#  ('M. Schmitz', 'O. Kalekin'),
#  ('M. Schmitz', 'S. Robertson'),
#  ('M. Schmitz', 'H. K. M. Tanaka'),
#  ('M. Schmitz', 'C. Pfendner'),
#  ('M. Schmitz', 'C. -C. Fösig'),
#  ('M. Schmitz', 'K. Clark'),
#  ('M. Schmitz', 'D. R. Williams'),
#  ('M. Schmitz', 'C. Kopper'),
#  ('M. Schmitz', 'S. Toscano'),
#  ('M. Schmitz', 'C. Spiering'),
#  ('M. Schmitz', 'M. Kauer'),
#  ('M. Schmitz', 'K. Rawlins'),
#  ('M. Schmitz', 'C. Finley'),
#  ('M. Schmitz', 'A. Christov'),
#  ('M. Schmitz', 'D. J. Koskinen'),
#  ('M. Schmitz', 'L. Gladstone'),
#  ('M. Schmitz', 'S. In'),
#  ('M. Schmitz', 'M. J. Larson'),
#  ('M. Schmitz', 'J. Feintzeig'),
#  ('M. Schmitz', 'T. Ruhe'),
#  ('M. Schmitz', 'V. di Lorenzo'),
#  ('M. Schmitz', 'M. Zoll'),
#  ('M. Schmitz', 'G. Binder'),
#  ('M. Schmitz', 'C. Wichary'),
#  ('M. Schmitz', 'A. Keivani'),
#  ('M. Schmitz', 'D. Seckel'),
#  ('M. Schmitz', 'M. Leuermann'),
#  ('M. Schmitz', 'M. Labare'),
#  ('M. Schmitz', 'K. Schatto'),
#  ('M. Schmitz', 'A. Obertacke'),
#  ('M. Schmitz', 'M. Huber'),
#  ('M. Schmitz', 'M. Richman'),
#  ('M. Schmitz', 'M. H. Shaevitz'),
#  ('M. Schmitz', 'M. Relich'),
#  ('M. Schmitz', 'K. Hultqvist'),
#  ('M. Schmitz', 'M. Sutherland'),
#  ('M. Schmitz', 'B. Hansmann'),
#  ('M. Schmitz', 'T. Katori'),
#  ('M. Schmitz', 'T. Anderson'),
#  ('M. Schmitz', 'G. M. Spiczak'),
#  ('M. Schmitz', 'T. Fischer-Wasels'),
#  ('M. Schmitz', 'S. Vanheule'),
#  ('M. Schmitz', 'J. Haugen'),
#  ('M. Schmitz', 'W. Rhode'),
#  ('M. Schmitz', 'P. A. Toale'),
#  ('M. Schmitz', 'D. Bose'),
#  ('M. Schmitz', 'G. W. Sullivan'),
#  ('M. Schmitz', 'E. del Pino Rosendo'),
#  ('M. Schmitz', 'P. A. Evenson'),
#  ('M. Schmitz', 'L. Lu'),
#  ('M. Schmitz', 'B. Eichmann'),
#  ('M. Schmitz', 'T. Montaruli'),
#  ('M. Schmitz', 'Z. Marka'),
#  ('M. Schmitz', 'J. L. Pinfold'),
#  ('M. Schmitz', 'J. Felde'),
#  ('M. Schmitz', 'C. H. Wiebusch'),
#  ('M. Schmitz', 'M. Wallraff'),
#  ('M. Schmitz', 'A. Ishihara'),
#  ('M. Schmitz', 'G. Golup'),
#  ('M. Schmitz', 'T. C. Petersen'),
#  ('M. Schmitz', 'J. Braun'),
#  ('M. Schmitz', 'M. Börner'),
#  ('M. Schmitz', 'A. Groß'),
#  ('M. Schmitz', "A. O'Murchadha"),
#  ('M. Schmitz', 'J. Kiryluk'),
#  ('M. Schmitz', 'P. O. Hulth'),
#  ('M. Schmitz', 'J. Madsen'),
#  ('M. Schmitz', 'N. Buzinsky'),
#  ('M. Schmitz', 'N. A. Stanisha'),
#  ('M. Schmitz', 'R. Maruyama'),
#  ('M. Schmitz', 'D. Soldin'),
#  ('M. Schmitz', 'M. Lesiak-Bzdak'),
#  ('M. Schmitz', 'D. Tosi'),
#  ('M. Schmitz', 'G. de Wasseige'),
#  ('M. Schmitz', 'J. J. Evans'),
#  ('M. Schmitz', 'U. Katz'),
#  ('M. Schmitz', 'J. G. Gonzalez'),
#  ('M. Schmitz', 'S. Euler'),
#  ('M. Schmitz', 'D. L. Xu'),
#  ('M. Schmitz', 'D. Hellwig'),
#  ('M. Schmitz', 'S. Ter-Antonyan'),
#  ('M. Schmitz', 'E. Jacobi'),
#  ('M. Schmitz', 'S. Axani'),
#  ('M. Schmitz', 'M. Rameez'),
#  ('M. Schmitz', 'J. P. A. M. de André'),
#  ('M. Schmitz', 'H. Wissing'),
#  ('M. Schmitz', 'A. R. Fazely'),
#  ('M. Schmitz', 'A. Fedynitch'),
#  ('M. Schmitz', 'A. Karle'),
#  ('M. Schmitz', 'M. Kroll'),
#  ('M. Schmitz', 'R. Nahnhauer'),
#  ('M. Schmitz', 'F. McNally'),
#  ('M. Schmitz', 'K. Helbing'),
#  ('M. Schmitz', 'G. Tešić'),
#  ('M. Schmitz', 'J. Pütz'),
#  ('M. Schmitz', 'E. Middell'),
#  ('M. Schmitz', 'B. Eberhardt'),
#  ('M. Schmitz', 'K. Wiebe'),
#  ('M. Schmitz', 'E. Beiser'),
#  ('M. Schmitz', 'K. Hanson'),
#  ('M. Schmitz', 'C. Haack'),
#  ('M. Schmitz', 'H. Kolanoski'),
#  ('M. Schmitz', 'M. G. Aartsen'),
#  ('M. Schmitz', 'K. D. Hoffman'),
#  ('M. Schmitz', 'A. H. Cruz Silva'),
#  ('M. Schmitz', 'L. Rädel'),
#  ('M. Schmitz', 'A. Schönwald'),
#  ('M. Schmitz', 'K. Jero'),
#  ('M. Schmitz', 'H. -P. Bretz'),
#  ('M. Schmitz', 'M. Ahlers'),
#  ('M. Schmitz', 'M. Song'),
#  ('M. Schmitz', 'A. Kheirandish'),
#  ('M. Schmitz', 'J. A. Aguilar'),
#  ('M. Schmitz', 'J. van Santen'),
#  ('M. Schmitz', 'R. G. Stokstad'),
#  ('M. Schmitz', 'J. Becker Tjus'),
#  ('M. Schmitz', 'M. Kowalski'),
#  ('M. Schmitz', 'K. Abraham'),
#  ('M. Schmitz', 'D. Altmann'),
#  ('M. Schmitz', 'T. C. Arlen'),
#  ('M. Schmitz', 'G. C. Hill'),
#  ('M. Schmitz', 'D. F. Cowen'),
#  ('M. Schmitz', 'C. Wendt'),
#  ('M. Schmitz', 'A. Koob'),
#  ('M. Schmitz', 'E. Resconi'),
#  ('M. Schmitz', 'S. Schoenen'),
#  ('M. Schmitz', 'V. Baum'),
#  ('M. Schmitz', 'H. Taavola'),
#  ('M. Schmitz', 'A. Palazzo'),
#  ('M. Schmitz', 'G. Anton'),
#  ('M. Schmitz', 'R. Eagan'),
#  ('M. Schmitz', 'J. Casey'),
#  ('M. Schmitz', 'D. Z. Besson'),
#  ('M. Schmitz', 'E. Bernardini'),
#  ('M. Schmitz', 'R. Reimann'),
#  ...]

# %%
G.degree('M. Schmitz')
# Out:
# 340

# %%
a['feed']['entry'][0]['title']
# Out:
# 'Determining Graphene Adhesion via Substrate-regulated Morphology of\n  Graphene'

# %%
a = search_all('Graphene',0,10)

# %%
a['feed']['entry']
# Out:
# [OrderedDict([('id', 'http://arxiv.org/abs/1111.2286v1'),
#               ('updated', '2011-11-09T17:38:30Z'),
#               ('published', '2011-11-09T17:38:30Z'),
#               ('title',
#                'Determining Graphene Adhesion via Substrate-regulated Morphology of\n  Graphene'),
#               ('summary',
#                'Understanding the adhesion between graphene and other materials is crucial\nfor achieving more reliable graphene-based applications in electronic devices\nand nanocomposites. The ultra-thin profile of graphene, however, poses\nsignificant challenge to direct measurement of its adhesion property using\nconventional approaches. We show that there is a strong correlation between the\nmorphology of graphene on a compliant substrate with patterned surface and the\ngraphene-substrate adhesion. We establish an analytic model to quantitatively\ndetermine such a strong correlation. Results show that, depending on the\ngraphene-substrate adhesion, number of graphene layers and substrate stiffness,\ngraphene exhibits two distinct types of morphology: I) graphene remains bonded\nto the substrate and corrugates to an amplitude up to that of the substrate\nsurface patterns; II) graphene debonds from the substrate and remains flat on\ntop of the substrate surface patterns. The sharp transition between these two\ntypes of graphene morphology occurs at a critical adhesion between the graphene\nand the compliant substrate material. These results potentially open up a\nfeasible pathway to measuring the adhesion property of graphene.'),
#               ('author',
#                [OrderedDict([('name', 'Zhao Zhang')]),
#                 OrderedDict([('name', 'Teng Li')])]),
#               ('arxiv:doi',
#                OrderedDict([('@xmlns:arxiv', 'http://arxiv.org/schemas/atom'),
#                             ('#text', '10.1063/1.3656720')])),
#               ('link',
#                [OrderedDict([('@title', 'doi'),
#                              ('@href', 'http://dx.doi.org/10.1063/1.3656720'),
#                              ('@rel', 'related')]),
#                 OrderedDict([('@href', 'http://arxiv.org/abs/1111.2286v1'),
#                              ('@rel', 'alternate'),
#                              ('@type', 'text/html')]),
#                 OrderedDict([('@title', 'pdf'),
#                              ('@href', 'http://arxiv.org/pdf/1111.2286v1'),
#                              ('@rel', 'related'),
#                              ('@type', 'application/pdf')])]),
#               ('arxiv:comment',
#                OrderedDict([('@xmlns:arxiv', 'http://arxiv.org/schemas/atom'),
#                             ('#text', '17 pages, 4 figures')])),
#               ('arxiv:journal_ref',
#                OrderedDict([('@xmlns:arxiv', 'http://arxiv.org/schemas/atom'),
#                             ('#text',
#                              'Journal of Applied Physics, 110, 083526 (2011)')])),
#               ('arxiv:primary_category',
#                OrderedDict([('@xmlns:arxiv', 'http://arxiv.org/schemas/atom'),
#                             ('@term', 'cond-mat.mtrl-sci'),
#                             ('@scheme', 'http://arxiv.org/schemas/atom')])),
#               ('category',
#                [OrderedDict([('@term', 'cond-mat.mtrl-sci'),
#                              ('@scheme', 'http://arxiv.org/schemas/atom')]),
#                 OrderedDict([('@term', 'cond-mat.mes-hall'),
#                              ('@scheme',
#                               'http://arxiv.org/schemas/atom')])])]),
#  OrderedDict([('id', 'http://arxiv.org/abs/0806.4074v1'),
#               ('updated', '2008-06-25T11:34:42Z'),
#               ('published', '2008-06-25T11:34:42Z'),
#               ('title',
#                'Morphology and flexibility of graphene and few-layer graphene on various\n  substrates'),
#               ('summary',
#                'We report on detailed microscopy studies of graphene and few-layer-graphene\nproduced by mechanical exfoliation on various semi-conducting substrates. We\ndemonstrate the possibility to prepare and analyze graphene on (001)-GaAs,\nmanganese p-doped (001)-GaAs and InGaAs substrates. The morphology of graphene\non these substrates was investigated by scanning electron and atomic force\nmicroscopy and compared to layers on silicon oxide. It was found that graphene\nsheets strongly follow the texture of the sustaining substrates independent on\ndoping, polarity or roughness. Furthermore resist residues exist on top of\ngraphene after a lithographic step. The obtained results provide the\nopportunity to research the graphene-substrate interactions.'),
#               ('author',
#                [OrderedDict([('name', 'U. Stöberl')]),
#                 OrderedDict([('name', 'U. Wurstbauer')]),
#                 OrderedDict([('name', 'W. Wegscheider')]),
#                 OrderedDict([('name', 'D. Weiss')]),
#                 OrderedDict([('name', 'J. Eroms')])]),
#               ('arxiv:doi',
#                OrderedDict([('@xmlns:arxiv', 'http://arxiv.org/schemas/atom'),
#                             ('#text', '10.1063/1.2968310')])),
#               ('link',
#                [OrderedDict([('@title', 'doi'),
#                              ('@href', 'http://dx.doi.org/10.1063/1.2968310'),
#                              ('@rel', 'related')]),
#                 OrderedDict([('@href', 'http://arxiv.org/abs/0806.4074v1'),
#                              ('@rel', 'alternate'),
#                              ('@type', 'text/html')]),
#                 OrderedDict([('@title', 'pdf'),
#                              ('@href', 'http://arxiv.org/pdf/0806.4074v1'),
#                              ('@rel', 'related'),
#                              ('@type', 'application/pdf')])]),
#               ('arxiv:primary_category',
#                OrderedDict([('@xmlns:arxiv', 'http://arxiv.org/schemas/atom'),
#                             ('@term', 'cond-mat.mtrl-sci'),
#                             ('@scheme', 'http://arxiv.org/schemas/atom')])),
#               ('category',
#                OrderedDict([('@term', 'cond-mat.mtrl-sci'),
#                             ('@scheme', 'http://arxiv.org/schemas/atom')]))]),
#  OrderedDict([('id', 'http://arxiv.org/abs/1407.4389v1'),
#               ('updated', '2014-07-16T17:32:06Z'),
#               ('published', '2014-07-16T17:32:06Z'),
#               ('title',
#                'Electronic and magnetic properties of the graphene/Eu/Ni(111) hybrid\n  system'),
#               ('summary',
#                'The electronic and magnetic properties of the graphene/Eu/Ni(111)\nintercalation-like system are studied in the framework of the GGA+U approach\nwith dispersive interactions taken into account. Intercalation of monoatomic Eu\nlayer underneath graphene on Ni(111) leads to the drastic changes of the\nelectronic structure of graphene compared to free-standing graphene as well as\ngraphene/Ni(111). The strong influence of the spin-polarised Eu 4f states,\ncrossing the graphene-derived $\\pi$ states, on magnetic properties of graphene\nand on spin-filtering properties of the graphene/Eu/Ni(111) trilayer is\ndiscussed.'),
#               ('author',
#                [OrderedDict([('name', 'E. N. Voloshina')]),
#                 OrderedDict([('name', 'Yu. S. Dedkov')])]),
#               ('arxiv:doi',
#                OrderedDict([('@xmlns:arxiv', 'http://arxiv.org/schemas/atom'),
#                             ('#text', '10.5560/ZNA.2014-0012')])),
#               ('link',
#                [OrderedDict([('@title', 'doi'),
#                              ('@href',
#                               'http://dx.doi.org/10.5560/ZNA.2014-0012'),
#                              ('@rel', 'related')]),
#                 OrderedDict([('@href', 'http://arxiv.org/abs/1407.4389v1'),
#                              ('@rel', 'alternate'),
#                              ('@type', 'text/html')]),
#                 OrderedDict([('@title', 'pdf'),
#                              ('@href', 'http://arxiv.org/pdf/1407.4389v1'),
#                              ('@rel', 'related'),
#                              ('@type', 'application/pdf')])]),
#               ('arxiv:comment',
#                OrderedDict([('@xmlns:arxiv', 'http://arxiv.org/schemas/atom'),
#                             ('#text', 'manuscript and figures')])),
#               ('arxiv:journal_ref',
#                OrderedDict([('@xmlns:arxiv', 'http://arxiv.org/schemas/atom'),
#                             ('#text', 'Z. Naturforsch. 69a, 297 (2014)')])),
#               ('arxiv:primary_category',
#                OrderedDict([('@xmlns:arxiv', 'http://arxiv.org/schemas/atom'),
#                             ('@term', 'cond-mat.mtrl-sci'),
#                             ('@scheme', 'http://arxiv.org/schemas/atom')])),
#               ('category',
#                OrderedDict([('@term', 'cond-mat.mtrl-sci'),
#                             ('@scheme', 'http://arxiv.org/schemas/atom')]))]),
#  OrderedDict([('id', 'http://arxiv.org/abs/1403.7964v1'),
#               ('updated', '2014-03-31T12:15:18Z'),
#               ('published', '2014-03-31T12:15:18Z'),
#               ('title',
#                'Crystal orientation relation and macroscopic surface roughness in\n  hetero-epitaxially grown graphene on Cu/mica'),
#               ('summary',
#                'A clean, flat and orientation-identified graphene on a substrate is in high\ndemand for graphene electronics. In this study, the hetero-epitaxial graphene\ngrowth on Cu(111)/mica(001) by chemical vapor deposition is investigated to\ncheck the applicability for the top-gate insulator research on graphene as well\nas the graphene channel research by transferring graphene on SiO2/Si\nsubstrates. After adjusting the graphene-growth condition, the surface\nroughness of the graphene/Cu/mica substrate and the average smooth area are\n~0.34 nm and ~100 um2, respectively. The orientation of graphene in the\ngraphene/Cu/mica substrate can be identified by the hexagonal void morphology\nof Cu. Moreover, we demonstrate the relatively high mobility of ~4500 cm2V-1s-1\nin graphene transferred on the SiO2/Si substrate. These results suggest that\nthe present graphene/Cu/mica substrate can be used for top-gate insulator\nresearch on graphene.'),
#               ('author',
#                [OrderedDict([('name', 'J. L. Qi')]),
#                 OrderedDict([('name', 'K. Nagashio')]),
#                 OrderedDict([('name', 'T. Nishimura')]),
#                 OrderedDict([('name', 'A. Toriumi')])]),
#               ('arxiv:doi',
#                OrderedDict([('@xmlns:arxiv', 'http://arxiv.org/schemas/atom'),
#                             ('#text', '10.1088/0957-4484/25/18/185602')])),
#               ('link',
#                [OrderedDict([('@title', 'doi'),
#                              ('@href',
#                               'http://dx.doi.org/10.1088/0957-4484/25/18/185602'),
#                              ('@rel', 'related')]),
#                 OrderedDict([('@href', 'http://arxiv.org/abs/1403.7964v1'),
#                              ('@rel', 'alternate'),
#                              ('@type', 'text/html')]),
#                 OrderedDict([('@title', 'pdf'),
#                              ('@href', 'http://arxiv.org/pdf/1403.7964v1'),
#                              ('@rel', 'related'),
#                              ('@type', 'application/pdf')])]),
#               ('arxiv:comment',
#                OrderedDict([('@xmlns:arxiv', 'http://arxiv.org/schemas/atom'),
#                             ('#text', 'will appear in nanotechnology')])),
#               ('arxiv:journal_ref',
#                OrderedDict([('@xmlns:arxiv', 'http://arxiv.org/schemas/atom'),
#                             ('#text', 'Nanotechnology,2014, 25, 185602')])),
#               ('arxiv:primary_category',
#                OrderedDict([('@xmlns:arxiv', 'http://arxiv.org/schemas/atom'),
#                             ('@term', 'cond-mat.mtrl-sci'),
#                             ('@scheme', 'http://arxiv.org/schemas/atom')])),
#               ('category',
#                OrderedDict([('@term', 'cond-mat.mtrl-sci'),
#                             ('@scheme', 'http://arxiv.org/schemas/atom')]))]),
#  OrderedDict([('id', 'http://arxiv.org/abs/1303.0768v1'),
#               ('updated', '2013-03-01T20:24:56Z'),
#               ('published', '2013-03-01T20:24:56Z'),
#               ('title',
#                'Localization of metallicity and magnetic properties of graphene and of\n  graphene nanoribbons doped with boron clusters'),
#               ('summary',
#                'As a possible way of modifying the intrinsic properties of graphene we study\nthe doping of graphene by embedded boron clusters with density functional\ntheory. Cluster doping is technologically relevant as the cluster implantation\ntechnique can be readily applied to graphene. We find that B7 clusters embedded\ninto graphene and graphene nanoribbons are structurally stable and locally\nmetallize the system. This is done both by the reduction of the Fermi energy\nand by the introduction of boron states near the Fermi level. A linear chain of\nboron clusters forms a metallic "wire" inside the graphene matrix. In a zigzag\nedge graphene nanoribbon the cluster-related states tend to hybridize with the\nedge and bulk states. The magnetism in boron doped graphene systems is\ngenerally very weak. The presence of boron clusters weakens the edge magnetism\nin zigzag edge graphene nanoribbon, rather than making the system appropriate\nfor spintronics. Thus the doping of graphene with the cluster implantation\ntechnique might be a viable technique to locally metallize graphene without\ndestroying its attractive bulk properties.'),
#               ('author',
#                [OrderedDict([('name', 'Cem Ozdogan')]),
#                 OrderedDict([('name', 'Jens Kunstmann')]),
#                 OrderedDict([('name', 'Alexander Quandt')])]),
#               ('arxiv:doi',
#                OrderedDict([('@xmlns:arxiv', 'http://arxiv.org/schemas/atom'),
#                             ('#text', '10.1080/14786435.2014.895875')])),
#               ('link',
#                [OrderedDict([('@title', 'doi'),
#                              ('@href',
#                               'http://dx.doi.org/10.1080/14786435.2014.895875'),
#                              ('@rel', 'related')]),
#                 OrderedDict([('@href', 'http://arxiv.org/abs/1303.0768v1'),
#                              ('@rel', 'alternate'),
#                              ('@type', 'text/html')]),
#                 OrderedDict([('@title', 'pdf'),
#                              ('@href', 'http://arxiv.org/pdf/1303.0768v1'),
#                              ('@rel', 'related'),
#                              ('@type', 'application/pdf')])]),
#               ('arxiv:primary_category',
#                OrderedDict([('@xmlns:arxiv', 'http://arxiv.org/schemas/atom'),
#                             ('@term', 'cond-mat.mtrl-sci'),
#                             ('@scheme', 'http://arxiv.org/schemas/atom')])),
#               ('category',
#                OrderedDict([('@term', 'cond-mat.mtrl-sci'),
#                             ('@scheme', 'http://arxiv.org/schemas/atom')]))]),
#  OrderedDict([('id', 'http://arxiv.org/abs/1406.3159v1'),
#               ('updated', '2014-06-12T09:11:23Z'),
#               ('published', '2014-06-12T09:11:23Z'),
#               ('title',
#                'Influence of graphene-substrate interactions on configurations of\n  organic molecules on graphene: pentacene/epitaxial graphene/SiC'),
#               ('summary',
#                'Pentacene has been used widely in organic devices, and the interface\nstructure between pentacene and a substrate is known to significantly influence\ndevice performances. Here we demonstrate that molecular ordering of pentacene\non graphene depends on the interaction between graphene and its underlying SiC\nsubstrate. The adsorption of pentacene molecules on zero-layer and single-layer\ngraphene, which were grown on a Sifaced 6H-SiC(0001) wafer, was studied using\nscanning tunneling microscopy (STM). Pentacene molecules form a quasi-amorphous\nlayer on zero-layer graphene which interacts strongly with the underlying SiC\nsubstrate. In contrast, they form a uniformly ordered layer on the single-layer\ngraphene having a weak graphene-SiC interaction. Furthermore, we could change\nthe configuration of pentacene molecules on the singlelayer graphene by using\nSTM tips. The results suggest that the molecular ordering of pentacene on\ngraphene and the pentacene/graphene interface structure can be controlled by a\ngraphene-substrate interaction.'),
#               ('author',
#                [OrderedDict([('name', 'W. Jung')]),
#                 OrderedDict([('name', 'D. -H. Oh')]),
#                 OrderedDict([('name', 'I. Song')]),
#                 OrderedDict([('name', 'H. -C. Shin')]),
#                 OrderedDict([('name', 'S. J. Ahn')]),
#                 OrderedDict([('name', 'Y. Moon')]),
#                 OrderedDict([('name', 'C. -Y. Park')]),
#                 OrderedDict([('name', 'J. R. Ahn')])]),
#               ('arxiv:doi',
#                OrderedDict([('@xmlns:arxiv', 'http://arxiv.org/schemas/atom'),
#                             ('#text', '10.1063/1.4893880')])),
#               ('link',
#                [OrderedDict([('@title', 'doi'),
#                              ('@href', 'http://dx.doi.org/10.1063/1.4893880'),
#                              ('@rel', 'related')]),
#                 OrderedDict([('@href', 'http://arxiv.org/abs/1406.3159v1'),
#                              ('@rel', 'alternate'),
#                              ('@type', 'text/html')]),
#                 OrderedDict([('@title', 'pdf'),
#                              ('@href', 'http://arxiv.org/pdf/1406.3159v1'),
#                              ('@rel', 'related'),
#                              ('@type', 'application/pdf')])]),
#               ('arxiv:comment',
#                OrderedDict([('@xmlns:arxiv', 'http://arxiv.org/schemas/atom'),
#                             ('#text', '13 pages, 4 figures')])),
#               ('arxiv:primary_category',
#                OrderedDict([('@xmlns:arxiv', 'http://arxiv.org/schemas/atom'),
#                             ('@term', 'cond-mat.mes-hall'),
#                             ('@scheme', 'http://arxiv.org/schemas/atom')])),
#               ('category',
#                [OrderedDict([('@term', 'cond-mat.mes-hall'),
#                              ('@scheme', 'http://arxiv.org/schemas/atom')]),
#                 OrderedDict([('@term', 'cond-mat.mtrl-sci'),
#                              ('@scheme',
#                               'http://arxiv.org/schemas/atom')])])]),
#  OrderedDict([('id', 'http://arxiv.org/abs/1410.4857v1'),
#               ('updated', '2014-10-17T20:42:40Z'),
#               ('published', '2014-10-17T20:42:40Z'),
#               ('title',
#                'Direct dry transfer of chemical vapor deposition graphene to polymeric\n  substrates'),
#               ('summary',
#                'We demonstrate the direct dry transfer of large area Chemical Vapor\nDeposition graphene to several polymers (low density polyethylene, high density\npolyethylene, polystyrene, polylactide acid and\npoly(vinylidenefluoride-co-trifluoroethylene) by means of only moderate heat\nand pressure, and the later mechanical peeling of the original graphene\nsubstrate. Simulations of the graphene-polymer interactions, rheological tests\nand graphene transfer at various experimental conditions show that controlling\nthe graphene-polymer interface is the key to controlling graphene transfer.\nRaman spectroscopy and Optical Microscopy were used to identify and quantify\ngraphene transferred to the polymer substrates. The results showed that the\namount of graphene transferred to the polymer, from no-graphene to full\ngraphene transfers, can be achieved by fine tuning the transfer conditions. As\na result of the direct dry transfer technique, the graphene-polymer adhesion\nbeing stronger than graphene to Si/SiO2 wafer.'),
#               ('author',
#                [OrderedDict([('name', 'Guilhermino J. M. Fechine')]),
#                 OrderedDict([('name', 'Inigo Martin-Fernandez')]),
#                 OrderedDict([('name', 'George Yiapanis')]),
#                 OrderedDict([('name', 'Ricardo V. Bof de Oliveira')]),
#                 OrderedDict([('name', 'Xiao Hu')]),
#                 OrderedDict([('name', 'Irene Yarovsky')]),
#                 OrderedDict([('name', 'Antonio H. Castro Neto')]),
#                 OrderedDict([('name', 'Barbaros Ozyilmaz')])]),
#               ('arxiv:comment',
#                OrderedDict([('@xmlns:arxiv', 'http://arxiv.org/schemas/atom'),
#                             ('#text', '23 pages, 7 figures, 1 table')])),
#               ('link',
#                [OrderedDict([('@href', 'http://arxiv.org/abs/1410.4857v1'),
#                              ('@rel', 'alternate'),
#                              ('@type', 'text/html')]),
#                 OrderedDict([('@title', 'pdf'),
#                              ('@href', 'http://arxiv.org/pdf/1410.4857v1'),
#                              ('@rel', 'related'),
#                              ('@type', 'application/pdf')])]),
#               ('arxiv:primary_category',
#                OrderedDict([('@xmlns:arxiv', 'http://arxiv.org/schemas/atom'),
#                             ('@term', 'cond-mat.mtrl-sci'),
#                             ('@scheme', 'http://arxiv.org/schemas/atom')])),
#               ('category',
#                OrderedDict([('@term', 'cond-mat.mtrl-sci'),
#                             ('@scheme', 'http://arxiv.org/schemas/atom')]))]),
#  OrderedDict([('id', 'http://arxiv.org/abs/1606.00471v2'),
#               ('updated', '2016-06-04T18:55:56Z'),
#               ('published', '2016-06-01T21:05:33Z'),
#               ('title',
#                'Graphene-plasmon polaritons: From fundamental properties to potential\n  applications'),
#               ('summary',
#                'With the unique possibilities for controlling light in nanoscale devices,\ngraphene plasmonics has opened new perspectives to the nanophotonics community\nwith potential applications in metamaterials, modulators, photodetectors, and\nsensors. This paper briefly reviews the recent exciting progress in graphene\nplasmonics. We begin with a general description for optical properties of\ngraphene, particularly focusing on the dispersion of graphene-plasmon\npolaritons. The dispersion relation of graphene-plasmon polaritons of spatially\nextended graphene is expressed in terms of the local response limit with\nintraband contribution. With this theoretical foundation of graphene-plasmon\npolaritons, we then discuss recent exciting progress, paying specific attention\nto the following topics: excitation of graphene plasmon polaritons,\nelectron-phonon interactions in graphene on polar substrates, and tunable\ngraphene plasmonics with applications in modulators and sensors. Finally, we\nseek to address some of the apparent challenges and promising perspectives of\ngraphene plasmonics.'),
#               ('author',
#                [OrderedDict([('name', 'Sanshui Xiao')]),
#                 OrderedDict([('name', 'Xiaolong Zhu')]),
#                 OrderedDict([('name', 'Bo-Hong Li')]),
#                 OrderedDict([('name', 'N. Asger Mortensen')])]),
#               ('arxiv:doi',
#                OrderedDict([('@xmlns:arxiv', 'http://arxiv.org/schemas/atom'),
#                             ('#text', '10.1007/s11467-016-0551-z')])),
#               ('link',
#                [OrderedDict([('@title', 'doi'),
#                              ('@href',
#                               'http://dx.doi.org/10.1007/s11467-016-0551-z'),
#                              ('@rel', 'related')]),
#                 OrderedDict([('@href', 'http://arxiv.org/abs/1606.00471v2'),
#                              ('@rel', 'alternate'),
#                              ('@type', 'text/html')]),
#                 OrderedDict([('@title', 'pdf'),
#                              ('@href', 'http://arxiv.org/pdf/1606.00471v2'),
#                              ('@rel', 'related'),
#                              ('@type', 'application/pdf')])]),
#               ('arxiv:comment',
#                OrderedDict([('@xmlns:arxiv', 'http://arxiv.org/schemas/atom'),
#                             ('#text',
#                              'Invited minireview paper on graphene plasmon polaritons, 11 pages, 4\n  figures')])),
#               ('arxiv:journal_ref',
#                OrderedDict([('@xmlns:arxiv', 'http://arxiv.org/schemas/atom'),
#                             ('#text', 'Front. Phys. 11(2), 117801 (2016)')])),
#               ('arxiv:primary_category',
#                OrderedDict([('@xmlns:arxiv', 'http://arxiv.org/schemas/atom'),
#                             ('@term', 'physics.optics'),
#                             ('@scheme', 'http://arxiv.org/schemas/atom')])),
#               ('category',
#                [OrderedDict([('@term', 'physics.optics'),
#                              ('@scheme', 'http://arxiv.org/schemas/atom')]),
#                 OrderedDict([('@term', 'cond-mat.mes-hall'),
#                              ('@scheme',
#                               'http://arxiv.org/schemas/atom')])])]),
#  OrderedDict([('id', 'http://arxiv.org/abs/1611.09093v2'),
#               ('updated', '2016-11-30T10:46:15Z'),
#               ('published', '2016-11-28T12:20:40Z'),
#               ('title', 'Wetting of Water on Graphene'),
#               ('summary',
#                "The wetting properties of graphene have proven controversial and difficult to\nassess. The presence of a graphene layer on top of a substrate does not\nsignificantly change the wetting properties of the solid substrate, suggesting\nthat a single graphene layer does not affect the adhesion between the wetting\nphase and the substrate. However, wetting experiments of water on graphene show\ncontact angles that imply a large amount of adhesion. Here, we investigate the\nwetting of graphene by measuring the mass of water vapor adsorbing to graphene\nflakes of different thickness at different relative humidities. Our experiments\nunambiguously show that the thinnest of graphene flakes do not adsorb water,\nfrom which it follows that the contact angle of water on these flakes is ~180o.\nThicker flakes of graphene nanopowder, on the other hand, do adsorb water. A\ncalculation of the van der Waals (vdW) interactions that dominate the\nadsorption in this system confirms that the adhesive interactions between a\nsingle atomic layer of graphene and water are so weak that graphene is\nsuperhydrophobic. The observations are confirmed in an independent experiment\non graphene-coated water droplets that shows that it is impossible to make\nliquid 'marbles' with molecularly thin graphene."),
#               ('author',
#                [OrderedDict([('name', 'Bijoyendra Bera')]),
#                 OrderedDict([('name', 'Noushine Shahidzadeh')]),
#                 OrderedDict([('name', 'Himanshu Mishra')]),
#                 OrderedDict([('name', 'Daniel Bonn')])]),
#               ('link',
#                [OrderedDict([('@href', 'http://arxiv.org/abs/1611.09093v2'),
#                              ('@rel', 'alternate'),
#                              ('@type', 'text/html')]),
#                 OrderedDict([('@title', 'pdf'),
#                              ('@href', 'http://arxiv.org/pdf/1611.09093v2'),
#                              ('@rel', 'related'),
#                              ('@type', 'application/pdf')])]),
#               ('arxiv:primary_category',
#                OrderedDict([('@xmlns:arxiv', 'http://arxiv.org/schemas/atom'),
#                             ('@term', 'cond-mat.soft'),
#                             ('@scheme', 'http://arxiv.org/schemas/atom')])),
#               ('category',
#                [OrderedDict([('@term', 'cond-mat.soft'),
#                              ('@scheme', 'http://arxiv.org/schemas/atom')]),
#                 OrderedDict([('@term', 'cond-mat.mes-hall'),
#                              ('@scheme',
#                               'http://arxiv.org/schemas/atom')])])]),
#  OrderedDict([('id', 'http://arxiv.org/abs/0805.3712v1'),
#               ('updated', '2008-05-23T20:32:42Z'),
#               ('published', '2008-05-23T20:32:42Z'),
#               ('title',
#                'Atomic Layer Deposition of Metal Oxides on Pristine and Functionalized\n  Graphene'),
#               ('summary',
#                'We investigate Atomic Layer Deposition (ALD) of metal oxide on pristine and\nfunctionalized graphene. On pristine graphene, ALD coating can only actively\ngrow on edges and defect sites, where dangling bonds or surface groups react\nwith ALD precursors. This affords a simple method to decorate and probe single\ndefect sites in graphene planes. We used perylene tetracarboxylic acid (PTCA)\nto functionalize graphene surface and selectively introduced densely packed\nsurface groups on graphene. Uniform ultrathin ALD coating on PTCA graphene was\nachieved over large area. The functionalization method could be used to\nintegrate ultrathin high-k dielectrics in future graphene electronics.'),
#               ('author',
#                [OrderedDict([('name', 'Xinran Wang')]),
#                 OrderedDict([('name', 'Scott Tabakman')]),
#                 OrderedDict([('name', 'Hongjie Dai')])]),
#               ('arxiv:comment',
#                OrderedDict([('@xmlns:arxiv', 'http://arxiv.org/schemas/atom'),
#                             ('#text',
#                              '6pages, 3 figures, J. Am. Chem. Soc. in press')])),
#               ('link',
#                [OrderedDict([('@href', 'http://arxiv.org/abs/0805.3712v1'),
#                              ('@rel', 'alternate'),
#                              ('@type', 'text/html')]),
#                 OrderedDict([('@title', 'pdf'),
#                              ('@href', 'http://arxiv.org/pdf/0805.3712v1'),
#                              ('@rel', 'related'),
#                              ('@type', 'application/pdf')])]),
#               ('arxiv:primary_category',
#                OrderedDict([('@xmlns:arxiv', 'http://arxiv.org/schemas/atom'),
#                             ('@term', 'cond-mat.mtrl-sci'),
#                             ('@scheme', 'http://arxiv.org/schemas/atom')])),
#               ('category',
#                OrderedDict([('@term', 'cond-mat.mtrl-sci'),
#                             ('@scheme', 'http://arxiv.org/schemas/atom')]))])]

# %%
type(a['feed']['entry'])

# %%
b['feed']['entry']['author']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-c927edca6f07> in <module>()
# ----> 1 b['feed']['entry']['author']
#
# NameError: name 'b' is not defined

# %%
x = ['a','b','c','d']
y = []
y.extend(x)

# %%
y

# %%
len(G.node)
# Out:
# 58278

# %%
b['feed'].keys()
# Out:
# odict_keys(['@xmlns', 'link', 'title', 'id', 'updated', 'opensearch:totalResults', 'opensearch:startIndex', 'opensearch:itemsPerPage'])

# %%
b['feed']['title']
# Out:
# OrderedDict([('@type', 'html'),
#              ('#text',
#               'ArXiv Query: search_query=au:Zoltán Osváth&id_list=&start=0&max_results=100')])

# %%
x = {'one':1, 'two':2, 'three':3}

# %%
x
# Out:
# {'one': 1, 'three': 3, 'two': 2}

# %%
'one' not in x.keys()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-810adb75a3a8> in <module>()
# ----> 1 'one' not in x.keys()
#
# NameError: name 'x' is not defined

# %%
type(b) == type(None)
# Out:
# True

# %%
a
# Out:
# NoneType

# %%
len(G.nodes())
# Out:
# 58278

# %%
G

# %%
from networkx.readwrite import json_graph
import json

# %%
data = json_graph.node_link_data(G)

# %%
data
# Out:
# {'directed': False,
#  'graph': {},
#  'links': [{'source': 0, 'target': 6528},
#   {'source': 0, 'target': 31426},
#   {'source': 0, 'target': 42247},
#   {'source': 0, 'target': 14888},
#   {'source': 0, 'target': 11735},
#   {'source': 0, 'target': 1575},
#   {'source': 0, 'target': 38404},
#   {'source': 0, 'target': 7952},
#   {'source': 0, 'target': 26584},
#   {'source': 0, 'target': 47232},
#   {'source': 0, 'target': 49526},
#   {'source': 0, 'target': 57141},
#   {'source': 0, 'target': 45650},
#   {'source': 0, 'target': 50448},
#   {'source': 0, 'target': 36438},
#   {'source': 0, 'target': 14095},
#   {'source': 0, 'target': 26363},
#   {'source': 0, 'target': 33664},
#   {'source': 0, 'target': 10262},
#   {'source': 0, 'target': 11714},
#   {'source': 0, 'target': 35671},
#   {'source': 0, 'target': 19406},
#   {'source': 0, 'target': 11508},
#   {'source': 0, 'target': 15951},
#   {'source': 0, 'target': 16625},
#   {'source': 0, 'target': 57150},
#   {'source': 0, 'target': 3681},
#   {'source': 0, 'target': 43023},
#   {'source': 0, 'target': 22214},
#   {'source': 0, 'target': 53570},
#   {'source': 0, 'target': 54777},
#   {'source': 0, 'target': 44168},
#   {'source': 0, 'target': 33776},
#   {'source': 0, 'target': 22832},
#   {'source': 0, 'target': 30104},
#   {'source': 0, 'target': 48777},
#   {'source': 0, 'target': 32332},
#   {'source': 0, 'target': 45639},
#   {'source': 0, 'target': 5528},
#   {'source': 0, 'target': 26148},
#   {'source': 0, 'target': 4940},
#   {'source': 0, 'target': 53258},
#   {'source': 0, 'target': 57713},
#   {'source': 0, 'target': 28364},
#   {'source': 0, 'target': 55016},
#   {'source': 0, 'target': 17965},
#   {'source': 0, 'target': 255},
#   {'source': 0, 'target': 25448},
#   {'source': 0, 'target': 46554},
#   {'source': 0, 'target': 39811},
#   {'source': 0, 'target': 4921},
#   {'source': 0, 'target': 25458},
#   {'source': 0, 'target': 19305},
#   {'source': 0, 'target': 11531},
#   {'source': 0, 'target': 21542},
#   {'source': 0, 'target': 17528},
#   {'source': 0, 'target': 41140},
#   {'source': 0, 'target': 35736},
#   {'source': 0, 'target': 32122},
#   {'source': 0, 'target': 24074},
#   {'source': 0, 'target': 26628},
#   {'source': 0, 'target': 30142},
#   {'source': 0, 'target': 56700},
#   {'source': 0, 'target': 43689},
#   {'source': 0, 'target': 10590},
#   {'source': 0, 'target': 32348},
#   {'source': 0, 'target': 1810},
#   {'source': 0, 'target': 7016},
#   {'source': 0, 'target': 41233},
#   {'source': 0, 'target': 32153},
#   {'source': 0, 'target': 273},
#   {'source': 0, 'target': 53037},
#   {'source': 0, 'target': 56485},
#   {'source': 0, 'target': 49809},
#   {'source': 0, 'target': 37072},
#   {'source': 0, 'target': 41637},
#   {'source': 0, 'target': 25111},
#   {'source': 0, 'target': 30145},
#   {'source': 0, 'target': 41632},
#   {'source': 0, 'target': 52350},
#   {'source': 0, 'target': 8614},
#   {'source': 0, 'target': 6262},
#   {'source': 0, 'target': 45},
#   {'source': 0, 'target': 25911},
#   {'source': 0, 'target': 8838},
#   {'source': 0, 'target': 8947},
#   {'source': 0, 'target': 55134},
#   {'source': 0, 'target': 13936},
#   {'source': 0, 'target': 18335},
#   {'source': 0, 'target': 14161},
#   {'source': 0, 'target': 8842},
#   {'source': 0, 'target': 17779},
#   {'source': 0, 'target': 16033},
#   {'source': 0, 'target': 20125},
#   {'source': 0, 'target': 22942},
#   {'source': 0, 'target': 23174},
#   {'source': 0, 'target': 30395},
#   {'source': 0, 'target': 28990},
#   {'source': 0, 'target': 9872},
#   {'source': 0, 'target': 48495},
#   {'source': 0, 'target': 56502},
#   {'source': 0, 'target': 11745},
#   {'source': 0, 'target': 29938},
#   {'source': 0, 'target': 34114},
#   {'source': 0, 'target': 27583},
#   {'source': 0, 'target': 27450},
#   {'source': 0, 'target': 23813},
#   {'source': 0, 'target': 3671},
#   {'source': 0, 'target': 37137},
#   {'source': 0, 'target': 9073},
#   {'source': 0, 'target': 50877},
#   {'source': 0, 'target': 31066},
#   {'source': 0, 'target': 6132},
#   {'source': 0, 'target': 34291},
#   {'source': 0, 'target': 10404},
#   {'source': 0, 'target': 49063},
#   {'source': 0, 'target': 57213},
#   {'source': 0, 'target': 47003},
#   {'source': 0, 'target': 53312},
#   {'source': 0, 'target': 32360},
#   {'source': 0, 'target': 42094},
#   {'source': 0, 'target': 13504},
#   {'source': 0, 'target': 38487},
#   {'source': 0, 'target': 44784},
#   {'source': 0, 'target': 54474},
#   {'source': 0, 'target': 34699},
#   {'source': 0, 'target': 7365},
#   {'source': 0, 'target': 45476},
#   {'source': 0, 'target': 23405},
#   {'source': 0, 'target': 24090},
#   {'source': 0, 'target': 55842},
#   {'source': 0, 'target': 31267},
#   {'source': 0, 'target': 3744},
#   {'source': 0, 'target': 31505},
#   {'source': 0, 'target': 2278},
#   {'source': 0, 'target': 537},
#   {'source': 0, 'target': 54233},
#   {'source': 0, 'target': 15806},
#   {'source': 0, 'target': 1655},
#   {'source': 0, 'target': 53082},
#   {'source': 0, 'target': 316},
#   {'source': 0, 'target': 7302},
#   {'source': 0, 'target': 31069},
#   {'source': 0, 'target': 21835},
#   {'source': 0, 'target': 12637},
#   {'source': 0, 'target': 25737},
#   {'source': 0, 'target': 38276},
#   {'source': 0, 'target': 14891},
#   {'source': 0, 'target': 50099},
#   {'source': 0, 'target': 50724},
#   {'source': 0, 'target': 44149},
#   {'source': 0, 'target': 12679},
#   {'source': 0, 'target': 35948},
#   {'source': 0, 'target': 36409},
#   {'source': 0, 'target': 44372},
#   {'source': 0, 'target': 39879},
#   {'source': 0, 'target': 28855},
#   {'source': 0, 'target': 41911},
#   {'source': 0, 'target': 5401},
#   {'source': 0, 'target': 30440},
#   {'source': 0, 'target': 29733},
#   {'source': 0, 'target': 55416},
#   {'source': 0, 'target': 16948},
#   {'source': 0, 'target': 6163},
#   {'source': 0, 'target': 57011},
#   {'source': 0, 'target': 10682},
#   {'source': 0, 'target': 47576},
#   {'source': 0, 'target': 3915},
#   {'source': 0, 'target': 38376},
#   {'source': 0, 'target': 12583},
#   {'source': 0, 'target': 27971},
#   {'source': 0, 'target': 54412},
#   {'source': 0, 'target': 39657},
#   {'source': 0, 'target': 37062},
#   {'source': 0, 'target': 37181},
#   {'source': 0, 'target': 44822},
#   {'source': 0, 'target': 3233},
#   {'source': 0, 'target': 24663},
#   {'source': 0, 'target': 41175},
#   {'source': 0, 'target': 6470},
#   {'source': 0, 'target': 25222},
#   {'source': 0, 'target': 1681},
#   {'source': 0, 'target': 54746},
#   {'source': 0, 'target': 9573},
#   {'source': 0, 'target': 24457},
#   {'source': 0, 'target': 21383},
#   {'source': 0, 'target': 33558},
#   {'source': 0, 'target': 16972},
#   {'source': 0, 'target': 35105},
#   {'source': 0, 'target': 54755},
#   {'source': 0, 'target': 51532},
#   {'source': 0, 'target': 24839},
#   {'source': 0, 'target': 40335},
#   {'source': 0, 'target': 13323},
#   {'source': 0, 'target': 22336},
#   {'source': 0, 'target': 47121},
#   {'source': 0, 'target': 6638},
#   {'source': 0, 'target': 54528},
#   {'source': 0, 'target': 7343},
#   {'source': 0, 'target': 32206},
#   {'source': 0, 'target': 34009},
#   {'source': 0, 'target': 50814},
#   {'source': 0, 'target': 8095},
#   {'source': 0, 'target': 48962},
#   {'source': 0, 'target': 31994},
#   {'source': 0, 'target': 25400},
#   {'source': 0, 'target': 20281},
#   {'source': 0, 'target': 43992},
#   {'source': 0, 'target': 40328},
#   {'source': 0, 'target': 41947},
#   {'source': 0, 'target': 33116},
#   {'source': 0, 'target': 37655},
#   {'source': 0, 'target': 2168},
#   {'source': 0, 'target': 39794},
#   {'source': 0, 'target': 5351},
#   {'source': 0, 'target': 46702},
#   {'source': 0, 'target': 56450},
#   {'source': 0, 'target': 31839},
#   {'source': 0, 'target': 49654},
#   {'source': 0, 'target': 1417},
#   {'source': 0, 'target': 44948},
#   {'source': 0, 'target': 55234},
#   {'source': 0, 'target': 9161},
#   {'source': 0, 'target': 46695},
#   {'source': 0, 'target': 46696},
#   {'source': 0, 'target': 34254},
#   {'source': 0, 'target': 47939},
#   {'source': 0, 'target': 38658},
#   {'source': 0, 'target': 19566},
#   {'source': 0, 'target': 41392},
#   {'source': 0, 'target': 2664},
#   {'source': 0, 'target': 18383},
#   {'source': 0, 'target': 35203},
#   {'source': 0, 'target': 37779},
#   {'source': 0, 'target': 30933},
#   {'source': 0, 'target': 32478},
#   {'source': 0, 'target': 37893},
#   {'source': 0, 'target': 18100},
#   {'source': 0, 'target': 1917},
#   {'source': 0, 'target': 24203},
#   {'source': 0, 'target': 37447},
#   {'source': 0, 'target': 57985},
#   {'source': 0, 'target': 11195},
#   {'source': 0, 'target': 52008},
#   {'source': 0, 'target': 43081},
#   {'source': 0, 'target': 23965},
#   {'source': 0, 'target': 3517},
#   {'source': 0, 'target': 35873},
#   {'source': 0, 'target': 32213},
#   {'source': 0, 'target': 54728},
#   {'source': 0, 'target': 39474},
#   {'source': 0, 'target': 14968},
#   {'source': 0, 'target': 52205},
#   {'source': 0, 'target': 40414},
#   {'source': 0, 'target': 53169},
#   {'source': 0, 'target': 26758},
#   {'source': 0, 'target': 37511},
#   {'source': 0, 'target': 41523},
#   {'source': 0, 'target': 3257},
#   {'source': 0, 'target': 57303},
#   {'source': 0, 'target': 10051},
#   {'source': 0, 'target': 54798},
#   {'source': 0, 'target': 31593},
#   {'source': 0, 'target': 57770},
#   {'source': 0, 'target': 40699},
#   {'source': 0, 'target': 39220},
#   {'source': 0, 'target': 30508},
#   {'source': 0, 'target': 20544},
#   {'source': 0, 'target': 3534},
#   {'source': 0, 'target': 30957},
#   {'source': 0, 'target': 47655},
#   {'source': 0, 'target': 4649},
#   {'source': 0, 'target': 28911},
#   {'source': 0, 'target': 52480},
#   {'source': 0, 'target': 16579},
#   {'source': 0, 'target': 39372},
#   {'source': 0, 'target': 39981},
#   {'source': 0, 'target': 51080},
#   {'source': 0, 'target': 23746},
#   {'source': 0, 'target': 4431},
#   {'source': 0, 'target': 46254},
#   {'source': 0, 'target': 1998},
#   {'source': 0, 'target': 58009},
#   {'source': 0, 'target': 49784},
#   {'source': 0, 'target': 2603},
#   {'source': 0, 'target': 48107},
#   {'source': 0, 'target': 49731},
#   {'source': 0, 'target': 49489},
#   {'source': 0, 'target': 12088},
#   {'source': 0, 'target': 40852},
#   {'source': 0, 'target': 43333},
#   {'source': 0, 'target': 7175},
#   {'source': 0, 'target': 19360},
#   {'source': 0, 'target': 14534},
#   {'source': 0, 'target': 28671},
#   {'source': 0, 'target': 44464},
#   {'source': 0, 'target': 44200},
#   {'source': 0, 'target': 27493},
#   {'source': 0, 'target': 21500},
#   {'source': 0, 'target': 206},
#   {'source': 0, 'target': 43016},
#   {'source': 0, 'target': 22389},
#   {'source': 0, 'target': 49437},
#   {'source': 0, 'target': 21941},
#   {'source': 0, 'target': 37659},
#   {'source': 0, 'target': 12319},
#   {'source': 0, 'target': 40691},
#   {'source': 0, 'target': 29856},
#   {'source': 0, 'target': 8452},
#   {'source': 0, 'target': 2863},
#   {'source': 0, 'target': 55914},
#   {'source': 0, 'target': 13408},
#   {'source': 0, 'target': 5715},
#   {'source': 0, 'target': 49463},
#   {'source': 0, 'target': 433},
#   {'source': 0, 'target': 17553},
#   {'source': 0, 'target': 50436},
#   {'source': 0, 'target': 56898},
#   {'source': 0, 'target': 12544},
#   {'source': 0, 'target': 6192},
#   {'source': 0, 'target': 43243},
#   {'source': 0, 'target': 26771},
#   {'source': 0, 'target': 57810},
#   {'source': 0, 'target': 29595},
#   {'source': 0, 'target': 51592},
#   {'source': 0, 'target': 5604},
#   {'source': 1, 'target': 46914},
#   {'source': 1, 'target': 37184},
#   {'source': 1, 'target': 26216},
#   {'source': 2, 'target': 1800},
#   {'source': 2, 'target': 7772},
#   {'source': 2, 'target': 56765},
#   {'source': 2, 'target': 50545},
#   {'source': 2, 'target': 48283},
#   {'source': 2, 'target': 2769},
#   {'source': 2, 'target': 53502},
#   {'source': 2, 'target': 47508},
#   {'source': 2, 'target': 7229},
#   {'source': 2, 'target': 31792},
#   {'source': 2, 'target': 1837},
#   {'source': 2, 'target': 17149},
#   {'source': 3, 'target': 35354},
#   {'source': 3, 'target': 32856},
#   {'source': 3, 'target': 12833},
#   {'source': 4, 'target': 26689},
#   {'source': 4, 'target': 54992},
#   {'source': 4, 'target': 12198},
#   {'source': 5, 'target': 29168},
#   {'source': 5, 'target': 33192},
#   {'source': 5, 'target': 53761},
#   {'source': 5, 'target': 53230},
#   {'source': 5, 'target': 49059},
#   {'source': 5, 'target': 7656},
#   {'source': 5, 'target': 39533},
#   {'source': 5, 'target': 27653},
#   {'source': 5, 'target': 19399},
#   {'source': 5, 'target': 13893},
#   {'source': 5, 'target': 11850},
#   {'source': 5, 'target': 57432},
#   {'source': 5, 'target': 28739},
#   {'source': 5, 'target': 7508},
#   {'source': 5, 'target': 45410},
#   {'source': 5, 'target': 2736},
#   {'source': 5, 'target': 50135},
#   {'source': 5, 'target': 28236},
#   {'source': 5, 'target': 27778},
#   {'source': 5, 'target': 729},
#   {'source': 5, 'target': 466},
#   {'source': 5, 'target': 26832},
#   {'source': 5, 'target': 14056},
#   {'source': 5, 'target': 34583},
#   {'source': 5, 'target': 51373},
#   {'source': 5, 'target': 38190},
#   {'source': 5, 'target': 130},
#   {'source': 5, 'target': 16111},
#   {'source': 5, 'target': 34746},
#   {'source': 5, 'target': 42850},
#   {'source': 5, 'target': 20517},
#   {'source': 5, 'target': 16328},
#   {'source': 5, 'target': 54648},
#   {'source': 5, 'target': 42271},
#   {'source': 5, 'target': 15299},
#   {'source': 5, 'target': 2298},
#   {'source': 5, 'target': 43184},
#   {'source': 5, 'target': 14953},
#   {'source': 5, 'target': 54171},
#   {'source': 5, 'target': 19434},
#   {'source': 5, 'target': 43190},
#   {'source': 5, 'target': 43191},
#   {'source': 5, 'target': 20408},
#   {'source': 5, 'target': 14824},
#   {'source': 5, 'target': 19171},
#   {'source': 5, 'target': 12584},
#   {'source': 5, 'target': 19929},
#   {'source': 5, 'target': 24423},
#   {'source': 5, 'target': 488},
#   {'source': 5, 'target': 18885},
#   {'source': 5, 'target': 33918},
#   {'source': 5, 'target': 51165},
#   {'source': 5, 'target': 33023},
#   {'source': 5, 'target': 52349},
#   {'source': 5, 'target': 31477},
#   {'source': 5, 'target': 53586},
#   {'source': 5, 'target': 24991},
#   {'source': 5, 'target': 18278},
#   {'source': 5, 'target': 56039},
#   {'source': 5, 'target': 42740},
#   {'source': 5, 'target': 37338},
#   {'source': 5, 'target': 19454},
#   {'source': 5, 'target': 39136},
#   {'source': 5, 'target': 8065},
#   {'source': 5, 'target': 31915},
#   {'source': 5, 'target': 47579},
#   {'source': 5, 'target': 1410},
#   {'source': 5, 'target': 17136},
#   {'source': 5, 'target': 25472},
#   {'source': 5, 'target': 21807},
#   {'source': 5, 'target': 13669},
#   {'source': 5, 'target': 934},
#   {'source': 5, 'target': 21347},
#   {'source': 5, 'target': 54204},
#   {'source': 5, 'target': 20429},
#   {'source': 5, 'target': 10199},
#   {'source': 5, 'target': 5913},
#   {'source': 5, 'target': 39148},
#   {'source': 5, 'target': 7004},
#   {'source': 5, 'target': 49136},
#   {'source': 5, 'target': 26420},
#   {'source': 5, 'target': 17266},
#   {'source': 5, 'target': 4388},
#   {'source': 5, 'target': 32833},
#   {'source': 5, 'target': 20899},
#   {'source': 5, 'target': 40988},
#   {'source': 5, 'target': 20439},
#   {'source': 5, 'target': 51426},
#   {'source': 5, 'target': 10869},
#   {'source': 5, 'target': 40551},
#   {'source': 5, 'target': 28113},
#   {'source': 5, 'target': 30563},
#   {'source': 5, 'target': 6962},
#   {'source': 5, 'target': 25019},
#   {'source': 5, 'target': 44127},
#   {'source': 5, 'target': 13506},
#   {'source': 5, 'target': 39623},
#   {'source': 5, 'target': 35108},
#   {'source': 5, 'target': 51924},
#   {'source': 5, 'target': 43667},
#   {'source': 5, 'target': 42917},
#   {'source': 5, 'target': 13041},
#   {'source': 5, 'target': 40111},
#   {'source': 5, 'target': 44504},
#   {'source': 5, 'target': 13516},
#   {'source': 5, 'target': 11353},
#   {'source': 5, 'target': 54716},
#   {'source': 5, 'target': 30643},
#   {'source': 5, 'target': 45939},
#   {'source': 5, 'target': 26913},
#   {'source': 5, 'target': 14558},
#   {'source': 5, 'target': 48235},
#   {'source': 5, 'target': 38731},
#   {'source': 5, 'target': 30649},
#   {'source': 5, 'target': 14026},
#   {'source': 5, 'target': 4137},
#   {'source': 5, 'target': 6696},
#   {'source': 5, 'target': 9248},
#   {'source': 5, 'target': 37537},
#   {'source': 5, 'target': 52406},
#   {'source': 5, 'target': 49508},
#   {'source': 5, 'target': 10426},
#   {'source': 5, 'target': 31967},
#   {'source': 5, 'target': 24595},
#   {'source': 5, 'target': 29850},
#   {'source': 5, 'target': 27872},
#   {'source': 5, 'target': 20001},
#   {'source': 5, 'target': 49184},
#   {'source': 5, 'target': 33436},
#   {'source': 5, 'target': 53480},
#   {'source': 5, 'target': 27609},
#   {'source': 5, 'target': 36048},
#   {'source': 5, 'target': 32432},
#   {'source': 5, 'target': 42819},
#   {'source': 5, 'target': 25992},
#   {'source': 5, 'target': 5018},
#   {'source': 5, 'target': 34376},
#   {'source': 5, 'target': 43706},
#   {'source': 5, 'target': 46915},
#   {'source': 5, 'target': 40597},
#   {'source': 5, 'target': 26258},
#   {'source': 5, 'target': 3241},
#   {'source': 5, 'target': 20490},
#   {'source': 5, 'target': 50744},
#   {'source': 5, 'target': 9133},
#   {'source': 5, 'target': 56386},
#   {'source': 5, 'target': 44179},
#   {'source': 5, 'target': 37753},
#   {'source': 5, 'target': 20095},
#   {'source': 5, 'target': 21567},
#   {'source': 5, 'target': 19075},
#   {'source': 5, 'target': 19112},
#   {'source': 5, 'target': 1491},
#   {'source': 5, 'target': 40148},
#   {'source': 5, 'target': 24626},
#   {'source': 5, 'target': 54494},
#   {'source': 5, 'target': 21429},
#   {'source': 5, 'target': 49209},
#   {'source': 5, 'target': 29776},
#   {'source': 5, 'target': 19807},
#   {'source': 5, 'target': 34421},
#   {'source': 5, 'target': 49213},
#   {'source': 5, 'target': 53372},
#   {'source': 5, 'target': 21345},
#   {'source': 5, 'target': 40118},
#   {'source': 5, 'target': 10769},
#   {'source': 5, 'target': 36085},
#   {'source': 5, 'target': 42395},
#   {'source': 5, 'target': 10937},
#   {'source': 5, 'target': 42252},
#   {'source': 5, 'target': 23628},
#   {'source': 5, 'target': 26966},
#   {'source': 5, 'target': 3580},
#   {'source': 5, 'target': 45544},
#   {'source': 5, 'target': 43843},
#   {'source': 5, 'target': 46250},
#   {'source': 5, 'target': 40163},
#   {'source': 5, 'target': 156},
#   {'source': 5, 'target': 19567},
#   {'source': 5, 'target': 5349},
#   {'source': 5, 'target': 54303},
#   {'source': 5, 'target': 26382},
#   {'source': 5, 'target': 36442},
#   {'source': 5, 'target': 18384},
#   {'source': 5, 'target': 8189},
#   {'source': 5, 'target': 40881},
#   {'source': 5, 'target': 50968},
#   {'source': 5, 'target': 11728},
#   {'source': 5, 'target': 41077},
#   {'source': 5, 'target': 1646},
#   {'source': 5, 'target': 32483},
#   {'source': 5, 'target': 41968},
#   {'source': 5, 'target': 21904},
#   {'source': 5, 'target': 1472},
#   {'source': 5, 'target': 33904},
#   {'source': 5, 'target': 49695},
#   {'source': 5, 'target': 17254},
#   {'source': 5, 'target': 20066},
#   {'source': 5, 'target': 10047},
#   {'source': 5, 'target': 2366},
#   {'source': 5, 'target': 18219},
#   {'source': 5, 'target': 21875},
#   {'source': 5, 'target': 14814},
#   {'source': 5, 'target': 39723},
#   {'source': 5, 'target': 52468},
#   {'source': 5, 'target': 51067},
#   {'source': 5, 'target': 13148},
#   {'source': 5, 'target': 46477},
#   {'source': 5, 'target': 28872},
#   {'source': 5, 'target': 55259},
#   {'source': 5, 'target': 2829},
#   {'source': 5, 'target': 50619},
#   {'source': 5, 'target': 2831},
#   {'source': 5, 'target': 27079},
#   {'source': 5, 'target': 46947},
#   {'source': 5, 'target': 54154},
#   {'source': 5, 'target': 1937},
#   {'source': 5, 'target': 33381},
#   {'source': 5, 'target': 19118},
#   {'source': 5, 'target': 2834},
#   {'source': 5, 'target': 40616},
#   {'source': 5, 'target': 13604},
#   {'source': 5, 'target': 44237},
#   {'source': 5, 'target': 1137},
#   {'source': 5, 'target': 56623},
#   {'source': 5, 'target': 48876},
#   {'source': 5, 'target': 23039},
#   {'source': 5, 'target': 14487},
#   {'source': 5, 'target': 8828},
#   {'source': 5, 'target': 44245},
#   {'source': 5, 'target': 18229},
#   {'source': 5, 'target': 51555},
#   {'source': 5, 'target': 187},
#   {'source': 5, 'target': 55274},
#   {'source': 5, 'target': 46108},
#   {'source': 5, 'target': 31175},
#   {'source': 5, 'target': 48780},
#   {'source': 5, 'target': 8743},
#   {'source': 5, 'target': 16813},
#   {'source': 5, 'target': 32963},
#   {'source': 5, 'target': 57109},
#   {'source': 5, 'target': 33405},
#   {'source': 5, 'target': 47522},
#   {'source': 5, 'target': 2856},
#   {'source': 5, 'target': 45707},
#   {'source': 5, 'target': 33409},
#   {'source': 5, 'target': 16788},
#   {'source': 5, 'target': 37492},
#   {'source': 5, 'target': 45146},
#   {'source': 5, 'target': 46049},
#   {'source': 5, 'target': 51070},
#   {'source': 5, 'target': 27719},
#   {'source': 5, 'target': 55338},
#   {'source': 5, 'target': 15755},
#   {'source': 5, 'target': 58038},
#   {'source': 5, 'target': 54080},
#   {'source': 5, 'target': 53960},
#   {'source': 5, 'target': 52980},
#   {'source': 5, 'target': 47431},
#   {'source': 5, 'target': 36592},
#   {'source': 5, 'target': 6176},
#   {'source': 5, 'target': 32345},
#   {'source': 5, 'target': 27986},
#   {'source': 5, 'target': 54805},
#   {'source': 5, 'target': 35256},
#   {'source': 5, 'target': 11523},
#   {'source': 5, 'target': 37514},
#   {'source': 5, 'target': 27782},
#   {'source': 5, 'target': 38855},
#   {'source': 5, 'target': 5377},
#   {'source': 5, 'target': 45872},
#   {'source': 5, 'target': 2589},
#   {'source': 5, 'target': 27524},
#   {'source': 5, 'target': 42582},
#   {'source': 5, 'target': 3168},
#   {'source': 5, 'target': 2260},
#   {'source': 5, 'target': 19520},
#   {'source': 5, 'target': 26086},
#   {'source': 5, 'target': 36047},
#   {'source': 5, 'target': 58060},
#   {'source': 5, 'target': 33895},
#   {'source': 5, 'target': 50029},
#   {'source': 5, 'target': 45265},
#   {'source': 5, 'target': 21243},
#   {'source': 5, 'target': 35136},
#   {'source': 5, 'target': 40248},
#   {'source': 5, 'target': 18728},
#   {'source': 5, 'target': 6870},
#   {'source': 5, 'target': 20491},
#   {'source': 5, 'target': 41702},
#   {'source': 5, 'target': 21984},
#   {'source': 5, 'target': 13159},
#   {'source': 5, 'target': 31830},
#   {'source': 5, 'target': 55556},
#   {'source': 5, 'target': 52075},
#   {'source': 5, 'target': 14128},
#   {'source': 5, 'target': 8120},
#   {'source': 5, 'target': 28012},
#   {'source': 5, 'target': 42040},
#   {'source': 5, 'target': 56688},
#   {'source': 5, 'target': 7459},
#   {'source': 5, 'target': 39808},
#   {'source': 5, 'target': 2914},
#   {'source': 5, 'target': 41535},
#   {'source': 5, 'target': 6556},
#   {'source': 5, 'target': 47030},
#   {'source': 5, 'target': 19672},
#   {'source': 5, 'target': 56692},
#   {'source': 5, 'target': 42460},
#   {'source': 5, 'target': 27980},
#   {'source': 5, 'target': 24751},
#   {'source': 5, 'target': 15008},
#   {'source': 5, 'target': 28511},
#   {'source': 5, 'target': 24313},
#   {'source': 5, 'target': 18746},
#   {'source': 5, 'target': 1586},
#   {'source': 5, 'target': 55349},
#   {'source': 5, 'target': 54545},
#   {'source': 5, 'target': 47513},
#   {'source': 5, 'target': 41265},
#   {'source': 5, 'target': 54440},
#   {'source': 5, 'target': 1630},
#   {'source': 5, 'target': 36236},
#   {'source': 5, 'target': 32615},
#   {'source': 5, 'target': 43871},
#   {'source': 5, 'target': 57184},
#   {'source': 5, 'target': 56407},
#   {'source': 5, 'target': 17374},
#   {'source': 5, 'target': 14616},
#   {'source': 5, 'target': 282},
#   {'source': 5, 'target': 51697},
#   {'source': 5, 'target': 42527},
#   {'source': 5, 'target': 42061},
#   {'source': 5, 'target': 50732},
#   {'source': 5, 'target': 46942},
#   {'source': 5, 'target': 48134},
#   {'source': 5, 'target': 54449},
#   {'source': 5, 'target': 44764},
#   {'source': 5, 'target': 30843},
#   {'source': 5, 'target': 40775},
#   {'source': 5, 'target': 48436},
#   {'source': 5, 'target': 49833},
#   {'source': 5, 'target': 51766},
#   {'source': 5, 'target': 29937},
#   {'source': 5, 'target': 34499},
#   {'source': 5, 'target': 22027},
#   {'source': 5, 'target': 5680},
#   {'source': 5, 'target': 51190},
#   {'source': 5, 'target': 1011},
#   {'source': 5, 'target': 42085},
#   {'source': 5, 'target': 29150},
#   {'source': 5, 'target': 50288},
#   {'source': 5, 'target': 8992},
#   {'source': 5, 'target': 23555},
#   {'source': 5, 'target': 16007},
#   {'source': 5, 'target': 28546},
#   {'source': 5, 'target': 7951},
#   {'source': 5, 'target': 36679},
#   {'source': 5, 'target': 57370},
#   {'source': 5, 'target': 25911},
#   {'source': 5, 'target': 12403},
#   {'source': 5, 'target': 42210},
#   {'source': 5, 'target': 45695},
#   {'source': 5, 'target': 12408},
#   {'source': 5, 'target': 15981},
#   {'source': 5, 'target': 28558},
#   {'source': 5, 'target': 3578},
#   {'source': 5, 'target': 24801},
#   {'source': 5, 'target': 7290},
#   {'source': 5, 'target': 10205},
#   {'source': 5, 'target': 14422},
#   {'source': 5, 'target': 28566},
#   {'source': 5, 'target': 6415},
#   {'source': 5, 'target': 5701},
#   {'source': 5, 'target': 46629},
#   {'source': 5, 'target': 24964},
#   {'source': 5, 'target': 9099},
#   {'source': 5, 'target': 45897},
#   {'source': 5, 'target': 46165},
#   {'source': 5, 'target': 29977},
#   {'source': 5, 'target': 20243},
#   {'source': 5, 'target': 48836},
#   {'source': 5, 'target': 45548},
#   {'source': 5, 'target': 54463},
#   {'source': 5, 'target': 2518},
#   {'source': 5, 'target': 50776},
#   {'source': 5, 'target': 19121},
#   {'source': 5, 'target': 4767},
#   {'source': 5, 'target': 9335},
#   {'source': 5, 'target': 36279},
#   {'source': 5, 'target': 18390},
#   {'source': 5, 'target': 18247},
#   {'source': 5, 'target': 35690},
#   {'source': 5, 'target': 39417},
#   {'source': 5, 'target': 37506},
#   {'source': 5, 'target': 8896},
#   {'source': 5, 'target': 53109},
#   {'source': 5, 'target': 338},
#   {'source': 5, 'target': 6635},
#   {'source': 5, 'target': 42629},
#   {'source': 5, 'target': 26600},
#   {'source': 5, 'target': 26604},
#   {'source': 5, 'target': 33553},
#   {'source': 5, 'target': 25823},
#   {'source': 5, 'target': 27565},
#   {'source': 5, 'target': 54908},
#   {'source': 5, 'target': 15141},
#   {'source': 5, 'target': 46662},
#   {'source': 5, 'target': 31765},
#   {'source': 5, 'target': 18405},
#   {'source': 5, 'target': 10703},
#   {'source': 5, 'target': 56969},
#   {'source': 5, 'target': 13770},
#   {'source': 5, 'target': 27790},
#   {'source': 5, 'target': 53126},
#   {'source': 5, 'target': 42600},
#   {'source': 5, 'target': 58186},
#   {'source': 5, 'target': 23018},
#   {'source': 5, 'target': 37648},
#   {'source': 5, 'target': 9368},
#   {'source': 5, 'target': 39914},
#   {'source': 5, 'target': 28618},
#   {'source': 5, 'target': 2113},
#   {'source': 5, 'target': 6196},
#   {'source': 5, 'target': 36789},
#   {'source': 5, 'target': 40383},
#   {'source': 5, 'target': 31334},
#   {'source': 5, 'target': 3029},
#   {'source': 5, 'target': 11631},
#   {'source': 5, 'target': 34012},
#   {'source': 5, 'target': 34951},
#   {'source': 5, 'target': 46689},
#   {'source': 5, 'target': 48977},
#   {'source': 5, 'target': 1345},
#   {'source': 5, 'target': 20290},
#   {'source': 5, 'target': 12476},
#   {'source': 5, 'target': 2561},
#   {'source': 5, 'target': 20763},
#   {'source': 5, 'target': 55908},
#   {'source': 5, 'target': 27830},
#   {'source': 5, 'target': 43071},
#   {'source': 5, 'target': 34145},
#   {'source': 5, 'target': 17486},
#   {'source': 5, 'target': 43982},
#   {'source': 5, 'target': 48992},
#   {'source': 5, 'target': 25343},
#   {'source': 5, 'target': 803},
#   {'source': 5, 'target': 33267},
#   {'source': 5, 'target': 19084},
#   {'source': 5, 'target': 51101},
#   {'source': 5, 'target': 23495},
#   {'source': 5, 'target': 34969},
#   {'source': 5, 'target': 14273},
#   {'source': 5, 'target': 44158},
#   {'source': 5, 'target': 52981},
#   {'source': 5, 'target': 39150},
#   {'source': 5, 'target': 33178},
#   {'source': 5, 'target': 57201},
#   {'source': 5, 'target': 14735},
#   {'source': 5, 'target': 54574},
#   {'source': 5, 'target': 49470},
#   {'source': 5, 'target': 20786},
#   {'source': 5, 'target': 38547},
#   {'source': 5, 'target': 39041},
#   {'source': 5, 'target': 19585},
#   {'source': 5, 'target': 29586},
#   {'source': 5, 'target': 21520},
#   {'source': 5, 'target': 17034},
#   {'source': 5, 'target': 57774},
#   {'source': 5, 'target': 24902},
#   {'source': 5, 'target': 23984},
#   {'source': 5, 'target': 24444},
#   {'source': 5, 'target': 20583},
#   {'source': 5, 'target': 44898},
#   {'source': 5, 'target': 7619},
#   {'source': 5, 'target': 52591},
#   {'source': 5, 'target': 58247},
#   {'source': 5, 'target': 30520},
#   {'source': 5, 'target': 7073},
#   {'source': 5, 'target': 19120},
#   {'source': 5, 'target': 17048},
#   {'source': 5, 'target': 18238},
#   {'source': 5, 'target': 18920},
#   {'source': 5, 'target': 27722},
#   {'source': 5, 'target': 39060},
#   {'source': 5, 'target': 34531},
#   {'source': 5, 'target': 50417},
#   {'source': 5, 'target': 57786},
#   {'source': 5, 'target': 46142},
#   {'source': 5, 'target': 1067},
#   {'source': 5, 'target': 21249},
#   {'source': 5, 'target': 15097},
#   {'source': 5, 'target': 8806},
#   {'source': 5, 'target': 39878},
#   {'source': 5, 'target': 11602},
#   {'source': 5, 'target': 49036},
#   {'source': 5, 'target': 19370},
#   {'source': 5, 'target': 14315},
#   {'source': 5, 'target': 52818},
#   {'source': 5, 'target': 26342},
#   {'source': 5, 'target': 25859},
#   {'source': 5, 'target': 6846},
#   {'source': 5, 'target': 17814},
#   {'source': 5, 'target': 47974},
#   {'source': 5, 'target': 57347},
#   {'source': 5, 'target': 53681},
#   {'source': 5, 'target': 51821},
#   {'source': 5, 'target': 42682},
#   {'source': 5, 'target': 3573},
#   {'source': 5, 'target': 17073},
#   {'source': 5, 'target': 38155},
#   {'source': 5, 'target': 13878},
#   {'source': 5, 'target': 17557},
#   {'source': 5, 'target': 46761},
#   {'source': 5, 'target': 15716},
#   {'source': 5, 'target': 21112},
#   {'source': 5, 'target': 1573},
#   {'source': 5, 'target': 56436},
#   {'source': 6, 'target': 58189},
#   {'source': 6, 'target': 30929},
#   {'source': 6, 'target': 48545},
#   {'source': 7, 'target': 10812},
#   {'source': 7, 'target': 56788},
#   {'source': 7, 'target': 31933},
#   {'source': 7, 'target': 54587},
#   {'source': 7, 'target': 394},
#   {'source': 7, 'target': 55171},
#   {'source': 8, 'target': 32874},
#   {'source': 8, 'target': 13616},
#   {'source': 8, 'target': 45113},
#   {'source': 8, 'target': 49363},
#   {'source': 8, 'target': 8000},
#   {'source': 8, 'target': 34271},
#   {'source': 8, 'target': 35057},
#   {'source': 8, 'target': 52820},
#   {'source': 8, 'target': 4954},
#   {'source': 8, 'target': 17201},
#   {'source': 8, 'target': 48656},
#   {'source': 8, 'target': 14286},
#   {'source': 8, 'target': 55943},
#   {'source': 8, 'target': 24494},
#   {'source': 8, 'target': 23397},
#   {'source': 8, 'target': 26947},
#   {'source': 8, 'target': 56649},
#   {'source': 8, 'target': 54757},
#   {'source': 8, 'target': 36741},
#   {'source': 8, 'target': 8575},
#   {'source': 8, 'target': 14457},
#   {'source': 8, 'target': 53821},
#   {'source': 8, 'target': 46985},
#   {'source': 8, 'target': 9649},
#   {'source': 8, 'target': 51085},
#   {'source': 8, 'target': 28829},
#   {'source': 8, 'target': 40682},
#   {'source': 8, 'target': 31824},
#   {'source': 8, 'target': 39061},
#   {'source': 8, 'target': 4810},
#   {'source': 8, 'target': 7288},
#   {'source': 8, 'target': 36021},
#   {'source': 8, 'target': 54351},
#   {'source': 8, 'target': 41266},
#   {'source': 8, 'target': 1997},
#   {'source': 8, 'target': 44976},
#   {'source': 8, 'target': 29418},
#   {'source': 8, 'target': 57059},
#   {'source': 8, 'target': 3390},
#   {'source': 8, 'target': 28094},
#   {'source': 8, 'target': 24256},
#   {'source': 8, 'target': 9819},
#   {'source': 8, 'target': 15349},
#   {'source': 8, 'target': 52031},
#   {'source': 8, 'target': 5782},
#   {'source': 8, 'target': 39919},
#   {'source': 8, 'target': 26012},
#   {'source': 8, 'target': 20710},
#   {'source': 8, 'target': 23493},
#   {'source': 8, 'target': 16226},
#   {'source': 8, 'target': 43817},
#   {'source': 8, 'target': 7486},
#   {'source': 8, 'target': 17444},
#   {'source': 8, 'target': 54738},
#   {'source': 8, 'target': 32178},
#   {'source': 8, 'target': 47756},
#   {'source': 8, 'target': 45718},
#   {'source': 9, 'target': 9483},
#   {'source': 10, 'target': 53021},
#   {'source': 10, 'target': 7798},
#   {'source': 10, 'target': 47084},
#   {'source': 10, 'target': 30012},
#   {'source': 10, 'target': 29331},
#   {'source': 10, 'target': 37896},
#   {'source': 10, 'target': 1006},
#   {'source': 10, 'target': 57752},
#   {'source': 10, 'target': 43856},
#   {'source': 10, 'target': 15008},
#   {'source': 10, 'target': 4503},
#   {'source': 10, 'target': 13506},
#   {'source': 10, 'target': 17180},
#   {'source': 10, 'target': 38729},
#   {'source': 10, 'target': 37322},
#   {'source': 10, 'target': 27092},
#   {'source': 10, 'target': 53538},
#   {'source': 10, 'target': 48214},
#   {'source': 10, 'target': 15234},
#   {'source': 10, 'target': 13878},
#   {'source': 10, 'target': 31306},
#   {'source': 10, 'target': 102},
#   {'source': 10, 'target': 15837},
#   {'source': 10, 'target': 14694},
#   {'source': 10, 'target': 25711},
#   {'source': 10, 'target': 48372},
#   {'source': 10, 'target': 27653},
#   {'source': 10, 'target': 50591},
#   {'source': 10, 'target': 9853},
#   {'source': 10, 'target': 25650},
#   {'source': 10, 'target': 17733},
#   {'source': 11, 'target': 15388},
#   {'source': 12, 'target': 29627},
#   {'source': 12, 'target': 5312},
#   {'source': 12, 'target': 23345},
#   {'source': 12, 'target': 26828},
#   {'source': 12, 'target': 36069},
#   {'source': 12, 'target': 22906},
#   {'source': 12, 'target': 110},
#   {'source': 12, 'target': 9599},
#   {'source': 12, 'target': 17426},
#   {'source': 12, 'target': 18663},
#   {'source': 12, 'target': 26212},
#   {'source': 13, 'target': 16786},
#   {'source': 13, 'target': 25190},
#   {'source': 13, 'target': 24174},
#   {'source': 14, 'target': 28588},
#   {'source': 14, 'target': 37275},
#   {'source': 14, 'target': 31828},
#   {'source': 14, 'target': 26512},
#   {'source': 14, 'target': 20400},
#   {'source': 14, 'target': 39515},
#   {'source': 14, 'target': 20570},
#   {'source': 14, 'target': 612},
#   {'source': 14, 'target': 15877},
#   {'source': 14, 'target': 23371},
#   {'source': 14, 'target': 18065},
#   {'source': 14, 'target': 43686},
#   {'source': 15, 'target': 47225},
#   {'source': 15, 'target': 29602},
#   {'source': 15, 'target': 3594},
#   {'source': 15, 'target': 27283},
#   {'source': 15, 'target': 40024},
#   {'source': 15, 'target': 10803},
#   {'source': 15, 'target': 25458},
#   {'source': 15, 'target': 21763},
#   {'source': 15, 'target': 43592},
#   {'source': 15, 'target': 3590},
#   ...],
#  'multigraph': False,
#  'nodes': [{'id': 'P. Hallen'},
#   {'id': 'Arash Amini'},
#   {'id': 'Ville Havu'},
#   {'id': 'M. Bondi'},
#   {'id': 'Renaud Lambiotte'},
#   {'id': 'D. Wölbing'},
#   {'id': 'Susan Hermiller'},
#   {'id': 'P. Mukherjee'},
#   {'id': 'D. Burton'},
#   {'id': 'F. Naderi'},
#   {'id': 'W. Brodowski'},
#   {'id': 'Peter J. Cho'},
#   {'id': 'E. Louis'},
#   {'id': 'Mehdi Bennis'},
#   {'id': 'Annie Baglin'},
#   {'id': 'P. Shawhan'},
#   {'id': 'J. Trummer'},
#   {'id': 'H. Hoorani'},
#   {'id': 'S. M. M. Coelho'},
#   {'id': 'C. L. Gao'},
#   {'id': 'J. Borkowski'},
#   {'id': 'T. Kajita'},
#   {'id': 'L. P. Teo'},
#   {'id': 'Hsin-Ying Chiu'},
#   {'id': 'Y. Sakai'},
#   {'id': 'Daniela Rebuzzi'},
#   {'id': 'S. Roman Lopez'},
#   {'id': 'S. Reid'},
#   {'id': 'Amiel Sternberg'},
#   {'id': 'A K Rajagopal'},
#   {'id': 'L. A. Winslow'},
#   {'id': 'R. Ganter'},
#   {'id': 'M. Sakamoto'},
#   {'id': 'Z. Patrick'},
#   {'id': 'P. G. Kuijer'},
#   {'id': 'S. E. Haaland'},
#   {'id': 'Tanmoy Das'},
#   {'id': 'T. Junk'},
#   {'id': 'L. Singer'},
#   {'id': 'J. von Delft'},
#   {'id': 'Sotiris A. Sanidas'},
#   {'id': 'G. Penso'},
#   {'id': 'Sofia Ribeiro'},
#   {'id': 'R. Smiljanic'},
#   {'id': 'H. Htoon'},
#   {'id': 'M. Tselengidou'},
#   {'id': 'K. V. Gopalakrishnan'},
#   {'id': 'Volkmar Liebscher'},
#   {'id': 'V. Vassilieva'},
#   {'id': 'D. N. Basov'},
#   {'id': 'Ronan M. T. Fleming'},
#   {'id': 'E. Vercellin'},
#   {'id': 'Linli Xu'},
#   {'id': 'G. Vansuch'},
#   {'id': 'Wushan Cheng'},
#   {'id': 'S. Shett'},
#   {'id': 'G. Matt'},
#   {'id': 'Zhi Lin'},
#   {'id': 'A. Kovacs'},
#   {'id': 'J. J. Ishikawa'},
#   {'id': 'M. Viola'},
#   {'id': 'T. Yamanaka'},
#   {'id': 'F. Sarasini'},
#   {'id': 'Alexandre Horth'},
#   {'id': 'Shujuan Liu'},
#   {'id': 'Anuradha M. Annaswamy'},
#   {'id': 'S. Jin'},
#   {'id': 'Guodong Pang'},
#   {'id': 'M. Ranferi Gutierrez'},
#   {'id': 'M. S. Ganti'},
#   {'id': 'Pranaw Rungta'},
#   {'id': 'I. Vai'},
#   {'id': 'Alejandro A. Pacheco-Sanjuan'},
#   {'id': 'Émile Le Page'},
#   {'id': 'W. Hartung'},
#   {'id': 'A. Schnorr-Müller'},
#   {'id': 'Alexander Heußner'},
#   {'id': 'Guo Lei'},
#   {'id': 'Xijun Hu'},
#   {'id': 'Zhixiang Sun'},
#   {'id': 'Xiaoyan Hu'},
#   {'id': 'H. Jahan'},
#   {'id': 'Deepak Samuel'},
#   {'id': 'Changbo Zhu'},
#   {'id': 'Matthias F. Kling'},
#   {'id': 'P. Weiss'},
#   {'id': 'C. R. Hagen'},
#   {'id': 'J. A. R. Caldwell'},
#   {'id': 'S. E. Schröder'},
#   {'id': 'S. J. Ahmed'},
#   {'id': 'J. R. T. de Mello Neto'},
#   {'id': 'T. Déchelette'},
#   {'id': 'Baitian Tang'},
#   {'id': 'Jean-Francois Raskin'},
#   {'id': 'Mark Waterson'},
#   {'id': "M. d'Errico"},
#   {'id': 'F. Bunzel'},
#   {'id': 'Giulio Cerullo'},
#   {'id': 'Nelson Merino'},
#   {'id': 'Rubens Esposito'},
#   {'id': 'K. P. McElroy'},
#   {'id': 'Haoran Feng'},
#   {'id': 'A. Sukhanov'},
#   {'id': 'F. Frasconi'},
#   {'id': 'R. Vasquez'},
#   {'id': 'Tasuku Mizukami'},
#   {'id': 'A. Bell'},
#   {'id': 'Vadim Brazhkin'},
#   {'id': 'Steve Lamoreaux'},
#   {'id': 'Q. -S. Tao'},
#   {'id': 'I. A. Makhotkin'},
#   {'id': 'Guoliang Yu'},
#   {'id': 'J. J. Drake'},
#   {'id': 'V. Chambert'},
#   {'id': 'H. P. Jakobsen'},
#   {'id': 'Archana Venugopal'},
#   {'id': 'E. Botta'},
#   {'id': 'I. Kamaretsos'},
#   {'id': 'V. V. Sagun'},
#   {'id': 'Chao Zhu'},
#   {'id': 'J. M. Diego'},
#   {'id': 'S. Y. Zhou'},
#   {'id': 'J. P. Attfield'},
#   {'id': 'K. Tsubono'},
#   {'id': 'T. Carroll'},
#   {'id': 'A. Koekemoer'},
#   {'id': 'Gadi Fibich'},
#   {'id': 'W. Kucewicz'},
#   {'id': 'Weizhe Zheng'},
#   {'id': 'V. M. Myles'},
#   {'id': 'M. Kümmel'},
#   {'id': 'Jesus Perez Padialla'},
#   {'id': 'J. Michel'},
#   {'id': 'L. B. Lin'},
#   {'id': 'J. Schumacher'},
#   {'id': 'N. K. Johnson-McDaniel'},
#   {'id': 'Jacob Vogel'},
#   {'id': 'M. Bowen'},
#   {'id': 'V. A. Stepkin'},
#   {'id': 'T. Pollmann'},
#   {'id': 'P. S. Barklem'},
#   {'id': 'Kamal P. Singh'},
#   {'id': 'S. Yu'},
#   {'id': 'Shijing Tan'},
#   {'id': 'Wenjuan Zou'},
#   {'id': 'Guillermo C. Gaunaurd'},
#   {'id': 'K. Lazaridis'},
#   {'id': 'B. Schröder'},
#   {'id': 'G. Rudnick'},
#   {'id': 'M. J. Rooks'},
#   {'id': 'Mohamed Firdhous'},
#   {'id': 'S. Neeleshwar'},
#   {'id': 'C. Hernández'},
#   {'id': 'B. Jacoby'},
#   {'id': 'H. Cho'},
#   {'id': 'J. Kovac'},
#   {'id': 'A. Fechtchenko'},
#   {'id': 'Bennett Chow'},
#   {'id': 'Jinping Yao'},
#   {'id': 'R. L. Plambeck'},
#   {'id': 'D. van der Marel'},
#   {'id': 'P. Cooper'},
#   {'id': 'Benoit Blossier'},
#   {'id': 'J. Schindler'},
#   {'id': 'H. Schmitt'},
#   {'id': 'Shouhong Wang'},
#   {'id': 'E. Oh'},
#   {'id': 'A. D. Krisch'},
#   {'id': 'Eros Mariani'},
#   {'id': 'A. Vinogradov'},
#   {'id': 'A. Takenaka'},
#   {'id': 'Gösta Gustafson'},
#   {'id': 'Nick Kaiser'},
#   {'id': 'S. A. Krupko'},
#   {'id': 'L. Song'},
#   {'id': 'Martin Kraus'},
#   {'id': 'Rongkuan Liu'},
#   {'id': 'H. Z. Zhang'},
#   {'id': 'Chang-Pu Sun'},
#   {'id': 'Jun Wu'},
#   {'id': 'Seif O. Cholakh'},
#   {'id': 'K. Xia'},
#   {'id': 'Vašek Chvátal'},
#   {'id': 'P. Díaz Fernández'},
#   {'id': 'M. Sakellariadou'},
#   {'id': 'M. André'},
#   {'id': 'W. H. T. Vlemmings'},
#   {'id': 'M. Krebs'},
#   {'id': 'S. E. Palmer'},
#   {'id': 'Feng Xu'},
#   {'id': 'Raul Jimenez'},
#   {'id': 'Gerhard Birkl'},
#   {'id': 'Chee-Tat Toh'},
#   {'id': 'Meenakshi Singh'},
#   {'id': 'S. N. Gninenko'},
#   {'id': 'G. Vermendi'},
#   {'id': 'Ian U. Roederer'},
#   {'id': 'Pedro A. Garcia-Sanchez'},
#   {'id': 'Xitao Guo'},
#   {'id': 'N. Toro'},
#   {'id': 'D. MacQueen'},
#   {'id': 'K. T. Kim'},
#   {'id': 'S. Bastrukov'},
#   {'id': 'Mohammad Farrokhi Derakhshandeh Ghouchan'},
#   {'id': 'F. Ambroglini'},
#   {'id': 'T. Ahn'},
#   {'id': 'H. S. Matis'},
#   {'id': 'R. Sunyaev'},
#   {'id': 'R. Everett'},
#   {'id': 'K. Hornoch'},
#   {'id': 'Liwei Liu'},
#   {'id': 'R. Welsing'},
#   {'id': 'P. Mandal'},
#   {'id': 'J. Terzic'},
#   {'id': 'Sudhir K. Pandey'},
#   {'id': 'Ranganathan Kumar'},
#   {'id': 'Kefeng Wang'},
#   {'id': 'J-P. Kneib'},
#   {'id': 'P. Ehrens'},
#   {'id': 'G. Sullivan'},
#   {'id': 'Z. C. Huang'},
#   {'id': 'Jeffery G. Andrews'},
#   {'id': 'Changheon Oh'},
#   {'id': 'Guangrui'},
#   {'id': 'Supratim Sengupta'},
#   {'id': 'S. Sudarshan'},
#   {'id': 'T. Vickey'},
#   {'id': 'E. Niemczura'},
#   {'id': 'G. Giovanetti'},
#   {'id': 'Yuzhu Wang'},
#   {'id': 'Wipapat Kladwang'},
#   {'id': 'S. Jena'},
#   {'id': 'E. Monnier'},
#   {'id': 'G. Flanagan'},
#   {'id': 'A. Post'},
#   {'id': 'M. Schauer'},
#   {'id': 'S. K. Bose'},
#   {'id': 'Nick Brook'},
#   {'id': 'Y. J. Qi'},
#   {'id': 'D. M Kaplan'},
#   {'id': 'A. W. Burnley'},
#   {'id': 'M. S. Dresselhaus'},
#   {'id': 'Won-Yong Shin'},
#   {'id': 'N. Booth'},
#   {'id': 'Marie Lemoine-Busserolle'},
#   {'id': 'Mats Hagberg'},
#   {'id': 'H. Minakata'},
#   {'id': 'D. Jörger'},
#   {'id': 'Muhammad Iqbal'},
#   {'id': 'X. H. Mo'},
#   {'id': 'K. Higa'},
#   {'id': 'X. Renshaw Wang'},
#   {'id': 'Michael Goodchild'},
#   {'id': 'Xiang-Sun Zhang'},
#   {'id': 'H. Y. Song'},
#   {'id': 'M. Usner'},
#   {'id': 'B. Hattaway'},
#   {'id': 'D. Coupland'},
#   {'id': 'C. Marcella Carollo'},
#   {'id': 'Jacques Smulevici'},
#   {'id': 'J. Sudou'},
#   {'id': 'F. Surina'},
#   {'id': 'A. Kutov'},
#   {'id': 'E. M. Takagui'},
#   {'id': 'H. -T. Ding'},
#   {'id': 'S. Gomillion'},
#   {'id': 'H. Muraishi'},
#   {'id': 'Mingjiang Zhang'},
#   {'id': 'Sebastian Drave'},
#   {'id': 'O. Petruk'},
#   {'id': 'Th. Proffen'},
#   {'id': 'E. Z. da Silva'},
#   {'id': 'Omer Arap'},
#   {'id': 'C. Finley'},
#   {'id': 'Alois Panholzer'},
#   {'id': 'Dmitri Efetov'},
#   {'id': 'Tobias Preis'},
#   {'id': 'U. Wurstbauer'},
#   {'id': 'S. Vaughan'},
#   {'id': 'Hideaki Sunagawa'},
#   {'id': 'He Chen'},
#   {'id': 'Cristóbal López'},
#   {'id': 'G. Alexeev'},
#   {'id': 'P. van Dokkum'},
#   {'id': 'Y. Takasu'},
#   {'id': 'J. Lane'},
#   {'id': 'K. Saha'},
#   {'id': 'C. J. Phillips'},
#   {'id': 'Zhixiang Zhao'},
#   {'id': 'T. Piazza'},
#   {'id': 'Jia Li'},
#   {'id': 'Robert W. Carlson'},
#   {'id': 'D. E. Miller'},
#   {'id': 'Maurizio Piai'},
#   {'id': 'Changjin Wan'},
#   {'id': 'N. Rangwala'},
#   {'id': 'L. C. P. M. de Smet'},
#   {'id': 'David J. Lane'},
#   {'id': 'A. Cabre'},
#   {'id': 'Cunjing Lv'},
#   {'id': 'R. Orive'},
#   {'id': 'Z. B. Yan'},
#   {'id': 'J. Pratt'},
#   {'id': 'Yang Pan'},
#   {'id': 'K. I. Kellermann'},
#   {'id': 'L. Ding'},
#   {'id': 'A. Simakov'},
#   {'id': 'Ana-Suncana Smith'},
#   {'id': 'R. Kotak'},
#   {'id': 'T. Taniguchi'},
#   {'id': 'Zhi-Hua Zhou'},
#   {'id': 'H. J. Zhu'},
#   {'id': 'Paolo Di Francesco'},
#   {'id': 'Xianhui Chen'},
#   {'id': 'M. Yoshimura'},
#   {'id': 'Darwin Chang'},
#   {'id': 'N. Kurahashi'},
#   {'id': 'J. T. Park'},
#   {'id': 'V. Lafage'},
#   {'id': 'S. Filchagin'},
#   {'id': 'Y. F. Guo'},
#   {'id': 'B. Bathen'},
#   {'id': 'J. Ren'},
#   {'id': 'T. Ravelomanantsoa'},
#   {'id': 'R. Bonnand'},
#   {'id': 'S. V. Nair'},
#   {'id': 'L. Deng'},
#   {'id': 'Pasquale Calabrese'},
#   {'id': 'J. Aalbers'},
#   {'id': 'Navin Singh'},
#   {'id': 'M. S. Jackson'},
#   {'id': 'J. Boyer'},
#   {'id': 'Katepalli R. Sreenivasan'},
#   {'id': 'G. Persson'},
#   {'id': 'F. Carena'},
#   {'id': 'Hongbo Huang'},
#   {'id': 'Kai Du'},
#   {'id': 'M. I. Auslender'},
#   {'id': 'Y. Yan'},
#   {'id': 'Semih Cakmakyapan'},
#   {'id': 'K. Wu'},
#   {'id': 'Wlodek Strupinski'},
#   {'id': 'D. Cortina-Gil'},
#   {'id': 'Y. Hello'},
#   {'id': 'M. Scott'},
#   {'id': 'V. Singh'},
#   {'id': 'L. Tutsch'},
#   {'id': 'Susan M. Clark'},
#   {'id': 'H. Jallouli'},
#   {'id': 'Erfang Shan'},
#   {'id': 'Michel Pioro-Ladriere'},
#   {'id': 'Jose J. Plata'},
#   {'id': 'A. K. Turner'},
#   {'id': 'Chin Poo Lee'},
#   {'id': 'Lami Kim'},
#   {'id': 'E. Sicking'},
#   {'id': 'G. Rizzo'},
#   {'id': 'M. A. Subieta Vásquez'},
#   {'id': 'P. T. Hille'},
#   {'id': 'Krishna S.'},
#   {'id': 'Meifang Li'},
#   {'id': 'Sarah P. Sherlock'},
#   {'id': 'M. Duncan'},
#   {'id': 'Brian L. Rachford'},
#   {'id': 'L. Strigari'},
#   {'id': 'Aiguo Xu'},
#   {'id': 'Paolo S. Coppi'},
#   {'id': 'L. Molina-Bueno'},
#   {'id': 'K. Alan Loper'},
#   {'id': 'F. Kapp'},
#   {'id': 'Daniel Bonn'},
#   {'id': 'Y. Watanabe'},
#   {'id': 'Zhenxiong Xiao'},
#   {'id': 'Xiaodong Yang'},
#   {'id': 'Hua Wei'},
#   {'id': 'K. Ghorbani'},
#   {'id': 'J. Dowell'},
#   {'id': 'Wanli Wang'},
#   {'id': 'Che-Man Cheng'},
#   {'id': 'C. Pascual-Izarra'},
#   {'id': 'Daisuke Murata'},
#   {'id': 'A. De Angelis'},
#   {'id': 'C. A. Moore'},
#   {'id': 'P. Polozov'},
#   {'id': 'M. D. Rodriguez-Frias'},
#   {'id': 'G. Vijaya Prakash'},
#   {'id': 'P. Joshi'},
#   {'id': 'A. Pineda'},
#   {'id': 'M. Bowne'},
#   {'id': 'S. Taneja'},
#   {'id': 'Francois Quitin'},
#   {'id': 'Ajay D. Thakur'},
#   {'id': 'Changhee Lee'},
#   {'id': 'K. Le Hur'},
#   {'id': 'A. Sarkar'},
#   {'id': 'N. Evans'},
#   {'id': 'J. Steinlechner'},
#   {'id': 'Paola Pietrini'},
#   {'id': 'I. Kowalska'},
#   {'id': 'A. Glaefke'},
#   {'id': 'Yao Zhou'},
#   {'id': 'S. Ghonge'},
#   {'id': 'Gao Mou'},
#   {'id': 'T. Rõõm'},
#   {'id': 'B. Kilminster'},
#   {'id': 'Joakim Edsjo'},
#   {'id': 'A. Miranowicz'},
#   {'id': 'M. Szczekowski'},
#   {'id': 'Troy Eichman'},
#   {'id': 'A. A. Serga'},
#   {'id': 'J. Holder'},
#   {'id': 'R. L. McNutt Jr.'},
#   {'id': 'M. Kurata-Nishimura'},
#   {'id': 'S. Caponi'},
#   {'id': 'Oleg R. Musin'},
#   {'id': 'Yufeng Li'},
#   {'id': 'E. M. Terentjev'},
#   {'id': 'Y. Butt'},
#   {'id': 'R. Lazarov'},
#   {'id': 'D. J. Schwarz'},
#   {'id': 'G. Addamo'},
#   {'id': 'Walter A. de Heer'},
#   {'id': 'R. de los Reyes Lopez'},
#   {'id': 'E. Manykin'},
#   {'id': 'Hervé Roussel'},
#   {'id': 'L. Koch'},
#   {'id': 'M. Lechman K. S. Lee'},
#   {'id': 'Z. Swierczynski'},
#   {'id': 'Torben Haenke'},
#   {'id': 'A. S. Bradley'},
#   {'id': 'Yi Song'},
#   {'id': 'Eugene Gregoryanz'},
#   {'id': 'Ajit Iqbal Singh'},
#   {'id': 'M. Santander'},
#   {'id': 'A. Brisuda'},
#   {'id': 'E. Montes'},
#   {'id': 'T. Moriguchi'},
#   {'id': 'E. Schinnerer'},
#   {'id': 'S. Krupko'},
#   {'id': 'K. S. Thygesen'},
#   {'id': 'J. L. Meunier'},
#   {'id': 'K. Slevin'},
#   {'id': 'G. L. Ganetis'},
#   {'id': 'U. -H. Hwang'},
#   {'id': 'G. Spiczak'},
#   {'id': 'X. Xia'},
#   {'id': 'Yongge Ma'},
#   {'id': 'G. Debreczeni'},
#   {'id': 'T. Colegate'},
#   {'id': 'Edward Wu'},
#   {'id': 'A. B. Souchkov'},
#   {'id': 'A. G. G. M. Tielens'},
#   {'id': 'Hui Lin'},
#   {'id': 'Dong Zhang'},
#   {'id': 'R. Vaidya'},
#   {'id': 'J. Rochford'},
#   {'id': 'Leif Lonnblad'},
#   {'id': 'Haiping Wu'},
#   {'id': 'I. Berceanu'},
#   {'id': 'Haigang Zhang'},
#   {'id': 'T. Müller'},
#   {'id': 'A. Albert'},
#   {'id': 'Jong Hak Lee'},
#   {'id': 'F. Bertrand'},
#   {'id': 'H. T. Diehl'},
#   {'id': 'Wendong Wang'},
#   {'id': 'R. Birsa'},
#   {'id': 'A. Aleev'},
#   {'id': 'Thierry Jourdan'},
#   {'id': 'R. Bondarescu'},
#   {'id': 'P. Wilcox'},
#   {'id': 'A. Mihara'},
#   {'id': 'D. Law'},
#   {'id': 'P. L. Luque-Escamilla'},
#   {'id': 'Philipp Hass'},
#   {'id': 'M. Harder'},
#   {'id': 'M. R. Mooney'},
#   {'id': 'W. M. Yao'},
#   {'id': 'T. Verdugo'},
#   {'id': 'Rui-Xue Xu'},
#   {'id': 'Zhao Sun'},
#   {'id': 'Pengfei Hu'},
#   {'id': 'T. Shimojima'},
#   {'id': 'A. Zullo'},
#   {'id': 'V. V. Yanovsky'},
#   {'id': 'T. Durakiewicz'},
#   {'id': 'Z. G. Wang'},
#   {'id': 'Cláudio J. daSilva'},
#   {'id': 'A. Sokolov'},
#   {'id': 'Randall Cavalero'},
#   {'id': 'J. L. Carlin'},
#   {'id': 'Swapan K. Pati'},
#   {'id': 'Elizabeth K. Mann'},
#   {'id': 'N. Pillet'},
#   {'id': 'Francisco Sanz'},
#   {'id': 'V. Sinev'},
#   {'id': 'R. Panse'},
#   {'id': 'Chun-Hung Liu'},
#   {'id': 'C. -P. Yuan'},
#   {'id': 'Péter Nemes Incze'},
#   {'id': 'F. Bournaud'},
#   {'id': 'C. L. Smallwood'},
#   {'id': 'Won Nam Kang*'},
#   {'id': 'Fabio Mogavero'},
#   {'id': 'J. Dai'},
#   {'id': 'Feng Miao'},
#   {'id': 'K. Hatanaka'},
#   {'id': 'Aigu L. Lin'},
#   {'id': 'A. Voronin'},
#   {'id': 'Philip G. Judge'},
#   {'id': 'T. J. M. Symons'},
#   {'id': 'Alexander Borichev'},
#   {'id': 'Tangsheng Che'},
#   {'id': 'J. Grcebosz'},
#   {'id': 'L. Guy'},
#   {'id': 'Alvise Raccanelli'},
#   {'id': 'Jun Luo'},
#   {'id': 'R. E. P. de Oliveira'},
#   {'id': 'P. M. Reis'},
#   {'id': 'Hua Jiang'},
#   {'id': 'Wenxian Zhang'},
#   {'id': 'M. Enderle'},
#   {'id': 'Zhao Tan'},
#   {'id': 'H. C. Fang'},
#   {'id': 'Zhao Deng'},
#   {'id': 'Y. M. Liu'},
#   {'id': 'Teresa Vidal-Calleja'},
#   {'id': 'N. Galli'},
#   {'id': 'Mark Wise'},
#   {'id': 'Y. Yamamoto'},
#   {'id': 'S. Manly'},
#   {'id': 'L. Schuelke'},
#   {'id': 'Marc Sentis'},
#   {'id': 'Francisco J. García-Vidal'},
#   {'id': 'E. -M. Schullian'},
#   {'id': 'Jens H. Bardarson'},
#   {'id': 'Palle E. T. Jorgensen'},
#   {'id': 'E. Middlemas'},
#   {'id': 'Baoguang Shi'},
#   {'id': 'Xiaohui Huang'},
#   {'id': 'Y. Kubota'},
#   {'id': 'Yeo Chai Kiat'},
#   {'id': 'G. Pope'},
#   {'id': 'V. F. Mitrović'},
#   {'id': 'S. ter Veen'},
#   {'id': 'B. M. Schaefer'},
#   {'id': 'Tame Gonzalez'},
#   {'id': 'Jaderick P. Pabico'},
#   {'id': 'Shu-Ping Yan'},
#   {'id': 'Tiantian Huan'},
#   {'id': 'Xiangdong Ye'},
#   {'id': 'Sofiene Tahar'},
#   {'id': 'H. K. Eriksen'},
#   {'id': 'Bo Meng'},
#   {'id': 'M. W. Ng'},
#   {'id': 'A. A. Golubov'},
#   {'id': 'L. Turko'},
#   {'id': 'W. C. Jones'},
#   {'id': 'K. Y. Singh'},
#   {'id': 'Xiangang Wan'},
#   {'id': 'J. Apple'},
#   {'id': 'M. Giomi'},
#   {'id': 'J. S. Mikhail'},
#   {'id': 'G. De'},
#   {'id': 'P. N. Y. David'},
#   {'id': 'T. Kondo'},
#   {'id': 'O. Cakir'},
#   {'id': 'Yuefang Sun'},
#   {'id': 'D. Tezier'},
#   {'id': 'J. Demsar'},
#   {'id': 'B. R. Heckel'},
#   {'id': 'D. Kalinkin'},
#   {'id': 'Anna Lia Longinotti'},
#   {'id': 'Lianhong Cai'},
#   {'id': 'C. H. Anderson'},
#   {'id': 'M. Wu'},
#   {'id': 'Anaël Lemaître'},
#   {'id': 'M. Zdráhal'},
#   {'id': 'Zuying Zhou'},
#   {'id': 'M. Hirmer'},
#   {'id': 'Jian-Bin Xiao'},
#   {'id': 'Furong Xu'},
#   {'id': 'C. C. Liu'},
#   {'id': 'J. van Leerdam'},
#   {'id': 'K. G. Strassmeier'},
#   {'id': 'Alexander I. Bufetov'},
#   {'id': 'Y. S. Park'},
#   {'id': 'G. X. Sun'},
#   {'id': 'Zhichao Weng'},
#   {'id': 'Shiqi Li'},
#   {'id': 'Yunbo Zhang'},
#   {'id': 'S. K. Lamoreaux'},
#   {'id': 'C. Newman-Holmes'},
#   {'id': 'A. Mefodiev'},
#   {'id': 'T. Besara'},
#   {'id': 'Y. H. Zhao'},
#   {'id': 'N. M. Brown'},
#   {'id': 'M. T. Clark'},
#   {'id': 'S. Shiraishi'},
#   {'id': 'Hala A. Eid'},
#   {'id': "S. D'Auria"},
#   {'id': 'Maciej Lewenstein'},
#   {'id': 'Ryan Yamachika'},
#   {'id': 'Nijo Varghese'},
#   {'id': 'Huaqing Huang'},
#   {'id': 'P. K. Mal'},
#   {'id': 'G. Güntherodt'},
#   {'id': 'D. A. Jensen'},
#   {'id': 'Xinchou Lou'},
#   {'id': 'Florian Speck'},
#   {'id': 'Qingrong Feng'},
#   {'id': 'Prashanth L. A.'},
#   {'id': 'Thierry Morel'},
#   {'id': 'G. Madejski'},
#   {'id': 'F. Jelezko'},
#   {'id': 'L. C. Jang'},
#   {'id': 'M. Taguchi'},
#   {'id': 'Uma Shankar'},
#   {'id': 'K. Wakamatsu'},
#   {'id': 'Wolung Lee'},
#   {'id': 'A. Pimpinelli'},
#   {'id': 'H. Kanai'},
#   {'id': 'I. Hrivnacova'},
#   {'id': 'Sarah E. Gibson'},
#   {'id': 'Marcos D. Caballero'},
#   {'id': 'K. Reitberger'},
#   {'id': 'Daniel W. Cranston'},
#   {'id': 'T. Laurent'},
#   {'id': 'R. Casini'},
#   {'id': 'R. Povey'},
#   {'id': 'P. Kravtsov'},
#   {'id': 'Osman Güler'},
#   {'id': 'Yanci Nie'},
#   {'id': 'W. E. Ortega'},
#   {'id': 'S. Grünewald'},
#   {'id': 'P. Gilkey'},
#   {'id': 'Caroline Norda'},
#   {'id': 'K. Vaziri'},
#   {'id': 'K. Taniguchi'},
#   {'id': 'John A. R. Caldwell'},
#   {'id': 'Wei Deng'},
#   {'id': 'D. Lucchesicc'},
#   {'id': 'C. Carbone'},
#   {'id': 'P. Rodriguez Perez'},
#   {'id': 'Y. Nagasaka'},
#   {'id': 'Ning Wang'},
#   {'id': 'Zihua Guo'},
#   {'id': 'J. Sichelschmidt'},
#   {'id': 'M. Bondioli'},
#   {'id': 'Laura L. M. Yang'},
#   {'id': 'William E. Devanny'},
#   {'id': 'Jian Huang'},
#   {'id': 'T. Tsuji'},
#   {'id': 'Qimiao Si'},
#   {'id': 'T. Downes'},
#   {'id': 'Andrei M. Popov'},
#   {'id': 'Amy Steele'},
#   {'id': 'Sudeshna Dasgupta'},
#   {'id': 'N. Bastid'},
#   {'id': 'Shoufeng Shen'},
#   {'id': 'Nicholas M. Luscombe'},
#   {'id': 'D. Stiles'},
#   {'id': 'S. Fodor'},
#   {'id': 'Liangying Jiang'},
#   {'id': 'A. M. Zungeru'},
#   {'id': 'A. Ocampo'},
#   {'id': 'Y. H. Tan'},
#   {'id': 'A. A. Katanin'},
#   {'id': 'D. Y. Tang'},
#   {'id': 'N. V. Mikheev'},
#   {'id': 'Shang-Hua Teng'},
#   {'id': 'Lin Wu'},
#   {'id': 'K. Kolar'},
#   {'id': 'S. Kamada'},
#   {'id': 'Sen Hu'},
#   {'id': 'A. Upadhye'},
#   {'id': 'J. Behrend'},
#   {'id': 'A. Martinez Davalos'},
#   {'id': 'P. Wilson'},
#   {'id': 'S. Vorobiov'},
#   {'id': 'J. -G. Yi'},
#   {'id': 'David Fobes'},
#   {'id': 'S. Randich'},
#   {'id': 'P. Kuhns'},
#   {'id': 'R. Mattana'},
#   {'id': 'S. Wright'},
#   {'id': 'M. Liguori'},
#   {'id': 'G. B. Thomson'},
#   {'id': 'J. -F. Olive'},
#   {'id': 'M. Shimizu'},
#   {'id': 'Sébastien Manneville'},
#   {'id': 'G. Migliore'},
#   {'id': 'Yasuyuki Tamari'},
#   {'id': 'Hong-tao Bian'},
#   {'id': 'Ian Shields'},
#   {'id': 'Chien-Hao Lin'},
#   {'id': 'Y. Ōno'},
#   {'id': 'W. Tyler'},
#   {'id': 'K. Campman'},
#   {'id': 'Seick Kim'},
#   {'id': 'George Em Karniadakis'},
#   {'id': 'V. M. Kalari'},
#   {'id': 'B. Relethford'},
#   {'id': 'J. D. Hofgartner'},
#   {'id': 'Mohan Chen'},
#   {'id': 'Ali Suleyman Ustunel'},
#   {'id': 'Dagobert Soergel'},
#   {'id': 'Wenjie Yang'},
#   {'id': 'Sourav K. Bhowmick'},
#   {'id': 'Stephen D. Griffiths'},
#   {'id': 'L. Chirolli'},
#   {'id': 'T. Kawano'},
#   {'id': 'V. V. Mazurenko'},
#   {'id': 'U. Bach'},
#   {'id': 'Rebekah M. Palmer'},
#   {'id': 'H. I. Park'},
#   {'id': 'A. B. Kolton'},
#   {'id': 'M. Pezeril'},
#   {'id': 'L. Montanet'},
#   {'id': "Michael O'Connell"},
#   {'id': 'Chung-Yu Mou'},
#   {'id': 'Tao Wang'},
#   {'id': 'M. Zinovjev'},
#   {'id': 'Scott D. Friedman'},
#   {'id': 'N. Pinkine'},
#   {'id': 'J. Nanni'},
#   {'id': 'R B Paris'},
#   {'id': 'Daniel Povey'},
#   {'id': 'A. Krieger'},
#   {'id': 'E. Atomssa'},
#   {'id': 'K. Bloom'},
#   {'id': 'C. Loizides'},
#   {'id': 'D. Nicmorus'},
#   {'id': 'D. Qu'},
#   {'id': 'Mickael Profeta'},
#   {'id': 'Yongsheng Li'},
#   {'id': 'D. Perini D. Perrino'},
#   {'id': 'Stéphane Gaubert'},
#   {'id': 'D V S Muthu'},
#   {'id': 'John McDonald'},
#   {'id': 'R. Lopez'},
#   {'id': 'P. Pakhlov'},
#   {'id': 'Dario Fadda'},
#   {'id': 'T. Le Bleis'},
#   {'id': 'Michael Kiermaier'},
#   {'id': 'J. P. Tavernet'},
#   {'id': 'Tom Van Doorsselaere'},
#   {'id': 'Xiaowei Peng'},
#   {'id': 'L. D. Anderson'},
#   {'id': 'M. Nohara'},
#   {'id': 'G. G. N. Angilella'},
#   {'id': 'G. Pakhlova'},
#   {'id': 'Bijoyendra Bera'},
#   {'id': 'Quan Qu'},
#   {'id': 'Michael L. Norman'},
#   {'id': 'J. Loveday'},
#   {'id': 'T. Aso'},
#   {'id': 'Inigo Martin-Fernandez'},
#   {'id': 'Jensen Li'},
#   {'id': 'Irina S. Tereshina'},
#   {'id': 'Fei-hung Ho'},
#   {'id': 'Ricardo Baeza-Yates'},
#   {'id': 'Zhanwen Han'},
#   {'id': 'L. C. Lü'},
#   {'id': 'F. Munoz'},
#   {'id': 'D. Keane'},
#   {'id': 'Lianfeng Sun'},
#   {'id': 'F. Yermia'},
#   {'id': 'C. A. Wilson'},
#   {'id': 'Omar Almaini'},
#   {'id': 'Stephanie E. Palmer'},
#   {'id': 'J. Hashimoto'},
#   {'id': 'M. Milnik'},
#   {'id': 'Fuqiang Xu'},
#   {'id': 'D. Hofmann'},
#   {'id': 'S. Yanagita'},
#   {'id': 'Sangchul Oh'},
#   {'id': 'B. Osmanov'},
#   {'id': 'P. Závada'},
#   {'id': 'Z. Ambroży'},
#   {'id': 'J. S. Berg'},
#   {'id': 'J. Gamboa'},
#   {'id': 'H. Hattermann'},
#   {'id': 'N. Nikitenkov'},
#   {'id': 'G. Ortona'},
#   {'id': 'S. Wallis'},
#   {'id': 'T. Yu'},
#   {'id': 'Himanshu Khandelia'},
#   {'id': 'M. Balogh'},
#   {'id': 'W. B. Dorwart'},
#   {'id': 'C. Moreau-Luchaire'},
#   {'id': 'Amal Taarabt'},
#   {'id': 'Johan Morren'},
#   {'id': 'Wilfried Sigle'},
#   {'id': 'M. Knecht'},
#   {'id': 'Bin Xia'},
#   {'id': 'C. Niebuhr'},
#   {'id': 'Olivier Guédon'},
#   {'id': 'Paola Giacconi'},
#   {'id': 'Lorin X. Benedict'},
#   {'id': 'V. K. Dugaev'},
#   {'id': 'S. R. Elliott'},
#   {'id': 'N. Kouzmine'},
#   {'id': 'J. Hu'},
#   {'id': 'A. M. Stefanik'},
#   {'id': 'Klaus Reinsch'},
#   {'id': 'R. Budnik'},
#   {'id': 'P. D. Ye'},
#   {'id': 'R. Robertson'},
#   {'id': 'B. C. Pant'},
#   {'id': 'J. Aleksic'},
#   {'id': 'Mark Herman'},
#   {'id': 'J. T. Matta'},
#   {'id': 'T. Wachala'},
#   {'id': 'C. Díaz'},
#   {'id': 'X. C. Zhu'},
#   {'id': 'F. Cavanna'},
#   {'id': 'M. Ziegler'},
#   {'id': 'H. F. Xi'},
#   {'id': 'H. Johansson'},
#   {'id': 'Alexander Kniss'},
#   {'id': 'E. Casarejos'},
#   {'id': 'Guorong Li'},
#   {'id': 'A. Di Cantodd'},
#   {'id': 'E. Conover'},
#   {'id': 'C. G. Ji'},
#   {'id': 'Stanislav Stoupin'},
#   {'id': 'J. C. Flores'},
#   {'id': 'M. S. Allie'},
#   {'id': 'S. Pashapour'},
#   {'id': 'S. Sapeta'},
#   {'id': 'Won Min Shin'},
#   {'id': 'Huazhe Wang'},
#   {'id': 'C. Bailet'},
#   {'id': 'Terrence Edmonds'},
#   {'id': 'F. Nova'},
#   {'id': 'Taekyun Kim'},
#   {'id': 'T. T. Lwin'},
#   {'id': 'M. Kutschera'},
#   {'id': 'Natascha Foerster Schreiber'},
#   {'id': 'D. Brunner'},
#   {'id': 'O. Entin-Wohlman'},
#   {'id': 'K. Leffhalm'},
#   {'id': 'B. Maffei'},
#   {'id': 'D. Nagae'},
#   {'id': 'C. Ferrari'},
#   {'id': 'P. M. Frinchaboy'},
#   {'id': 'A. Pritchard'},
#   {'id': 'Y. Ren'},
#   {'id': 'Carlos R. Arroyo'},
#   {'id': 'J. -B. Melin'},
#   {'id': 'E. Charles'},
#   {'id': 'Srilok Srinivasan'},
#   {'id': 'Bao-Wei Wang'},
#   {'id': 'R. Arceo'},
#   {'id': 'Wenjie Guo'},
#   {'id': 'Guangyu An'},
#   {'id': 'B. Yang'},
#   {'id': 'Qinglin Tang'},
#   {'id': 'V. Samoilov'},
#   {'id': 'F. Costa M. E. Cotallo'},
#   {'id': 'S. Y. Jun'},
#   {'id': 'Lin Zhang'},
#   {'id': 'M. Bellis'},
#   {'id': 'Alexander C. Kalloniatis'},
#   {'id': 'Nikolai Nadirashvili'},
#   {'id': 'G. Bonnoli'},
#   {'id': 'Guofan Jin'},
#   {'id': 'V. I. Savrin'},
#   {'id': 'E. Giro'},
#   {'id': 'Tom Hogan'},
#   {'id': 'D. Lopes Pegna'},
#   {'id': 'Naoki Nishida'},
#   {'id': 'N. Boudet'},
#   {'id': 'C. Leyrat'},
#   {'id': 'M. Werner'},
#   {'id': 'Stanislav Sobolevsky'},
#   {'id': 'Swapan Mandal'},
#   {'id': 'K. Partyka'},
#   {'id': 'D. Tonelli'},
#   {'id': 'Wentao Zhang'},
#   {'id': 'W. Slater'},
#   {'id': 'Marin Soljačić'},
#   {'id': 'R. Cady'},
#   {'id': 'Rodolfo Miranda'},
#   {'id': 'J. Kullman'},
#   {'id': 'E. L. Bolda'},
#   {'id': 'C. M. Carollo'},
#   {'id': 'Mohammad Mohammadi Amiri'},
#   {'id': 'M. Mokhtari'},
#   {'id': 'M. P. Reiter'},
#   {'id': 'D. Vieira'},
#   {'id': 'R. H. Koch'},
#   {'id': 'N. Yokoyama'},
#   {'id': 'LIGO Scientific Collaboration'},
#   {'id': 'Angshuman Guha'},
#   {'id': 'D. Horn'},
#   {'id': 'Takashi Sakurai'},
#   {'id': 'A. C. Ferrari'},
#   {'id': 'Jian Guo Hou'},
#   {'id': 'Maurizio Falanga'},
#   {'id': 'Krystal Guo'},
#   {'id': 'Martin Trautmann'},
#   {'id': 'D. Gardiol'},
#   {'id': 'Yulong Tang'},
#   {'id': 'J. van den Brand'},
#   {'id': 'J. M. Torrelles'},
#   {'id': 'M. F. Aller'},
#   {'id': 'G. Malcolm Stocks'},
#   {'id': 'S. H. Zhang'},
#   {'id': 'Bruce C. C. Cowie'},
#   {'id': 'M. Zíbar'},
#   {'id': 'Kyle Lane'},
#   {'id': 'Chrystopher L. Nehaniv'},
#   {'id': 'N. Simicevic'},
#   {'id': 'G. Papini'},
#   {'id': 'B. K. Wiggins'},
#   {'id': 'Wayne Goddard'},
#   {'id': 'Gerard Gorman'},
#   {'id': 'J. C. Gladstone'},
#   {'id': 'Maryam Salimi'},
#   {'id': 'R. J. Barber'},
#   {'id': 'A. Zimmermann'},
#   {'id': 'A. C. Wren'},
#   {'id': 'J. Eom'},
#   {'id': 'E. V. Deviatov'},
#   {'id': 'J. Yoneda'},
#   {'id': 'Juan Pablo Llinas'},
#   {'id': 'S. B. Thomas'},
#   {'id': 'S. H. Jhang'},
#   {'id': 'M. Dupuis'},
#   {'id': 'P. Kähler'},
#   {'id': 'J. Aysto'},
#   {'id': 'R. Jacobsen'},
#   {'id': 'T. Pocheptsov'},
#   {'id': 'Aday R. Robaina'},
#   {'id': 'J. J. Gonzalez-Pons'},
#   {'id': 'M. B. Silva Neto'},
#   {'id': 'D. Coyne'},
#   {'id': 'A. Insolia'},
#   {'id': 'C. Woodburn'},
#   {'id': 'Mehdi Saravani'},
#   {'id': 'N. Ikeno'},
#   {'id': 'I. N. Borzov'},
#   {'id': 'M. E. Dickinson'},
#   {'id': 'G. D. Orebi Gann'},
#   {'id': 'J. S. Arabadjis'},
#   {'id': 'Alim Karmous'},
#   {'id': 'Anatoly A. Klypin'},
#   {'id': 'Hadi Ravanbakhsh'},
#   {'id': 'J. Kortus'},
#   {'id': 'Hui Shen'},
#   {'id': 'J. Delgado'},
#   {'id': 'M. Isasa'},
#   {'id': 'V. Trusov'},
#   {'id': 'Guenter Ahlers'},
#   {'id': 'Bharath Sankaran'},
#   {'id': 'Jeremy Lovejoy'},
#   {'id': 'SeungBum Hong'},
#   {'id': 'W. -S. Lee'},
#   {'id': 'David M. Webber'},
#   {'id': 'Qinye Yin'},
#   {'id': 'S. D. Ganichev'},
#   {'id': 'K. Gozdziewski'},
#   {'id': 'E. Bouhova'},
#   {'id': 'M. Takamura'},
#   {'id': 'F. Simeone'},
#   {'id': 'Menglong Su'},
#   {'id': 'C. Rossler'},
#   {'id': 'Jinshan Wu'},
#   {'id': 'G. L. Ma'},
#   {'id': 'L. Mayer'},
#   {'id': 'Misha Balabas'},
#   {'id': 'M. G. Poghosyan'},
#   {'id': 'J. I. Jottar'},
#   {'id': 'M. R. Olyak'},
#   {'id': 'ANTARES Collaboration'},
#   {'id': 'N. N. Achasov'},
#   {'id': 'V. Dunin'},
#   {'id': 'Shuguang Zou'},
#   {'id': 'H. Savajols'},
#   {'id': 'S. Likhoded'},
#   {'id': 'J. T. Whelan'},
#   {'id': 'Cong Yu'},
#   {'id': 'S. M. Koohpayeh'},
#   {'id': 'J. Hinton'},
#   {'id': 'S. V. Dmitriev'},
#   {'id': 'R. Barrena'},
#   {'id': 'E. S. Zijlstra'},
#   {'id': 'S. M. Zyryanov'},
#   {'id': 'Weisheng Dong'},
#   {'id': 'G. -Q. Hai'},
#   {'id': 'Bei-Jiang Liu'},
#   {'id': 'Mirko Navara'},
#   {'id': 'Jason Horng'},
#   {'id': 'Patrick J. McCarthy'},
#   {'id': 'C. Langbrandtner'},
#   {'id': 'Stefano de Gironcoli'},
#   {'id': 'J. H. Roberts'},
#   {'id': 'Matthew Schenker'},
#   ...]}

# %%
test = json.dumps(data)

# %%
with open('test_arxiv.json','w') as f:
    json.dump(test,f)

# %%
# !open .

# %%
nx.write_gml(G,'test_arxiv.gml')

# %%
G.nodes()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-20c26818134b> in <module>()
# ----> 1 G.nodes()
#
# NameError: name 'G' is not defined

# %%
with open('test_axriv_2.json','w') as f:
    json.dump(G.nodes(),f)

# %%
a = 1

# %%
a
# Out:
# 1

# %%
a = {}

# %%
a.update({'Title':'Blah'})

# %%
a = {'Title':'Title','Test':'b'}

# %%
a
# Out:
# {'Test': 'b', 'Title': 'Blah'}

# %%
a.
